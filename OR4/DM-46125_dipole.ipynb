# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

import healpy as hp

import lsst.daf.butler as dafButler
from lsst.analysis.ap import apdb
from lsst.ap.association import AssociationTask, AssociationConfig
from lsst.dax.apdb import Apdb, ApdbCassandra, ApdbTables
import lsst.geom

from mpl_toolkits.axes_grid1 import make_axes_locatable
from astropy.visualization import ZScaleInterval, ImageNormalize, ManualInterval, AsinhStretch
from astropy.visualization import ZScaleInterval, SqrtStretch, ImageNormalize, MinMaxInterval, LogStretch

import warnings
warnings.filterwarnings('ignore')
warnings.simplefilter('ignore')

from typing import TYPE_CHECKING, cast

import astropy.units as u
from astropy.coordinates import SkyCoord

plt.set_loglevel('WARNING')

# %% [markdown]
# # Imports

# %%
i1 = 7436
i2 = 7565
# why this sometimes takes so long 
# find which ones are variable
df_single_ps1 = pd.read_parquet('/sdf/data/rubin/shared/ops-rehearsals/ops-rehearsal-4/imSim_catalogs/skyCatalogs/pointsource_'+str(i1)+'.parquet')
df_single_ps2 = pd.read_parquet('/sdf/data/rubin/shared/ops-rehearsals/ops-rehearsal-4/imSim_catalogs/skyCatalogs/pointsource_'+str(i2)+'.parquet')
# Concatenate the dataframes
df_single_ps = pd.concat([df_single_ps1, df_single_ps2], ignore_index=True)

df_single_ps1_flux = pd.read_parquet('/sdf/data/rubin/shared/ops-rehearsals/ops-rehearsal-4/imSim_catalogs/skyCatalogs/pointsource_flux_'+str(i1)+'.parquet')
df_single_ps2_flux = pd.read_parquet('/sdf/data/rubin/shared/ops-rehearsals/ops-rehearsal-4/imSim_catalogs/skyCatalogs/pointsource_flux_'+str(i2)+'.parquet')
# Concatenate the dataframes
df_single_ps_flux = pd.concat([df_single_ps1_flux, df_single_ps2_flux], ignore_index=True)

#df_single_sso = pd.read_parquet('/sdf/data/rubin/shared/ops-rehearsals/ops-rehearsal-4/imSim_catalogs/skyCatalogs/sso_'+str(i)+'.parquet')
#df_single_gal = pd.read_parquet('/sdf/data/rubin/shared/ops-rehearsals/ops-rehearsal-4/imSim_catalogs/skyCatalogs/galaxy_'+str(i)+'.parquet')
df_single_ps_var = df_single_ps[df_single_ps['is_variable']==True]


ra_min =215.60
ra_max = 216.40
dec_min = -12.90
dec_max = -12.15

# Apply the filter to the dataframe
tru_var_obj = df_single_ps_var[
    (df_single_ps_var['ra'] >= ra_min) & (df_single_ps_var['ra'] <= ra_max) &
    (df_single_ps_var['dec'] >= dec_min) & (df_single_ps_var['dec'] <= dec_max)]

# %%
def create_mag_errors(sciFlux, sciFluxErr):
    """Move flux into magnitudes and calculate the error on the magnitude
    
    Parameters
    ----------
    sciFlux : `float`
        Science flux
    sciFluxErr : `float`
        Science flux error

    Returns
    -------
    mag, magerr  : `float`, `float`
        Magnitude and magnitude error
    """
    
    mag = u.nJy.to(u.ABmag, sciFlux)
    upper_mag = u.nJy.to(u.ABmag, sciFlux+sciFluxErr)
    lower_mag = u.nJy.to(u.ABmag, sciFlux-sciFluxErr)
    magErr = -(upper_mag-lower_mag)/2
    
    return mag, magErr

def degrees_to_radians(degrees):
    """
    Convert an angle from degrees to radians.

    Parameters:
    degrees (float): Angle in degrees.

    Returns:
    float: Angle in radians (unitless).
    """
    # Convert the input degrees to radians
    radians = (degrees * u.deg).to(u.rad)
    
    # Return the numerical value (without the unit)
    return radians.value

def radians_to_degrees(radians):
    """
    Convert an angle from radians to degrees.

    Parameters:
    radians (float): Angle in radians.

    Returns:
    float: Angle in degrees (unitless).
    """
    # Convert the input radians to degrees
    degrees = (radians * u.rad).to(u.deg)
    
    # Return the numerical value (without the unit)
    return degrees.value

# %%
def plotFlagImages(exp, flagList=['NO_DATA', 'DETECTED', 'DETECTED_NEGATIVE', 'STREAK']):
    fig = plt.figure(figsize=(24,8))
    #plt.suptitle(dataId)
    fig.add_subplot(1, len(flagList)+1, 1)
    norm = ImageNormalize(exp.image.array, interval=ZScaleInterval(), stretch=SqrtStretch())
    im = plt.imshow(exp.image.array, origin='lower', norm=norm, cmap='gray')
    plt.gca().axes.xaxis.set_ticklabels([])
    plt.gca().axes.yaxis.set_ticklabels([])
    plt.title('diffim')
    i = 1
    for (name, bit) in exp.mask.getMaskPlaneDict().items():
        if name in flagList:
            fig.add_subplot(1, len(flagList)+1, i + 1)
            im = plt.imshow(np.where(exp.mask.array & 2**bit, 1, 0),
                       origin='lower', cmap='GnBu', interpolation='nearest')
            plt.title(name)
            plt.gca().axes.xaxis.set_ticklabels([])
            plt.gca().axes.yaxis.set_ticklabels([])
            i = i + 1
            del im

# %%
repo = 'embargo_or4'

instrument = 'LSSTComCamSim'
schema =  f'pp_ppdb_lsstcomcamsim_or4'

butler = dafButler.Butler(repo, instrument=instrument)
registry = butler.registry
# skymap = butler.get("skyMap", collections=collections, skymap="ops_rehersal_prep_2k_v1")
apdbQuery = apdb.ApdbPostgresQuery(instrument=instrument, namespace=schema)

# %%
ra_min = 215.6
ra_max = 216.4
dec_min = -12.9
dec_max = -12.15

ra_min_in_rad = (ra_min*u.deg).to(u.rad).value
ra_max_in_rad = (ra_max*u.deg).to(u.rad).value
dec_min_in_rad = (dec_min*u.deg).to(u.rad).value
dec_max_in_rad = (dec_max*u.deg).to(u.rad).value

# %%
with apdbQuery.connection as connection:
    src4_field = pd.read_sql_query(f'''
        SELECT 
            "diaSourceId", 
            "diaObjectId", 
            "ra", 
            "dec", 
            "raErr", 
            "decErr", 
            "midpointMjdTai", 
            "psfFlux", 
            "psfFluxErr", 
            "scienceFlux", 
            "scienceFluxErr", 
            "snr", 
            "band", 
            "visit",
            "detector",	
            "x",
            "xErr",
            "y",
            "yErr",
            "time_processed", 
            "time_withdrawn",
            "isDipole",
            "centroid_flag",
            "apFlux_flag",
            "apFlux_flag_apertureTruncated",
            "psfFlux_flag",
            "psfFlux_flag_edge",
            "psfFlux_flag_noGoodPixels",
            "trail_flag_edge",
            "forced_PsfFlux_flag",
            "forced_PsfFlux_flag_edge",
            "forced_PsfFlux_flag_noGoodPixels",
            "shape_flag",
            "shape_flag_no_pixels",
            "shape_flag_not_contained",
            "shape_flag_parent_source",
            "pixelFlags",
            "pixelFlags_bad",
            "pixelFlags_cr",
            "pixelFlags_crCenter",
            "pixelFlags_edge",
            "pixelFlags_interpolated",
            "pixelFlags_interpolatedCenter",
            "pixelFlags_offimage",
            "pixelFlags_saturated",
            "pixelFlags_saturatedCenter",
            "pixelFlags_suspect",
            "pixelFlags_suspectCenter",
            "pixelFlags_streak",
            "pixelFlags_streakCenter",
            "pixelFlags_injected",
            "pixelFlags_injectedCenter",
            "pixelFlags_injected_template",
            "pixelFlags_injected_templateCenter",
            "reliability"
        FROM "{schema}"."DiaSource"
        WHERE "ra" BETWEEN {ra_min} AND {ra_max}
        AND "dec" BETWEEN {dec_min} AND {dec_max}
        LIMIT 3000000;
    ''', connection)

# %%
with apdbQuery.connection as connection:
    srcForced4_field = pd.read_sql_query(f'''
        SELECT 
            "diaForcedSourceId", 
            "diaObjectId", 
            "ra", 
            "dec",
            "visit",
            "detector", 
            "midpointMjdTai", 
            "psfFlux", 
            "psfFluxErr", 
            "scienceFlux", 
            "scienceFluxErr", 
            "band"
        FROM "{schema}"."DiaForcedSource"
        WHERE "ra" BETWEEN {ra_min_in_rad} AND {ra_max_in_rad}
        AND "dec" BETWEEN {dec_min_in_rad} AND {dec_max_in_rad}
        LIMIT 3000000;
    ''', connection)
    
srcForced4_field['ra'] = radians_to_degrees(srcForced4_field['ra'].values)
srcForced4_field['dec'] = radians_to_degrees(srcForced4_field['dec'].values)

# %%
#latest = False does not work
or4_obj = apdbQuery.load_objects(limit=1e7, latest=True)

# We got all of them, less than 1e7 here
assert len(or4_obj) < 1e7

# %%
# lets look at only one field
# objects
obj4_field = or4_obj[(or4_obj['ra'] > ra_min) & (or4_obj['ra'] < ra_max) & (or4_obj['dec'] > dec_min) & (or4_obj['dec'] < dec_max)]
obj4_field
# Out:
#                 diaObjectId             validityStart validityEnd          ra  \
# 153210  3068394109505896606 2024-06-26 02:48:25+00:00        None  215.889039
# 153235  3068394109505896635 2024-06-26 02:52:34+00:00        None  215.948394
# 153238  3068394109505896638 2024-06-26 02:54:17+00:00        None  215.922383
# 153239  3068394109505896639 2024-06-26 02:58:21+00:00        None  215.966875
# 153244  3068394109505896644 2024-06-26 02:50:38+00:00        None  215.937075
# ...                     ...                       ...         ...         ...
# 171475  3068394172890218525 2024-06-26 02:55:53+00:00        None  215.635087
# 171477  3068394172890218554 2024-06-26 02:55:53+00:00        None  215.690908
# 171478  3068394172890218581 2024-06-26 02:55:53+00:00        None  215.665284
# 171479  3068394172890218585 2024-06-26 02:55:53+00:00        None  215.677023
# 171481  3068394172890218629 2024-06-26 02:55:53+00:00        None  215.749328
#
#                raErr        dec        decErr    ra_dec_Cov   radecMjdTai  \
# 153210           NaN -12.896901           NaN           NaN  60487.114560
# 153235  2.019397e-05 -12.894802  9.924860e-06 -1.183491e-10  60487.117363
# 153238  5.851012e-07 -12.885339  6.303400e-07  1.301129e-14  60487.118303
# 153239  8.505353e-06 -12.899532  1.858597e-05  9.602694e-11  60487.118303
# 153244           NaN -12.884774           NaN           NaN  60487.115963
# ...              ...        ...           ...           ...           ...
# 171475           NaN -12.360875           NaN           NaN  60487.119709
# 171477  3.625022e-05 -12.306796  2.220503e-05  4.035649e-11  60487.119709
# 171478  2.192825e-05 -12.264642  4.064201e-05 -5.401110e-11  60487.119709
# 171479  2.335178e-05 -12.260069  2.930849e-05 -1.390424e-11  60487.119709
# 171481           NaN -12.203916           NaN           NaN  60487.119709
#
#         pmRa  ... y_psfFluxPercentile95 y_psfFluxMin y_psfFluxMax  \
# 153210  None  ...                  None         None         None
# 153235  None  ...                  None         None         None
# 153238  None  ...                  None         None         None
# 153239  None  ...                  None         None         None
# 153244  None  ...                  None         None         None
# ...      ...  ...                   ...          ...          ...
# 171475  None  ...                  None         None         None
# 171477  None  ...                  None         None         None
# 171478  None  ...                  None         None         None
# 171479  None  ...                  None         None         None
# 171481  None  ...                  None         None         None
#
#        y_psfFluxStetsonJ y_psfFluxLinearSlope y_psfFluxLinearIntercept  \
# 153210              None                 None                     None
# 153235              None                 None                     None
# 153238              None                 None                     None
# 153239              None                 None                     None
# 153244              None                 None                     None
# ...                  ...                  ...                      ...
# 171475              None                 None                     None
# 171477              None                 None                     None
# 171478              None                 None                     None
# 171479              None                 None                     None
# 171481              None                 None                     None
#
#        y_psfFluxMaxSlope y_psfFluxErrMean       lastNonForcedSource  \
# 153210              None             None 2024-06-26 02:26:12+00:00
# 153235              None             None 2024-06-26 02:51:18+00:00
# 153238              None             None 2024-06-26 02:52:34+00:00
# 153239              None             None 2024-06-26 02:52:34+00:00
# 153244              None             None 2024-06-26 02:26:12+00:00
# ...                  ...              ...                       ...
# 171475              None             None 1970-01-01 00:00:00+00:00
# 171477              None             None 1970-01-01 00:00:00+00:00
# 171478              None             None 1970-01-01 00:00:00+00:00
# 171479              None             None 1970-01-01 00:00:00+00:00
# 171481              None             None 1970-01-01 00:00:00+00:00
#
#        nDiaSources
# 153210           5
# 153235           7
# 153238          23
# 153239          15
# 153244           4
# ...            ...
# 171475           1
# 171477           1
# 171478           1
# 171479           1
# 171481           1
#
# [9942 rows x 190 columns]

# %% [markdown]
# # DM - 46125

# %%
repo = 'embargo_or4'
instrument = 'LSSTComCamSim'
# pp_collections = ['LSSTComCamSim/prompt/output-2024-06-25', 'LSSTComCamSim/prompt/output-2024-06-26', 'LSSTComCamSim/prompt/output-2024-06-27']
pp_collections = 'u/sullii/DM-46333/OR4/association'

pp_butler = dafButler.Butler(repo, collections=pp_collections, instrument=instrument)

# %%
list_datasets = list(set(pp_butler.registry.queryDatasets('goodSeeingDiff_assocDiaSrc',  where="instrument='LSSTComCamSim'",  collections=pp_collections)))
# Extract relevant fields: 'detector', 'visit', 'band'
extracted_info = [(item.dataId['detector'], item.dataId['visit'], item.dataId['band']) for item in list_datasets]
extracted_info = pd.DataFrame(extracted_info, columns=['detector', 'visit', 'band']).sort_values(by='visit')
# all the visits in OR4
list_of_visits = (np.unique(extracted_info['visit']))

# %%
# visit which exists in the source table but not in goodSeeingDiff_assocDiaSrc table?
np.setxor1d( np.intersect1d(src4_field['visit'].unique(),list_of_visits),src4_field['visit'].unique())
# Out:
# array([7024062500195])

# %%
# obj that have nan as raErr or decErr
obj4_field_nan = obj4_field[pd.isna(obj4_field['raErr'])]
# obj that have actual values as raErr or decErr
obj4_field_not_nan = obj4_field[pd.notna(obj4_field['raErr'])]

print(len(obj4_field_not_nan))
print(len(obj4_field_nan))
# Out:
# 5876
# 4066

# %%
# select a single object
single_obj = obj4_field_nan[obj4_field_nan['nDiaSources'] > 10].iloc[23]
single_obj = obj4_field_not_nan[obj4_field_not_nan['nDiaSources'] > 10].iloc[230]
single_obj
# Out:
# diaObjectId                       3068394109518479458
# validityStart               2024-06-26 02:56:11+00:00
# validityEnd                                      None
# ra                                         216.165437
# raErr                                        0.000008
#                                       ...
# y_psfFluxLinearIntercept                         None
# y_psfFluxMaxSlope                                None
# y_psfFluxErrMean                                 None
# lastNonForcedSource         2024-06-26 02:55:46+00:00
# nDiaSources                                        19
# Name: 154061, Length: 190, dtype: object

# %%
# select all sources for this object
src_for_single_obj = src4_field[(src4_field['diaObjectId']==single_obj['diaObjectId']) ]
print(src_for_single_obj['diaSourceId'].values[0], src_for_single_obj['ra'].values[0], src_for_single_obj['dec'].values[0])
# Out:
# 3068394109518479458 216.16532087735004 -12.71539803680108

# %%
# select a single source
single_src_id = src_for_single_obj['diaSourceId'].values[0]
print(single_src_id)
# Out:
# 3068394109518479458

# %%
# selector boolean array
select_single = src_for_single_obj['diaSourceId']==single_src_id
select_single
# Out:
# 152       True
# 1448     False
# 10758    False
# 21982    False
# 25305    False
# 27819    False
# 29637    False
# 33789    False
# 35253    False
# 36094    False
# 38357    False
# 39371    False
# 45887    False
# 47081    False
# 48372    False
# 50239    False
# 51739    False
# 53329    False
# 57244    False
# Name: diaSourceId, dtype: bool

# %%
plt.scatter(np.arange(len(list_of_visits)), list_of_visits)
plt.axhline(src_for_single_obj.loc[select_single,'visit'].values[0], color='r', linestyle='--')  
plt.ylim(src_for_single_obj.loc[select_single,'visit'].values[0] - 100 , src_for_single_obj.loc[select_single,'visit'].values[0] + 100)
# Out:
# (7024062500090.0, 7024062500290.0)

# %%
# position of the source
center = lsst.geom.SpherePoint(src_for_single_obj.loc[select_single,'ra'], src_for_single_obj.loc[select_single,'dec'] , lsst.geom.degrees)
center
# Out:
# SpherePoint(216.16532087735004*degrees, -12.71539803680108*degrees)

# %%
extent = lsst.geom.Extent2I(2000, 2000)
data1= {'detector': src_for_single_obj.loc[select_single,'detector'].values[0], 'visit': src_for_single_obj.loc[select_single,'visit'].values[0]}

src_via_butler = pp_butler.get('goodSeeingDiff_assocDiaSrc', dataId=data1)

one_pp_science = pp_butler.get('initial_pvi', dataId=data1)
one_pp_template = pp_butler.get('goodSeeingDiff_templateExp', dataId=data1)
one_pp_diffim = pp_butler.get('goodSeeingDiff_differenceExp', dataId=data1)

science_cutout = one_pp_science.getCutout(center, extent)
template_cutout = one_pp_template.getCutout(center, extent)
difference_cutout = one_pp_diffim.getCutout(center, extent)

# %%
# check that source is there via butler
src_for_single_obj_via_butler = src_via_butler[src_via_butler['diaObjectId'] == src_for_single_obj['diaObjectId'].values[0]]
src_for_single_obj_via_butler
# Out:
#                                                       diaSourceId  \
# diaObjectId         band diaSourceId
# 3068394109518479458 i    3068394109518479458  3068394109518479458
#
#                                                       visit  detector  \
# diaObjectId         band diaSourceId
# 3068394109518479458 i    3068394109518479458  7024062500190         3
#
#                                                       diaObjectId  ssObjectId  \
# diaObjectId         band diaSourceId
# 3068394109518479458 i    3068394109518479458  3068394109518479458           0
#
#                                               parentDiaSourceId  \
# diaObjectId         band diaSourceId
# 3068394109518479458 i    3068394109518479458                  0
#
#                                              ssObjectReassocTime  \
# diaObjectId         band diaSourceId
# 3068394109518479458 i    3068394109518479458                 NaT
#
#                                               midpointMjdTai          ra  \
# diaObjectId         band diaSourceId
# 3068394109518479458 i    3068394109518479458     60487.08931  216.165321
#
#                                                  raErr  ...  \
# diaObjectId         band diaSourceId                    ...
# 3068394109518479458 i    3068394109518479458  0.000008  ...
#
#                                               pixelFlags_saturatedCenter  \
# diaObjectId         band diaSourceId
# 3068394109518479458 i    3068394109518479458                       False
#
#                                               pixelFlags_suspect  \
# diaObjectId         band diaSourceId
# 3068394109518479458 i    3068394109518479458               False
#
#                                               pixelFlags_suspectCenter  \
# diaObjectId         band diaSourceId
# 3068394109518479458 i    3068394109518479458                     False
#
#                                               pixelFlags_streak  \
# diaObjectId         band diaSourceId
# 3068394109518479458 i    3068394109518479458              False
#
#                                               pixelFlags_streakCenter  \
# diaObjectId         band diaSourceId
# 3068394109518479458 i    3068394109518479458                    False
#
#                                               pixelFlags_injected  \
# diaObjectId         band diaSourceId
# 3068394109518479458 i    3068394109518479458                False
#
#                                               pixelFlags_injectedCenter  \
# diaObjectId         band diaSourceId
# 3068394109518479458 i    3068394109518479458                      False
#
#                                               pixelFlags_injected_template  \
# diaObjectId         band diaSourceId
# 3068394109518479458 i    3068394109518479458                         False
#
#                                               pixelFlags_injected_templateCenter  \
# diaObjectId         band diaSourceId
# 3068394109518479458 i    3068394109518479458                               False
#
#                                               programId
# diaObjectId         band diaSourceId
# 3068394109518479458 i    3068394109518479458          0
#
# [1 rows x 144 columns]

# %%
src_for_single_obj[src_for_single_obj['visit'] == src_for_single_obj_via_butler['visit'].values[0]]
# Out:
#              diaSourceId          diaObjectId          ra        dec  \
# 152  3068394109518479458  3068394109518479458  216.165321 -12.715398
#
#         raErr   decErr  midpointMjdTai      psfFlux  psfFluxErr  scienceFlux  \
# 152  0.000008  0.00001     60487.08931  4106.269531  348.134827  98635.84375
#
#      ...  pixelFlags_saturatedCenter  pixelFlags_suspect  \
# 152  ...                       False               False
#
#     pixelFlags_suspectCenter  pixelFlags_streak  pixelFlags_streakCenter  \
# 152                    False              False                    False
#
#      pixelFlags_injected  pixelFlags_injectedCenter  \
# 152                False                      False
#
#      pixelFlags_injected_template  pixelFlags_injected_templateCenter  \
# 152                         False                               False
#
#     reliability
# 152        None
#
# [1 rows x 55 columns]

# %%
# Create subplots
fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(24,8))


# Normalize the science and template images using ZScaleInterval
norm_science = ImageNormalize(science_cutout.image.array, interval=ZScaleInterval())
norm_template = ImageNormalize(template_cutout.image.array, interval=ZScaleInterval())

# Normalize the diffim image symmetrically around 0 using ManualInterval and SqrtStretch
max_abs_val = norm_science.vmax  # Find max absolute value
norm_diffim = ImageNormalize(vmin=-max_abs_val, vmax=max_abs_val)


# Display the images and store the imshow object for adding colorbars
img1 = ax1.imshow(science_cutout.image.array, origin='lower', norm=norm_science, cmap='gray')
img2 = ax2.imshow(template_cutout.image.array, origin='lower', norm=norm_template, cmap='gray')
img3 = ax3.imshow(difference_cutout.image.array, origin='lower', norm=norm_diffim, cmap='gray')


# Add colorbars for each image
# Create colorbars with appropriate sizes next to each subplot
for ax, img in zip([ax1, ax2, ax3], [img1, img2, img3]):
    divider = make_axes_locatable(ax)
    cax = divider.append_axes("right", size="5%", pad=0.05)
    fig.colorbar(img, cax=cax, orientation='vertical')

# Set individual titles above each image
ax1.set_title('Science Image')
ax2.set_title('Template Image')
ax3.set_title('Difference Image')

# Show the plot
plt.show()

# %%
# Create subplots
fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(24,8))


# Normalize the science and template images using ZScaleInterval
norm_science = ImageNormalize(science_cutout.image.array, interval=ZScaleInterval())
norm_template = ImageNormalize(template_cutout.image.array, interval=ZScaleInterval())

# Normalize the diffim image symmetrically around 0 using ManualInterval and SqrtStretch
max_abs_val = norm_science.vmax  # Find max absolute value
norm_diffim = ImageNormalize(vmin=-max_abs_val, vmax=max_abs_val)


# Display the images and store the imshow object for adding colorbars
img1 = ax1.imshow(science_cutout.mask.array, origin='lower', norm=norm_science, cmap='gray')
img2 = ax2.imshow(template_cutout.mask.array, origin='lower', norm=norm_template, cmap='gray')
img3 = ax3.imshow(difference_cutout.mask.array, origin='lower', norm=norm_diffim, cmap='gray')


# Add colorbars for each image
# Create colorbars with appropriate sizes next to each subplot
for ax, img in zip([ax1, ax2, ax3], [img1, img2, img3]):
    divider = make_axes_locatable(ax)
    cax = divider.append_axes("right", size="5%", pad=0.05)
    fig.colorbar(img, cax=cax, orientation='vertical')

# Set individual titles above each image
ax1.set_title('Science Image')
ax2.set_title('Template Image')
ax3.set_title('Difference Image')
# Out:
# Text(0.5, 1.0, 'Difference Image')

# %%
template_cutout.mask.getMaskPlaneDict().items()
# Out:
# dict_items([('BAD', 0), ('CLIPPED', 9), ('CR', 3), ('DETECTED', 5), ('DETECTED_NEGATIVE', 6), ('EDGE', 4), ('INEXACT_PSF', 10), ('INJECTED', 11), ('INJECTED_TEMPLATE', 12), ('INTRP', 2), ('NOT_DEBLENDED', 13), ('NO_DATA', 8), ('REJECTED', 14), ('SAT', 1), ('SAT_TEMPLATE', 15), ('SENSOR_EDGE', 16), ('STREAK', 17), ('SUSPECT', 7), ('UNMASKEDNAN', 18)])

# %%
print(np.unique(template_cutout.mask.array))
print(np.unique(difference_cutout.mask.array))
print(np.unique(science_cutout.mask.array))


# Invert the mask_plane_dict so we can look up bit positions
bit_to_flag = {v: k for k, v in mask_plane_dict.items()}

# Function to explain mask value
def explain_mask_value(mask_value):
    explanations = []
    for bit_position in range(32):  # Assume 32-bit mask values, adjust if necessary
        if mask_value & (1 << bit_position):  # Check if the bit at bit_position is set
            flag = bit_to_flag.get(bit_position, f'Unknown flag at bit {bit_position}')
            explanations.append(flag)
    return explanations

# Print explanations for each unique mask value
for value in np.unique(template_cutout.mask.array):
    explanation = explain_mask_value(value)
    print(f"Mask value {value} has the following flags set: {explanation}")
# Out:
# [    0    12    32    44  1536 17440 17442 17452 17454 17668 17702 66560
#  66572 66592 82976 82978 83204 83238]
# [   0   32   64   96  256  262 8224 8480]
# [ 0 32 38]

# %%
def plotFlagImages(exp, flagList=['DETECTED_NEGATIVE', 'DETECTED', 'SENSOR_EDGE', 'INEXACT_PSF']):
    fig = plt.figure(figsize=(24,8))
    #plt.suptitle(dataId)
    fig.add_subplot(1, len(flagList)+1, 1)
    norm = ImageNormalize(exp.image.array, interval=ZScaleInterval(), stretch=SqrtStretch())
    im = plt.imshow(exp.image.array, origin='lower', norm=norm, cmap='gray')
    plt.gca().axes.xaxis.set_ticklabels([])
    plt.gca().axes.yaxis.set_ticklabels([])
    plt.title('diffim')
    i = 1
    for (name, bit) in exp.mask.getMaskPlaneDict().items():
        if name in flagList:
            
            fig.add_subplot(1, len(flagList)+1, i + 1)
            im = plt.imshow(np.where(exp.mask.array & 2**bit, 1, 0),
                       origin='lower', cmap='GnBu', interpolation='nearest')
            plt.title(name)
            plt.gca().axes.xaxis.set_ticklabels([])
            plt.gca().axes.yaxis.set_ticklabels([])
            i = i + 1
            del im

# %%
plotFlagImages(science_cutout)

# %%
plotFlagImages(template_cutout)

# %%
plotFlagImages(difference_cutout)

# %%
single_obj = obj4_field_nan[obj4_field_nan['nDiaSources'] > 10].iloc[230]
single_obj
# Out:
# diaObjectId                       3068394111678546018
# validityStart               2024-06-26 02:55:53+00:00
# validityEnd                                      None
# ra                                         216.280468
# raErr                                             NaN
#                                       ...
# y_psfFluxLinearIntercept                         None
# y_psfFluxMaxSlope                                None
# y_psfFluxErrMean                                 None
# lastNonForcedSource         2024-06-26 02:53:01+00:00
# nDiaSources                                        28
# Name: 155859, Length: 190, dtype: object

# %%
single_obj = obj4_field_not_nan[obj4_field_not_nan['nDiaSources'] > 10].iloc[230]
single_obj
# Out:
# diaObjectId                       3068394109518479458
# validityStart               2024-06-26 02:56:11+00:00
# validityEnd                                      None
# ra                                         216.165437
# raErr                                        0.000008
#                                       ...
# y_psfFluxLinearIntercept                         None
# y_psfFluxMaxSlope                                None
# y_psfFluxErrMean                                 None
# lastNonForcedSource         2024-06-26 02:55:46+00:00
# nDiaSources                                        19
# Name: 154061, Length: 190, dtype: object

# %%
# select all sources for this object
src_for_single_obj = src4_field[(src4_field['diaObjectId']==single_obj['diaObjectId']) ]
src_for_single_obj[['centroid_flag', 'apFlux_flag', 'psfFlux_flag', 'forced_PsfFlux_flag', 'shape_flag']]
# Out:
#        centroid_flag  apFlux_flag  psfFlux_flag  forced_PsfFlux_flag  \
# 152            False        False         False                False
# 1448           False        False         False                False
# 10758           True         True          True                 True
# 21982           True         True          True                 True
# 25305           True         True          True                 True
# 27819          False        False         False                False
# 29637          False        False         False                False
# 33789          False        False         False                False
# 35253          False        False         False                False
# 36094          False        False         False                False
# 38357          False        False         False                False
# 39371          False        False         False                False
# 45887           True         True          True                 True
# 47081          False        False         False                False
# 48372          False        False         False                False
# 50239          False        False         False                False
# 51739          False        False         False                False
# 53329           True         True          True                 True
# 57244          False        False         False                False
#
#        shape_flag
# 152          True
# 1448        False
# 10758        True
# 21982        True
# 25305        True
# 27819       False
# 29637        True
# 33789       False
# 35253        True
# 36094       False
# 38357        True
# 39371        True
# 45887        True
# 47081        True
# 48372       False
# 50239        True
# 51739        True
# 53329        True
# 57244        True

# %%
src_for_single_obj.loc[45887]
# Out:
# diaSourceId                                 3068394170709180481
# diaObjectId                                 3068394109518479458
# ra                                                   216.165468
# dec                                                  -12.715666
# raErr                                                       NaN
# decErr                                                      NaN
# midpointMjdTai                                      60487.11877
# psfFlux                                            -1608.145874
# psfFluxErr                                           303.842804
# scienceFlux                                        61105.542969
# scienceFluxErr                                       296.876678
# snr                                                    5.301852
# band                                                          r
# visit                                             7024062500247
# detector                                                      0
# x                                                         383.0
# xErr                                                        NaN
# y                                                        1305.0
# yErr                                                        NaN
# time_processed                        2024-06-26 02:54:03+00:00
# time_withdrawn                                             None
# isDipole                                                  False
# centroid_flag                                              True
# apFlux_flag                                                True
# apFlux_flag_apertureTruncated                             False
# psfFlux_flag                                               True
# psfFlux_flag_edge                                         False
# psfFlux_flag_noGoodPixels                                 False
# trail_flag_edge                                           False
# forced_PsfFlux_flag                                        True
# forced_PsfFlux_flag_edge                                  False
# forced_PsfFlux_flag_noGoodPixels                          False
# shape_flag                                                 True
# shape_flag_no_pixels                                      False
# shape_flag_not_contained                                  False
# shape_flag_parent_source                                  False
# pixelFlags                                                False
# pixelFlags_bad                                            False
# pixelFlags_cr                                             False
# pixelFlags_crCenter                                       False
# pixelFlags_edge                                           False
# pixelFlags_interpolated                                   False
# pixelFlags_interpolatedCenter                             False
# pixelFlags_offimage                                       False
# pixelFlags_saturated                                      False
# pixelFlags_saturatedCenter                                False
# pixelFlags_suspect                                        False
# pixelFlags_suspectCenter                                  False
# pixelFlags_streak                                         False
# pixelFlags_streakCenter                                   False
# pixelFlags_injected                                       False
# pixelFlags_injectedCenter                                 False
# pixelFlags_injected_template                              False
# pixelFlags_injected_templateCenter                        False
# reliability                                                None
# Name: 45887, dtype: object

# %%
src_for_single_obj[['diaSourceId', 'raErr', 'decErr', 'xErr', 'yErr', 'psfFlux', 'band', 'centroid_flag', 'apFlux_flag', 'psfFlux_flag', 'forced_PsfFlux_flag', 'shape_flag']]
# Out:
#                diaSourceId     raErr    decErr      xErr      yErr  \
# 152    3068394109518479458  0.000008  0.000010       NaN       NaN
# 1448   3068394111653380230  0.000010  0.000012  0.175130  0.211453
# 10758  3068394133144993855       NaN       NaN       NaN       NaN
# 21982  3068394146017312928       NaN       NaN       NaN       NaN
# 25305  3068394150308085797       NaN       NaN       NaN       NaN
# 27819  3068394152459763779  0.000022  0.000029  0.381295  0.539300
# 29637  3068394155676794899  0.000016  0.000022       NaN       NaN
# 33789  3068394159971762331  0.000010  0.000009       NaN       NaN
# 35253  3068394161058086982  0.000017  0.000015       NaN       NaN
# 36094  3068394162119245909  0.000015  0.000015  0.278583  0.272957
# 38357  3068394163205570632  0.000022  0.000014  0.411763  0.245570
# 39371  3068394164279312397  0.000007  0.000006       NaN       NaN
# 45887  3068394170709180481       NaN       NaN       NaN       NaN
# 47081  3068394171787116674  0.000009  0.000008       NaN       NaN
# 48372  3068394172856664167  0.000027  0.000028  0.503825  0.500539
# 50239  3068394127759507529  0.000017  0.000015  0.305494  0.271959
# 51739  3068394128833249386  0.000012  0.000014  0.226048  0.243815
# 53329  3068394129906991231       NaN       NaN       NaN       NaN
# 57244  3068394126685765704  0.000022  0.000020  0.413977  0.364219
#
#            psfFlux band  centroid_flag  apFlux_flag  psfFlux_flag  \
# 152    4106.269531    i          False        False         False
# 1448   4028.226074    i          False        False         False
# 10758 -1692.929199    g           True         True          True
# 21982 -1451.361938    g           True         True          True
# 25305 -2636.998779    g           True         True          True
# 27819  1860.563477    r          False        False         False
# 29637  2031.590576    r          False        False         False
# 33789  4334.764160    r          False        False         False
# 35253  1988.346924    r          False        False         False
# 36094  2384.051270    r          False        False         False
# 38357  1970.999268    r          False        False         False
# 39371  5208.815430    r          False        False         False
# 45887 -1608.145874    r           True         True          True
# 47081  5071.286133    r          False        False         False
# 48372  1921.567383    r          False        False         False
# 50239  2690.723145    i          False        False         False
# 51739  3265.170654    i          False        False         False
# 53329 -1861.365845    i           True         True          True
# 57244  2531.459717    i          False        False         False
#
#        forced_PsfFlux_flag  shape_flag
# 152                  False        True
# 1448                 False       False
# 10758                 True        True
# 21982                 True        True
# 25305                 True        True
# 27819                False       False
# 29637                False        True
# 33789                False       False
# 35253                False        True
# 36094                False       False
# 38357                False        True
# 39371                False        True
# 45887                 True        True
# 47081                False        True
# 48372                False       False
# 50239                False        True
# 51739                False        True
# 53329                 True        True
# 57244                False        True

# %%
# If xErr and yErr are NaN, raErr and decErr are not NaN if isDipole is True
# If xErr and yErr are NaN, raErr and decErr are NaN if isDipole is False

# %%
# find this source in the butler, but as a candidate and associate it with the source

#example with a source that has Nan for xErr and yErr, but has errors for raErr and decErr

data1= {'detector': 3, 'visit': 7024062500190}
src_via_butler = pp_butler.get('goodSeeingDiff_assocDiaSrc', dataId=data1)
src_cand_via_butler = pp_butler.get('goodSeeingDiff_candidateDiaSrc', dataId=data1)

single_butler_src = src_via_butler[src_via_butler['diaSourceId'] == 3068394109518479458]
single_butler_cand_src = src_cand_via_butler[src_cand_via_butler['id'] == 3068394109518479458]

# %%
single_butler_src[['diaSourceId', 'ra', 'raErr', 'dec', 'decErr', 'x', 'xErr', 'y', 'yErr', 'psfFlux', 'band', 'centroid_flag', 'apFlux_flag', 'psfFlux_flag', 'forced_PsfFlux_flag', 'shape_flag']]
# Out:
#                                                       diaSourceId          ra  \
# diaObjectId         band diaSourceId
# 3068394109518479458 i    3068394109518479458  3068394109518479458  216.165321
#
#                                                  raErr        dec   decErr  \
# diaObjectId         band diaSourceId
# 3068394109518479458 i    3068394109518479458  0.000008 -12.715398  0.00001
#
#                                                        x  xErr            y  \
# diaObjectId         band diaSourceId
# 3068394109518479458 i    3068394109518479458  431.811554   NaN  1537.749512
#
#                                               yErr      psfFlux band  \
# diaObjectId         band diaSourceId
# 3068394109518479458 i    3068394109518479458   NaN  4106.269531    i
#
#                                               centroid_flag  apFlux_flag  \
# diaObjectId         band diaSourceId
# 3068394109518479458 i    3068394109518479458          False        False
#
#                                               psfFlux_flag  \
# diaObjectId         band diaSourceId
# 3068394109518479458 i    3068394109518479458         False
#
#                                               forced_PsfFlux_flag  shape_flag
# diaObjectId         band diaSourceId
# 3068394109518479458 i    3068394109518479458                False        True

# %%
catalog = single_butler_cand_src
columns = catalog.schema.getNames()  # Get all column names
data = {col: catalog[col].tolist() for col in columns}  # Extract each column's data

# Create a pandas DataFrame
df = pd.DataFrame(data)

df[['id', 'coord_ra', 'coord_raErr', 'coord_dec', 'coord_decErr', 'base_SdssCentroid_x', 'base_SdssCentroid_y', 'base_PsfFlux_instFlux']]
# Out:
#                     id  coord_ra   coord_raErr  coord_dec  coord_decErr  \
# 0  3068394109518479458  3.772797  1.309876e-07  -0.221926  1.661769e-07
#
#    base_SdssCentroid_x  base_SdssCentroid_y  base_PsfFlux_instFlux
# 0           434.075123          1538.242949            4106.269749

# %%
# example where they are both Nan

src4_field[src4_field['diaSourceId'] == 3068394133144993855][['visit', 'detector']]
# Out:
#                visit  detector
# 10758  7024062500212         4

# %%
data1= {'detector': 4, 'visit': 7024062500212}
src_via_butler = pp_butler.get('goodSeeingDiff_assocDiaSrc', dataId=data1)
src_cand_via_butler = pp_butler.get('goodSeeingDiff_candidateDiaSrc', dataId=data1)

single_butler_src = src_via_butler[src_via_butler['diaSourceId'] == 3068394133144993855]
single_butler_cand_src = src_cand_via_butler[src_cand_via_butler['id'] == 3068394133144993855]

# %%
single_butler_src[['diaSourceId', 'ra', 'raErr', 'dec', 'decErr', 'x', 'xErr', 'y', 'yErr', 'psfFlux', 'band', 'centroid_flag', 'apFlux_flag', 'psfFlux_flag', 'forced_PsfFlux_flag', 'shape_flag']]
# Out:
#                                                       diaSourceId          ra  \
# diaObjectId         band diaSourceId
# 3068394109518479458 g    3068394133144993855  3068394133144993855  216.165366
#
#                                               raErr        dec  decErr      x  \
# diaObjectId         band diaSourceId
# 3068394109518479458 g    3068394133144993855    NaN -12.715597     NaN  888.0
#
#                                               xErr       y  yErr      psfFlux  \
# diaObjectId         band diaSourceId
# 3068394109518479458 g    3068394133144993855   NaN  1046.0   NaN -1692.929199
#
#                                              band  centroid_flag  apFlux_flag  \
# diaObjectId         band diaSourceId
# 3068394109518479458 g    3068394133144993855    g           True         True
#
#                                               psfFlux_flag  \
# diaObjectId         band diaSourceId
# 3068394109518479458 g    3068394133144993855          True
#
#                                               forced_PsfFlux_flag  shape_flag
# diaObjectId         band diaSourceId
# 3068394109518479458 g    3068394133144993855                 True        True

# %%
columns = single_butler_cand_src.schema.getNames()  # Get all column names
data = {col: single_butler_cand_src[col].tolist() for col in columns}  # Extract each column's data

# Create a pandas DataFrame
single_butler_cand_src_df = pd.DataFrame(data)

single_butler_cand_src_df[['id', 'ip_diffim_DipoleFit_flag_classification', 'coord_ra', 'coord_raErr', 'coord_dec', 'coord_decErr', 'base_SdssCentroid_x', 'base_SdssCentroid_xErr', 'base_SdssCentroid_y', 'base_SdssCentroid_yErr', 'base_PsfFlux_instFlux']]
# Out:
#                     id  ip_diffim_DipoleFit_flag_classification  coord_ra  \
# 0  3068394133144993855                                    False  3.772797
#
#    coord_raErr  coord_dec  coord_decErr  base_SdssCentroid_x  \
# 0          NaN  -0.221929           NaN                888.0
#
#    base_SdssCentroid_xErr  base_SdssCentroid_y  base_SdssCentroid_yErr  \
# 0                     NaN               1046.0                     NaN
#
#    base_PsfFlux_instFlux
# 0           -1692.929254

# %%
src4_field
# Out:
#                diaSourceId          diaObjectId          ra        dec  \
# 0      3068394109514285084  3068394109514285084  215.630838 -12.872106
# 1      3068394109514285091  3068394109514285091  215.605865 -12.862209
# 2      3068394109514285097  3068394109514285097  215.600511 -12.857998
# 3      3068394109514285112  3068394109514285112  215.612834 -12.852351
# 4      3068394109514285133  3068394109514285133  215.603055 -12.837839
# ...                    ...                  ...         ...        ...
# 58246  3068394109505896678  3068394109505896678  216.043168 -12.889193
# 58247  3068394109505896679  3068394109505896679  216.040823 -12.884584
# 58248  3068394109505896681  3068394109505896681  215.982984 -12.864661
# 58249  3068394109505896684  3068394109505896684  216.032279 -12.879396
# 58250  3068394109505896685  3068394109505896685  215.951706 -12.852196
#
#           raErr    decErr  midpointMjdTai       psfFlux  psfFluxErr  \
# 0           NaN       NaN     60487.08931  -1946.655640  265.989258
# 1      0.000006  0.000005     60487.08931   9831.191406  490.275330
# 2      0.000005  0.000004     60487.08931  11874.484375  574.258484
# 3      0.000027  0.000021     60487.08931   1254.862061  220.586670
# 4      0.000016  0.000022     60487.08931   1797.926636  223.478989
# ...         ...       ...             ...           ...         ...
# 58246       NaN       NaN     60487.08931  -1556.873657  308.702271
# 58247  0.000009  0.000017     60487.08931   5060.183105  358.326630
# 58248  0.000016  0.000024     60487.08931   2006.866821  282.490417
# 58249       NaN       NaN     60487.08931    501.499268  265.190002
# 58250  0.000011  0.000020     60487.08931   3522.141602  411.112366
#
#          scienceFlux  ...  pixelFlags_saturatedCenter  pixelFlags_suspect  \
# 0       38199.613281  ...                       False               False
# 1      228865.218750  ...                       False               False
# 2      266401.906250  ...                       False               False
# 3        1145.690308  ...                       False               False
# 4        1748.432129  ...                       False               False
# ...              ...  ...                         ...                 ...
# 58246   46690.707031  ...                       False               False
# 58247  122485.781250  ...                       False               False
# 58248   48344.000000  ...                       False               False
# 58249   56084.191406  ...                       False               False
# 58250  188358.718750  ...                       False               False
#
#       pixelFlags_suspectCenter  pixelFlags_streak  pixelFlags_streakCenter  \
# 0                        False              False                    False
# 1                        False              False                    False
# 2                        False              False                    False
# 3                        False              False                    False
# 4                        False              False                    False
# ...                        ...                ...                      ...
# 58246                    False              False                    False
# 58247                    False              False                    False
# 58248                    False              False                    False
# 58249                    False              False                    False
# 58250                    False              False                    False
#
#        pixelFlags_injected  pixelFlags_injectedCenter  \
# 0                    False                      False
# 1                    False                      False
# 2                    False                      False
# 3                    False                      False
# 4                    False                      False
# ...                    ...                        ...
# 58246                False                      False
# 58247                False                      False
# 58248                False                      False
# 58249                False                      False
# 58250                False                      False
#
#        pixelFlags_injected_template  pixelFlags_injected_templateCenter  \
# 0                             False                               False
# 1                             False                               False
# 2                             False                               False
# 3                             False                               False
# 4                             False                               False
# ...                             ...                                 ...
# 58246                         False                               False
# 58247                         False                               False
# 58248                         False                               False
# 58249                         False                               False
# 58250                         False                               False
#
#       reliability
# 0            None
# 1            None
# 2            None
# 3            None
# 4            None
# ...           ...
# 58246        None
# 58247        None
# 58248        None
# 58249        None
# 58250        None
#
# [58251 rows x 55 columns]

# %%
# creating a minimal example
# this is an example where xErr and yErr are NaN, but raErr and decErr are not NaN
import lsst.daf.butler as dafButler

repo = 'embargo_or4'
instrument = 'LSSTComCamSim'
# pp_collections = ['LSSTComCamSim/prompt/output-2024-06-25', 'LSSTComCamSim/prompt/output-2024-06-26', 'LSSTComCamSim/prompt/output-2024-06-27']
pp_collections = 'u/sullii/DM-46333/OR4/association'
pp_butler = dafButler.Butler(repo, collections=pp_collections, instrument=instrument)

data1= {'detector': 3, 'visit': 7024062500190}
src_via_butler = pp_butler.get('goodSeeingDiff_assocDiaSrc', dataId=data1)
forced_src_via_butler = pp_butler.get('goodSeeingDiff_diaForcedSrc', dataId=data1)
src_cand_via_butler = pp_butler.get('goodSeeingDiff_candidateDiaSrc', dataId=data1)
src_prefilter_via_butler = pp_butler.get('goodSeeingDiff_diaSrc', dataId=data1)

3068394109518479458

3068394109518479363
single_butler_src = src_via_butler[src_via_butler['diaSourceId'] == 3068394109518479363]
single_butler_cand_src = src_cand_via_butler[src_cand_via_butler['id'] == 3068394109518479363]
single_butler_prefilter_src = src_prefilter_via_butler[src_prefilter_via_butler['id'] == 3068394109518479363]

single_butler_src[['diaSourceId', 'ra', 'raErr', 'dec', 'decErr', 'x', 'xErr', 'y', 'yErr', 'psfFlux', 'band', 'isDipole', 'centroid_flag', 'apFlux_flag', 'psfFlux_flag', 'forced_PsfFlux_flag', 'shape_flag']]
# Out:
#                                                       diaSourceId          ra  \
# diaObjectId         band diaSourceId
# 3068394109518479363 i    3068394109518479363  3068394109518479363  216.017679
#
#                                                 raErr       dec    decErr  \
# diaObjectId         band diaSourceId
# 3068394109518479363 i    3068394109518479363  0.00001 -12.75408  0.000009
#
#                                                         x  xErr          y  \
# diaObjectId         band diaSourceId
# 3068394109518479363 i    3068394109518479363  2679.237793   NaN  73.829376
#
#                                               yErr      psfFlux band  \
# diaObjectId         band diaSourceId
# 3068394109518479363 i    3068394109518479363   NaN  5689.605469    i
#
#                                               isDipole  centroid_flag  \
# diaObjectId         band diaSourceId
# 3068394109518479363 i    3068394109518479363      True          False
#
#                                               apFlux_flag  psfFlux_flag  \
# diaObjectId         band diaSourceId
# 3068394109518479363 i    3068394109518479363        False         False
#
#                                               forced_PsfFlux_flag  shape_flag
# diaObjectId         band diaSourceId
# 3068394109518479363 i    3068394109518479363                False        True

# %%
forced_src_via_butler[forced_src_via_butler['diaObjectId'] == 3068394109518479363]
# Out:
#                                            diaForcedSourceId  \
# diaObjectId         diaForcedSourceId
# 3068394109518479363 3068394109518479363  3068394109518479363
#
#                                                  diaObjectId          ra  \
# diaObjectId         diaForcedSourceId
# 3068394109518479363 3068394109518479363  3068394109518479363  216.017679
#
#                                               dec          visit  detector  \
# diaObjectId         diaForcedSourceId
# 3068394109518479363 3068394109518479363 -12.75408  7024062500190         3
#
#                                              psfFlux  psfFluxErr  \
# diaObjectId         diaForcedSourceId
# 3068394109518479363 3068394109518479363  5746.184082  695.733582
#
#                                          midpointMjdTai  scienceFlux  \
# diaObjectId         diaForcedSourceId
# 3068394109518479363 3068394109518479363     60487.08931  467585.9375
#
#                                          scienceFluxErr band  \
# diaObjectId         diaForcedSourceId
# 3068394109518479363 3068394109518479363      684.134094    i
#
#                                                  time_processed time_withdrawn
# diaObjectId         diaForcedSourceId
# 3068394109518479363 3068394109518479363 2024-09-18 00:06:05.971            NaT

# %%
config = pp_butler.get('detectAndMeasure_config')
config.toDict()
# Out:
# {'saveLogOutput': True,
#  'doMerge': True,
#  'doForcedMeasurement': True,
#  'doAddMetrics': False,
#  'detection': {'minPixels': 1,
#   'isotropicGrow': True,
#   'combinedGrow': True,
#   'nSigmaToGrow': 2.4,
#   'returnOriginalFootprints': False,
#   'thresholdValue': 5.0,
#   'includeThresholdMultiplier': 1.0,
#   'thresholdType': 'pixel_stdev',
#   'thresholdPolarity': 'both',
#   'adjustBackground': 0.0,
#   'reEstimateBackground': False,
#   'background': {'statisticsProperty': 'MEANCLIP',
#    'undersampleStyle': 'REDUCE_INTERP_ORDER',
#    'binSize': 128,
#    'binSizeX': 0,
#    'binSizeY': 0,
#    'algorithm': 'AKIMA_SPLINE',
#    'ignoredPixelMask': ['BAD',
#     'EDGE',
#     'DETECTED',
#     'DETECTED_NEGATIVE',
#     'NO_DATA'],
#    'isNanSafe': False,
#    'useApprox': True,
#    'approxOrderX': 6,
#    'approxOrderY': -1,
#    'weighting': True},
#   'tempLocalBackground': {'statisticsProperty': 'MEANCLIP',
#    'undersampleStyle': 'REDUCE_INTERP_ORDER',
#    'binSize': 64,
#    'binSizeX': 0,
#    'binSizeY': 0,
#    'algorithm': 'AKIMA_SPLINE',
#    'ignoredPixelMask': ['BAD',
#     'EDGE',
#     'DETECTED',
#     'DETECTED_NEGATIVE',
#     'NO_DATA'],
#    'isNanSafe': False,
#    'useApprox': False,
#    'approxOrderX': 6,
#    'approxOrderY': -1,
#    'weighting': True},
#   'doTempLocalBackground': True,
#   'tempWideBackground': {'statisticsProperty': 'MEANCLIP',
#    'undersampleStyle': 'REDUCE_INTERP_ORDER',
#    'binSize': 512,
#    'binSizeX': 0,
#    'binSizeY': 0,
#    'algorithm': 'AKIMA_SPLINE',
#    'ignoredPixelMask': ['BAD', 'EDGE', 'NO_DATA'],
#    'isNanSafe': False,
#    'useApprox': False,
#    'approxOrderX': 6,
#    'approxOrderY': -1,
#    'weighting': True},
#   'doTempWideBackground': False,
#   'nPeaksMaxSimple': 1,
#   'nSigmaForKernel': 7.0,
#   'statsMask': ['BAD', 'SAT', 'EDGE', 'NO_DATA'],
#   'excludeMaskPlanes': ['EDGE', 'SAT', 'BAD', 'INTRP']},
#  'deblend': {'edgeHandling': 'ramp',
#   'strayFluxToPointSources': 'necessary',
#   'assignStrayFlux': True,
#   'strayFluxRule': 'trim',
#   'clipStrayFluxFraction': 0.001,
#   'psfChisq1': 1.5,
#   'psfChisq2': 1.5,
#   'psfChisq2b': 1.5,
#   'maxNumberOfPeaks': 0,
#   'maxFootprintArea': 10000,
#   'maxFootprintSize': 0,
#   'minFootprintAxisRatio': 0.0,
#   'notDeblendedMask': 'NOT_DEBLENDED',
#   'tinyFootprintSize': 2,
#   'propagateAllPeaks': False,
#   'catchFailures': True,
#   'maskPlanes': ['SAT', 'INTRP', 'NO_DATA'],
#   'maskLimits': {'NO_DATA': 0.25},
#   'weightTemplates': False,
#   'removeDegenerateTemplates': False,
#   'maxTempDotProd': 0.5,
#   'medianSmoothTemplate': True,
#   'useCiLimits': False,
#   'ciDeblendChildRange': [2, 10],
#   'ciNumParentsToDeblend': 10},
#  'measurement': {'slots': {'centroid': 'base_SdssCentroid',
#    'shape': 'ext_shapeHSM_HsmSourceMoments',
#    'psfShape': 'ext_shapeHSM_HsmPsfMoments',
#    'apFlux': 'base_CircularApertureFlux_12_0',
#    'modelFlux': None,
#    'psfFlux': 'base_PsfFlux',
#    'gaussianFlux': None,
#    'calibFlux': None},
#   'doReplaceWithNoise': False,
#   'noiseReplacer': {'noiseSource': 'measure',
#    'noiseOffset': 0.0,
#    'noiseSeedMultiplier': 1},
#   'undeblendedPrefix': 'undeblended_',
#   'plugins': {'names': ['base_LocalPhotoCalib', 'ext_shapeHSM_HsmPsfMoments', 'base_CircularApertureFlux', 'base_PixelFlags', 'base_PsfFlux', 'base_LocalWcs', 'ext_shapeHSM_HsmSourceMoments', 'ext_trailedSources_Naive', 'base_SkyCoord', 'base_SdssCentroid', 'ip_diffim_DipoleFit'],
#    'values': {'base_PsfFlux': {'doMeasure': True, 'badMaskPlanes': []},
#     'base_PeakLikelihoodFlux': {'doMeasure': True,
#      'warpingKernelName': 'lanczos4'},
#     'base_GaussianFlux': {'doMeasure': True, 'background': 0.0},
#     'base_NaiveCentroid': {'doMeasure': True,
#      'background': 0.0,
#      'doFootprintCheck': True,
#      'maxDistToPeak': 5.0},
#     'base_SdssCentroid': {'doMeasure': True,
#      'binmax': 16,
#      'doFootprintCheck': True,
#      'maxDistToPeak': 5.0,
#      'peakMin': -1.0,
#      'wfac': 1.5},
#     'base_PixelFlags': {'doMeasure': True,
#      'masksFpAnywhere': ['STREAK', 'INJECTED', 'INJECTED_TEMPLATE'],
#      'masksFpCenter': ['STREAK', 'INJECTED', 'INJECTED_TEMPLATE']},
#     'base_SdssShape': {'doMeasure': True,
#      'background': 0.0,
#      'doMeasurePsf': True,
#      'maxIter': 100,
#      'maxShift': 0.0,
#      'tol1': 9.999999747378752e-06,
#      'tol2': 9.999999747378752e-05},
#     'base_ScaledApertureFlux': {'doMeasure': True,
#      'scale': 3.14,
#      'shiftKernel': 'lanczos5'},
#     'base_CircularApertureFlux': {'doMeasure': True,
#      'maxSincRadius': 10.0,
#      'radii': [12.0],
#      'shiftKernel': 'lanczos5'},
#     'base_Blendedness': {'doMeasure': True,
#      'doFlux': True,
#      'doOld': True,
#      'doShape': True,
#      'nSigmaWeightMax': 3.0},
#     'base_LocalBackground': {'doMeasure': True,
#      'annulusInner': 7.0,
#      'annulusOuter': 15.0,
#      'badMaskPlanes': ['BAD', 'SAT', 'NO_DATA'],
#      'bgIter': 3,
#      'bgRej': 3.0},
#     'base_FPPosition': {'doMeasure': True},
#     'base_Jacobian': {'doMeasure': True, 'pixelScale': 0.5},
#     'base_Variance': {'doMeasure': True,
#      'scale': 5.0,
#      'mask': ['DETECTED', 'DETECTED_NEGATIVE', 'BAD', 'SAT']},
#     'base_InputCount': {'doMeasure': True},
#     'base_LocalPhotoCalib': {'doMeasure': True},
#     'base_LocalWcs': {'doMeasure': True},
#     'base_PeakCentroid': {'doMeasure': True},
#     'base_SkyCoord': {'doMeasure': True},
#     'base_ClassificationSizeExtendedness': {'doMeasure': True,
#      'exponent': 0.5},
#     'base_CompensatedGaussianFlux': {'doMeasure': True,
#      'kernel_widths': [3, 5],
#      't': 2.0},
#     'base_CompensatedTophatFlux': {'doMeasure': True,
#      'apertures': [12],
#      'inner_scale': 1.0,
#      'outer_scale': 1.7},
#     'ip_diffim_DipoleFit': {'doMeasure': True,
#      'fitAllDiaSources': False,
#      'maxSeparation': 5.0,
#      'relWeight': 0.5,
#      'tolerance': 1e-07,
#      'fitBackground': 1,
#      'fitSeparateNegParams': False,
#      'minSn': 7.0710678118654755,
#      'maxFluxRatio': 0.65,
#      'maxChi2DoF': 0.05,
#      'maxFootprintArea': 1200},
#     'ip_diffim_ClassificationDipole': {'doMeasure': True,
#      'minSn': 7.0710678118654755,
#      'maxFluxRatio': 0.65},
#     'ext_trailedSources_Naive': {'doMeasure': True, 'maxFlux': 10000000000.0},
#     'ext_trailedSources_Veres': {'doMeasure': True,
#      'optimizerMethod': 'L-BFGS-B'},
#     'ext_shapeHSM_HigherOrderMomentsSource': {'doMeasure': True,
#      'min_order': 3,
#      'max_order': 4,
#      'badMaskPlanes': ['BAD', 'SAT'],
#      'setMaskedPixelsToZero': False},
#     'ext_shapeHSM_HigherOrderMomentsPSF': {'doMeasure': True,
#      'min_order': 3,
#      'max_order': 4,
#      'useSourceCentroidOffset': False},
#     'ext_shapeHSM_HsmSourceMoments': {'doMeasure': True,
#      'roundMoments': False,
#      'addFlux': False,
#      'subtractCenter': False,
#      'badMaskPlanes': ['BAD', 'SAT']},
#     'ext_shapeHSM_HsmSourceMomentsRound': {'doMeasure': True,
#      'roundMoments': True,
#      'addFlux': False,
#      'subtractCenter': False,
#      'badMaskPlanes': ['BAD', 'SAT']},
#     'ext_shapeHSM_HsmPsfMoments': {'doMeasure': True,
#      'roundMoments': False,
#      'addFlux': False,
#      'subtractCenter': True,
#      'useSourceCentroidOffset': False},
#     'ext_shapeHSM_HsmPsfMomentsDebiased': {'doMeasure': True,
#      'roundMoments': False,
#      'addFlux': False,
#      'subtractCenter': True,
#      'useSourceCentroidOffset': True,
#      'noiseSource': 'variance',
#      'seedOffset': 0,
#      'badMaskPlanes': ['BAD', 'SAT']},
#     'ext_shapeHSM_HsmShapeBj': {'doMeasure': True,
#      'deblendNChild': '',
#      'badMaskPlanes': ['BAD', 'SAT']},
#     'ext_shapeHSM_HsmShapeLinear': {'doMeasure': True,
#      'deblendNChild': '',
#      'badMaskPlanes': ['BAD', 'SAT']},
#     'ext_shapeHSM_HsmShapeKsb': {'doMeasure': True,
#      'deblendNChild': '',
#      'badMaskPlanes': ['BAD', 'SAT']},
#     'ext_shapeHSM_HsmShapeRegauss': {'doMeasure': True,
#      'deblendNChild': '',
#      'badMaskPlanes': ['BAD', 'SAT']},
#     'ip_diffim_NaiveDipoleCentroid': {'doMeasure': True},
#     'ip_diffim_NaiveDipoleFlux': {'doMeasure': True},
#     'ip_diffim_PsfDipoleFlux': {'doMeasure': True,
#      'errorDef': 1.0,
#      'maxFnCalls': 100000,
#      'stepSizeCoord': 0.10000000149011612,
#      'stepSizeFlux': 1.0}}},
#   'undeblended': {'names': [],
#    'values': {'base_PsfFlux': {'doMeasure': True, 'badMaskPlanes': []},
#     'base_PeakLikelihoodFlux': {'doMeasure': True,
#      'warpingKernelName': 'lanczos4'},
#     'base_GaussianFlux': {'doMeasure': True, 'background': 0.0},
#     'base_NaiveCentroid': {'doMeasure': True,
#      'background': 0.0,
#      'doFootprintCheck': True,
#      'maxDistToPeak': 5.0},
#     'base_SdssCentroid': {'doMeasure': True,
#      'binmax': 16,
#      'doFootprintCheck': True,
#      'maxDistToPeak': 1.0,
#      'peakMin': -1.0,
#      'wfac': 1.5},
#     'base_PixelFlags': {'doMeasure': True,
#      'masksFpAnywhere': [],
#      'masksFpCenter': []},
#     'base_SdssShape': {'doMeasure': True,
#      'background': 0.0,
#      'doMeasurePsf': True,
#      'maxIter': 100,
#      'maxShift': 0.0,
#      'tol1': 9.999999747378752e-06,
#      'tol2': 9.999999747378752e-05},
#     'base_ScaledApertureFlux': {'doMeasure': True,
#      'scale': 3.14,
#      'shiftKernel': 'lanczos5'},
#     'base_CircularApertureFlux': {'doMeasure': True,
#      'maxSincRadius': 10.0,
#      'radii': [3.0, 4.5, 6.0, 9.0, 12.0, 17.0, 25.0, 35.0, 50.0, 70.0],
#      'shiftKernel': 'lanczos5'},
#     'base_Blendedness': {'doMeasure': True,
#      'doFlux': True,
#      'doOld': True,
#      'doShape': True,
#      'nSigmaWeightMax': 3.0},
#     'base_LocalBackground': {'doMeasure': True,
#      'annulusInner': 7.0,
#      'annulusOuter': 15.0,
#      'badMaskPlanes': ['BAD', 'SAT', 'NO_DATA'],
#      'bgIter': 3,
#      'bgRej': 3.0},
#     'base_FPPosition': {'doMeasure': True},
#     'base_Jacobian': {'doMeasure': True, 'pixelScale': 0.5},
#     'base_Variance': {'doMeasure': True,
#      'scale': 5.0,
#      'mask': ['DETECTED', 'DETECTED_NEGATIVE', 'BAD', 'SAT']},
#     'base_InputCount': {'doMeasure': True},
#     'base_LocalPhotoCalib': {'doMeasure': True},
#     'base_LocalWcs': {'doMeasure': True},
#     'base_PeakCentroid': {'doMeasure': True},
#     'base_SkyCoord': {'doMeasure': True},
#     'base_ClassificationSizeExtendedness': {'doMeasure': True,
#      'exponent': 0.5},
#     'base_CompensatedGaussianFlux': {'doMeasure': True,
#      'kernel_widths': [3, 5],
#      't': 2.0},
#     'base_CompensatedTophatFlux': {'doMeasure': True,
#      'apertures': [12],
#      'inner_scale': 1.0,
#      'outer_scale': 1.7},
#     'ip_diffim_DipoleFit': {'doMeasure': True,
#      'fitAllDiaSources': False,
#      'maxSeparation': 5.0,
#      'relWeight': 0.5,
#      'tolerance': 1e-07,
#      'fitBackground': 1,
#      'fitSeparateNegParams': False,
#      'minSn': 7.0710678118654755,
#      'maxFluxRatio': 0.65,
#      'maxChi2DoF': 0.05,
#      'maxFootprintArea': 1200},
#     'ip_diffim_ClassificationDipole': {'doMeasure': True,
#      'minSn': 7.0710678118654755,
#      'maxFluxRatio': 0.65},
#     'ext_trailedSources_Naive': {'doMeasure': True, 'maxFlux': 10000000000.0},
#     'ext_trailedSources_Veres': {'doMeasure': True,
#      'optimizerMethod': 'L-BFGS-B'},
#     'ext_shapeHSM_HigherOrderMomentsSource': {'doMeasure': True,
#      'min_order': 3,
#      'max_order': 4,
#      'badMaskPlanes': ['BAD', 'SAT'],
#      'setMaskedPixelsToZero': False},
#     'ext_shapeHSM_HigherOrderMomentsPSF': {'doMeasure': True,
#      'min_order': 3,
#      'max_order': 4,
#      'useSourceCentroidOffset': False},
#     'ext_shapeHSM_HsmSourceMoments': {'doMeasure': True,
#      'roundMoments': False,
#      'addFlux': False,
#      'subtractCenter': False,
#      'badMaskPlanes': ['BAD', 'SAT']},
#     'ext_shapeHSM_HsmSourceMomentsRound': {'doMeasure': True,
#      'roundMoments': True,
#      'addFlux': False,
#      'subtractCenter': False,
#      'badMaskPlanes': ['BAD', 'SAT']},
#     'ext_shapeHSM_HsmPsfMoments': {'doMeasure': True,
#      'roundMoments': False,
#      'addFlux': False,
#      'subtractCenter': True,
#      'useSourceCentroidOffset': False},
#     'ext_shapeHSM_HsmPsfMomentsDebiased': {'doMeasure': True,
#      'roundMoments': False,
#      'addFlux': False,
#      'subtractCenter': True,
#      'useSourceCentroidOffset': True,
#      'noiseSource': 'variance',
#      'seedOffset': 0,
#      'badMaskPlanes': ['BAD', 'SAT']},
#     'ext_shapeHSM_HsmShapeBj': {'doMeasure': True,
#      'deblendNChild': '',
#      'badMaskPlanes': ['BAD', 'SAT']},
#     'ext_shapeHSM_HsmShapeLinear': {'doMeasure': True,
#      'deblendNChild': '',
#      'badMaskPlanes': ['BAD', 'SAT']},
#     'ext_shapeHSM_HsmShapeKsb': {'doMeasure': True,
#      'deblendNChild': '',
#      'badMaskPlanes': ['BAD', 'SAT']},
#     'ext_shapeHSM_HsmShapeRegauss': {'doMeasure': True,
#      'deblendNChild': '',
#      'badMaskPlanes': ['BAD', 'SAT']},
#     'ip_diffim_NaiveDipoleCentroid': {'doMeasure': True},
#     'ip_diffim_NaiveDipoleFlux': {'doMeasure': True},
#     'ip_diffim_PsfDipoleFlux': {'doMeasure': True,
#      'errorDef': 1.0,
#      'maxFnCalls': 100000,
#      'stepSizeCoord': 0.10000000149011612,
#      'stepSizeFlux': 1.0}}}},
#  'doApCorr': True,
#  'applyApCorr': {'ignoreList': [],
#   'doFlagApCorrFailures': True,
#   'proxies': {}},
#  'forcedMeasurement': {'slots': {'centroid': 'base_TransformedCentroid',
#    'shape': None,
#    'psfShape': 'base_SdssShape_psf',
#    'apFlux': None,
#    'modelFlux': None,
#    'psfFlux': None,
#    'gaussianFlux': None,
#    'calibFlux': None},
#   'doReplaceWithNoise': True,
#   'noiseReplacer': {'noiseSource': 'measure',
#    'noiseOffset': 0.0,
#    'noiseSeedMultiplier': 1},
#   'undeblendedPrefix': 'undeblended_',
#   'plugins': {'names': ['base_TransformedCentroid', 'base_PsfFlux'],
#    'values': {'base_PsfFlux': {'doMeasure': True, 'badMaskPlanes': []},
#     'base_PeakLikelihoodFlux': {'doMeasure': True,
#      'warpingKernelName': 'lanczos4'},
#     'base_GaussianFlux': {'doMeasure': True, 'background': 0.0},
#     'base_NaiveCentroid': {'doMeasure': True,
#      'background': 0.0,
#      'doFootprintCheck': True,
#      'maxDistToPeak': 5.0},
#     'base_SdssCentroid': {'doMeasure': True,
#      'binmax': 16,
#      'doFootprintCheck': True,
#      'maxDistToPeak': 1.0,
#      'peakMin': -1.0,
#      'wfac': 1.5},
#     'base_PixelFlags': {'doMeasure': True,
#      'masksFpAnywhere': [],
#      'masksFpCenter': []},
#     'base_SdssShape': {'doMeasure': True,
#      'background': 0.0,
#      'doMeasurePsf': True,
#      'maxIter': 100,
#      'maxShift': 0.0,
#      'tol1': 9.999999747378752e-06,
#      'tol2': 9.999999747378752e-05},
#     'base_ScaledApertureFlux': {'doMeasure': True,
#      'scale': 3.14,
#      'shiftKernel': 'lanczos5'},
#     'base_CircularApertureFlux': {'doMeasure': True,
#      'maxSincRadius': 10.0,
#      'radii': [3.0, 4.5, 6.0, 9.0, 12.0, 17.0, 25.0, 35.0, 50.0, 70.0],
#      'shiftKernel': 'lanczos5'},
#     'base_Blendedness': {'doMeasure': True,
#      'doFlux': True,
#      'doOld': True,
#      'doShape': True,
#      'nSigmaWeightMax': 3.0},
#     'base_LocalBackground': {'doMeasure': True,
#      'annulusInner': 7.0,
#      'annulusOuter': 15.0,
#      'badMaskPlanes': ['BAD', 'SAT', 'NO_DATA'],
#      'bgIter': 3,
#      'bgRej': 3.0},
#     'base_Variance': {'doMeasure': True,
#      'scale': 5.0,
#      'mask': ['DETECTED', 'DETECTED_NEGATIVE', 'BAD', 'SAT']},
#     'base_InputCount': {'doMeasure': True},
#     'base_LocalPhotoCalib': {'doMeasure': True},
#     'base_LocalWcs': {'doMeasure': True},
#     'base_PeakCentroid': {'doMeasure': True},
#     'base_TransformedCentroid': {'doMeasure': True},
#     'base_TransformedCentroidFromCoord': {'doMeasure': True},
#     'base_TransformedShape': {'doMeasure': True},
#     'ip_diffim_NaiveDipoleCentroid': {'doMeasure': True},
#     'ip_diffim_NaiveDipoleFlux': {'doMeasure': True},
#     'ip_diffim_PsfDipoleFlux': {'doMeasure': True,
#      'errorDef': 1.0,
#      'maxFnCalls': 100000,
#      'stepSizeCoord': 0.10000000149011612,
#      'stepSizeFlux': 1.0}}},
#   'undeblended': {'names': [],
#    'values': {'base_PsfFlux': {'doMeasure': True, 'badMaskPlanes': []},
#     'base_PeakLikelihoodFlux': {'doMeasure': True,
#      'warpingKernelName': 'lanczos4'},
#     'base_GaussianFlux': {'doMeasure': True, 'background': 0.0},
#     'base_NaiveCentroid': {'doMeasure': True,
#      'background': 0.0,
#      'doFootprintCheck': True,
#      'maxDistToPeak': 5.0},
#     'base_SdssCentroid': {'doMeasure': True,
#      'binmax': 16,
#      'doFootprintCheck': True,
#      'maxDistToPeak': 1.0,
#      'peakMin': -1.0,
#      'wfac': 1.5},
#     'base_PixelFlags': {'doMeasure': True,
#      'masksFpAnywhere': [],
#      'masksFpCenter': []},
#     'base_SdssShape': {'doMeasure': True,
#      'background': 0.0,
#      'doMeasurePsf': True,
#      'maxIter': 100,
#      'maxShift': 0.0,
#      'tol1': 9.999999747378752e-06,
#      'tol2': 9.999999747378752e-05},
#     'base_ScaledApertureFlux': {'doMeasure': True,
#      'scale': 3.14,
#      'shiftKernel': 'lanczos5'},
#     'base_CircularApertureFlux': {'doMeasure': True,
#      'maxSincRadius': 10.0,
#      'radii': [3.0, 4.5, 6.0, 9.0, 12.0, 17.0, 25.0, 35.0, 50.0, 70.0],
#      'shiftKernel': 'lanczos5'},
#     'base_Blendedness': {'doMeasure': True,
#      'doFlux': True,
#      'doOld': True,
#      'doShape': True,
#      'nSigmaWeightMax': 3.0},
#     'base_LocalBackground': {'doMeasure': True,
#      'annulusInner': 7.0,
#      'annulusOuter': 15.0,
#      'badMaskPlanes': ['BAD', 'SAT', 'NO_DATA'],
#      'bgIter': 3,
#      'bgRej': 3.0},
#     'base_Variance': {'doMeasure': True,
#      'scale': 5.0,
#      'mask': ['DETECTED', 'DETECTED_NEGATIVE', 'BAD', 'SAT']},
#     'base_InputCount': {'doMeasure': True},
#     'base_LocalPhotoCalib': {'doMeasure': True},
#     'base_LocalWcs': {'doMeasure': True},
#     'base_PeakCentroid': {'doMeasure': True},
#     'base_TransformedCentroid': {'doMeasure': True},
#     'base_TransformedCentroidFromCoord': {'doMeasure': True},
#     'base_TransformedShape': {'doMeasure': True},
#     'ip_diffim_NaiveDipoleCentroid': {'doMeasure': True},
#     'ip_diffim_NaiveDipoleFlux': {'doMeasure': True},
#     'ip_diffim_PsfDipoleFlux': {'doMeasure': True,
#      'errorDef': 1.0,
#      'maxFnCalls': 100000,
#      'stepSizeCoord': 0.10000000149011612,
#      'stepSizeFlux': 1.0}}},
#   'copyColumns': {'id': 'objectId',
#    'parent': 'parentObjectId',
#    'coord_ra': 'coord_ra',
#    'coord_dec': 'coord_dec'},
#   'checkUnitsParseStrict': 'raise'},
#  'growFootprint': 2,
#  'diaSourceMatchRadius': 0.5,
#  'doSkySources': True,
#  'skySources': {'avoidMask': ['DETECTED',
#    'DETECTED_NEGATIVE',
#    'BAD',
#    'NO_DATA',
#    'EDGE'],
#   'growMask': 0,
#   'sourceRadius': 8.0,
#   'nSources': 100,
#   'nTrialSources': None,
#   'nTrialSourcesMultiplier': 5},
#  'doMaskStreaks': True,
#  'maskStreaks': {'minimumKernelHeight': 0.0,
#   'absMinimumKernelHeight': 5.0,
#   'clusterMinimumSize': 50,
#   'clusterMinimumDeviation': 2,
#   'delta': 0.2,
#   'nSigma': 2.0,
#   'rhoBinSize': 30.0,
#   'thetaBinSize': 2.0,
#   'invSigma': 0.1,
#   'footprintThreshold': 0.01,
#   'dChi2Tolerance': 0.1,
#   'detectedMaskPlane': 'DETECTED',
#   'onlyMaskDetected': False,
#   'streaksMaskPlane': 'STREAK',
#   'badMaskPlanes': ['NO_DATA', 'INTRP', 'BAD', 'SAT', 'EDGE']},
#  'writeStreakInfo': False,
#  'setPrimaryFlags': {'pseudoFilterList': ['sky']},
#  'badSourceFlags': ['base_PixelFlags_flag_offimage',
#   'base_PixelFlags_flag_interpolatedCenterAll',
#   'base_PixelFlags_flag_badCenterAll',
#   'base_PixelFlags_flag_edgeCenterAll',
#   'base_PixelFlags_flag_saturatedCenterAll'],
#  'idGenerator': {'release_id': 0,
#   'n_releases': 1,
#   'packer': {'name': None,
#    'values': {'observation': {'n_detectors': None, 'n_observations': None},
#     'rubin': {'controllers': {'O': 0, 'C': 1, 'H': 2, 'P': 3, 'Q': 4, 'S': 5},
#      'n_controllers': 8,
#      'n_visit_definitions': 2,
#      'n_days': 16384,
#      'n_seq_nums': 32768,
#      'n_detectors': 256,
#      'day_obs_begin': 20100101}}}},
#  'connections': {'science': 'initial_pvi',
#   'matchedTemplate': '{fakesType}{coaddName}Diff_matchedExp',
#   'difference': '{fakesType}{coaddName}Diff_differenceTempExp',
#   'outputSchema': '{fakesType}{coaddName}Diff_diaSrc_schema',
#   'diaSources': '{fakesType}{coaddName}Diff_diaSrc',
#   'subtractedMeasuredExposure': '{fakesType}{coaddName}Diff_differenceExp',
#   'maskedStreaks': '{fakesType}{coaddName}Diff_streaks',
#   'coaddName': 'goodSeeing',
#   'warpTypeSuffix': '',
#   'fakesType': ''}}

# %%
single_butler_prefilter_src[0]
# Out:
# <class 'lsst.afw.table.SourceRecord'>
# id: 3068394109518479363
# coord_ra: 3.77022 rad
# coord_dec: -0.222601 rad
# parent: 0
# coord_raErr: 1.66289e-07
# coord_decErr: 1.63613e-07
# coord_ra_dec_Cov: -8.31726e-16
# flags_negative: 0
# deblend_nChild: 0
# deblend_deblendedAsPsf: 0
# deblend_psfCenter_x: nan
# deblend_psfCenter_y: nan
# deblend_psf_instFlux: nan
# deblend_tooManyPeaks: 0
# deblend_parentTooBig: 0
# deblend_masked: 0
# deblend_failed: 0
# deblend_skipped: 0
# deblend_rampedTemplate: 0
# deblend_patchedTemplate: 0
# deblend_hasStrayFlux: 0
# deblend_peak_center_x: 0
# deblend_peak_center_y: 0
# deblend_peakId: 0
# deblend_nPeaks: 0
# deblend_parentNPeaks: 0
# detect_isPrimary: 0
# detect_isDeblendedSource: 0
# detect_fromBlend: 0
# detect_isIsolated: 0
# base_SdssCentroid_x: 2678.79
# base_SdssCentroid_y: 72.6395
# base_SdssCentroid_xErr: 0.176473
# base_SdssCentroid_yErr: 0.167678
# base_SdssCentroid_flag: 0
# base_SdssCentroid_flag_edge: 0
# base_SdssCentroid_flag_noSecondDerivative: 0
# base_SdssCentroid_flag_almostNoSecondDerivative: 0
# base_SdssCentroid_flag_notAtMaximum: 0
# base_SdssCentroid_flag_near_edge: 0
# base_SdssCentroid_flag_resetToPeak: 0
# base_SdssCentroid_flag_badError: 0
# ip_diffim_DipoleFit_pos_instFlux: 540894
# ip_diffim_DipoleFit_pos_instFluxErr: 5305.44
# ip_diffim_DipoleFit_neg_instFlux: -540894
# ip_diffim_DipoleFit_neg_instFluxErr: 5305.44
# ip_diffim_DipoleFit_instFlux: 540894
# ip_diffim_DipoleFit_instFluxErr: nan
# ip_diffim_DipoleFit_pos_x: 2679.23
# ip_diffim_DipoleFit_pos_y: 73.819
# ip_diffim_DipoleFit_neg_x: 2679.24
# ip_diffim_DipoleFit_neg_y: 73.8397
# ip_diffim_DipoleFit_x: 2679.24
# ip_diffim_DipoleFit_y: 73.8294
# ip_diffim_DipoleFit_xErr: nan
# ip_diffim_DipoleFit_yErr: nan
# ip_diffim_DipoleFit_orientation: -1.91144
# ip_diffim_DipoleFit_separation: 0.0219457
# ip_diffim_DipoleFit_chi2dof: 3630.29
# ip_diffim_DipoleFit_nData: 1200
# ip_diffim_DipoleFit_signalToNoise: 5305.44
# ip_diffim_DipoleFit_flag_classification: 1
# ip_diffim_DipoleFit_flag_classificationAttempted: 1
# ip_diffim_DipoleFit_flag: 0
# ip_diffim_DipoleFit_flag_edge: 0
# ext_shapeHSM_HsmPsfMoments_flag: 0
# ext_shapeHSM_HsmPsfMoments_flag_no_pixels: 0
# ext_shapeHSM_HsmPsfMoments_flag_not_contained: 0
# ext_shapeHSM_HsmPsfMoments_flag_parent_source: 0
# ext_shapeHSM_HsmPsfMoments_flag_galsim: 0
# ext_shapeHSM_HsmPsfMoments_flag_invalid_param: 0
# ext_shapeHSM_HsmPsfMoments_flag_edge: 0
# ext_shapeHSM_HsmPsfMoments_flag_no_psf: 0
# ext_shapeHSM_HsmPsfMoments_x: -0.00023008
# ext_shapeHSM_HsmPsfMoments_y: -0.000276243
# ext_shapeHSM_HsmPsfMoments_xx: 2.43921
# ext_shapeHSM_HsmPsfMoments_yy: 2.4084
# ext_shapeHSM_HsmPsfMoments_xy: -0.00320421
# ext_shapeHSM_HsmSourceMoments_flag: 1
# ext_shapeHSM_HsmSourceMoments_flag_no_pixels: 0
# ext_shapeHSM_HsmSourceMoments_flag_not_contained: 0
# ext_shapeHSM_HsmSourceMoments_flag_parent_source: 0
# ext_shapeHSM_HsmSourceMoments_flag_galsim: 0
# ext_shapeHSM_HsmSourceMoments_flag_invalid_param: 0
# ext_shapeHSM_HsmSourceMoments_flag_edge: 0
# ext_shapeHSM_HsmSourceMoments_flag_no_psf: 0
# ext_shapeHSM_HsmSourceMoments_x: nan
# ext_shapeHSM_HsmSourceMoments_y: nan
# ext_shapeHSM_HsmSourceMoments_xx: nan
# ext_shapeHSM_HsmSourceMoments_yy: nan
# ext_shapeHSM_HsmSourceMoments_xy: nan
# base_CircularApertureFlux_12_0_instFlux: 192.089
# base_CircularApertureFlux_12_0_instFluxErr: 946.03
# base_CircularApertureFlux_12_0_flag: 0
# base_CircularApertureFlux_12_0_flag_apertureTruncated: 0
# base_LocalPhotoCalib_flag: 0
# base_LocalPhotoCalib: 1
# base_LocalPhotoCalibErr: 0.000214111
# base_LocalWcs_flag: 0
# base_LocalWcs_CDMatrix_1_1: -9.22668e-07
# base_LocalWcs_CDMatrix_1_2: 3.01533e-07
# base_LocalWcs_CDMatrix_2_1: 3.01879e-07
# base_LocalWcs_CDMatrix_2_2: 9.2258e-07
# base_PixelFlags_flag: 0
# base_PixelFlags_flag_offimage: 0
# base_PixelFlags_flag_edge: 0
# base_PixelFlags_flag_interpolated: 0
# base_PixelFlags_flag_saturated: 0
# base_PixelFlags_flag_cr: 0
# base_PixelFlags_flag_bad: 0
# base_PixelFlags_flag_suspect: 0
# base_PixelFlags_flag_edgeCenter: 0
# base_PixelFlags_flag_interpolatedCenter: 0
# base_PixelFlags_flag_saturatedCenter: 0
# base_PixelFlags_flag_crCenter: 0
# base_PixelFlags_flag_badCenter: 0
# base_PixelFlags_flag_suspectCenter: 0
# base_PixelFlags_flag_edgeCenterAll: 0
# base_PixelFlags_flag_interpolatedCenterAll: 0
# base_PixelFlags_flag_saturatedCenterAll: 0
# base_PixelFlags_flag_crCenterAll: 0
# base_PixelFlags_flag_badCenterAll: 0
# base_PixelFlags_flag_suspectCenterAll: 0
# base_PixelFlags_flag_streakCenter: 0
# base_PixelFlags_flag_injectedCenter: 0
# base_PixelFlags_flag_injected_templateCenter: 0
# base_PixelFlags_flag_streakCenterAll: 0
# base_PixelFlags_flag_injectedCenterAll: 0
# base_PixelFlags_flag_injected_templateCenterAll: 0
# base_PixelFlags_flag_streak: 0
# base_PixelFlags_flag_injected: 0
# base_PixelFlags_flag_injected_template: 0
# base_PsfFlux_instFlux: 5689.61
# base_PsfFlux_instFluxErr: 688.882
# base_PsfFlux_area: 38.0865
# base_PsfFlux_chi2: 2089.69
# base_PsfFlux_npixels: 1681
# base_PsfFlux_flag: 0
# base_PsfFlux_flag_noGoodPixels: 0
# base_PsfFlux_flag_edge: 0
# ext_trailedSources_Naive_ra: nan
# ext_trailedSources_Naive_dec: nan
# ext_trailedSources_Naive_x0: nan
# ext_trailedSources_Naive_y0: nan
# ext_trailedSources_Naive_x1: nan
# ext_trailedSources_Naive_y1: nan
# ext_trailedSources_Naive_flux: nan
# ext_trailedSources_Naive_length: nan
# ext_trailedSources_Naive_angle: nan
# ext_trailedSources_Naive_x0Err: nan
# ext_trailedSources_Naive_y0Err: nan
# ext_trailedSources_Naive_x1Err: nan
# ext_trailedSources_Naive_y1Err: nan
# ext_trailedSources_Naive_fluxErr: nan
# ext_trailedSources_Naive_lengthErr: nan
# ext_trailedSources_Naive_angleErr: nan
# ext_trailedSources_Naive_flag: 1
# ext_trailedSources_Naive_flag_noFlux: 0
# ext_trailedSources_Naive_flag_noConverge: 0
# ext_trailedSources_Naive_flag_noSigma: 0
# ext_trailedSources_Naive_flag_edge: 0
# ext_trailedSources_Naive_flag_off_image: 0
# ext_trailedSources_Naive_flag_nan: 0
# ext_trailedSources_Naive_flag_suspect_long_trail: 0
# ext_trailedSources_Naive_flag_shape: 1
# base_InvalidPsf_flag: 0
# base_PsfFlux_apCorr: 0.990154
# base_PsfFlux_apCorrErr: 0
# base_PsfFlux_flag_apCorr: 0
# ip_diffim_forced_PsfFlux_instFlux: 467585
# ip_diffim_forced_PsfFlux_instFluxErr: 676.769
# ip_diffim_forced_PsfFlux_area: 38.6546
# ip_diffim_forced_PsfFlux_flag: 0
# ip_diffim_forced_PsfFlux_flag_noGoodPixels: 0
# ip_diffim_forced_PsfFlux_flag_edge: 0
# refMatchId: 0
# srcMatchId: 0
# sky_source: 0

# %%
src_via_butler[src_via_butler['isDipole']==True]
# Out:
#                                                       diaSourceId  \
# diaObjectId         band diaSourceId
# 3068394109518479363 i    3068394109518479363  3068394109518479363
# 3068394109518479365 i    3068394109518479365  3068394109518479365
# 3068394109518479370 i    3068394109518479370  3068394109518479370
# 3068394109518479378 i    3068394109518479378  3068394109518479378
# 3068394109518479387 i    3068394109518479387  3068394109518479387
# ...                                                           ...
# 3068394109518479610 i    3068394109518479610  3068394109518479610
# 3068394109518479613 i    3068394109518479613  3068394109518479613
# 3068394109518479614 i    3068394109518479614  3068394109518479614
# 3068394109518479616 i    3068394109518479616  3068394109518479616
# 3068394109518479617 i    3068394109518479617  3068394109518479617
#
#                                                       visit  detector  \
# diaObjectId         band diaSourceId
# 3068394109518479363 i    3068394109518479363  7024062500190         3
# 3068394109518479365 i    3068394109518479365  7024062500190         3
# 3068394109518479370 i    3068394109518479370  7024062500190         3
# 3068394109518479378 i    3068394109518479378  7024062500190         3
# 3068394109518479387 i    3068394109518479387  7024062500190         3
# ...                                                     ...       ...
# 3068394109518479610 i    3068394109518479610  7024062500190         3
# 3068394109518479613 i    3068394109518479613  7024062500190         3
# 3068394109518479614 i    3068394109518479614  7024062500190         3
# 3068394109518479616 i    3068394109518479616  7024062500190         3
# 3068394109518479617 i    3068394109518479617  7024062500190         3
#
#                                                       diaObjectId  ssObjectId  \
# diaObjectId         band diaSourceId
# 3068394109518479363 i    3068394109518479363  3068394109518479363           0
# 3068394109518479365 i    3068394109518479365  3068394109518479365           0
# 3068394109518479370 i    3068394109518479370  3068394109518479370           0
# 3068394109518479378 i    3068394109518479378  3068394109518479378           0
# 3068394109518479387 i    3068394109518479387  3068394109518479387           0
# ...                                                           ...         ...
# 3068394109518479610 i    3068394109518479610  3068394109518479610           0
# 3068394109518479613 i    3068394109518479613  3068394109518479613           0
# 3068394109518479614 i    3068394109518479614  3068394109518479614           0
# 3068394109518479616 i    3068394109518479616  3068394109518479616           0
# 3068394109518479617 i    3068394109518479617  3068394109518479617           0
#
#                                               parentDiaSourceId  \
# diaObjectId         band diaSourceId
# 3068394109518479363 i    3068394109518479363                  0
# 3068394109518479365 i    3068394109518479365                  0
# 3068394109518479370 i    3068394109518479370                  0
# 3068394109518479378 i    3068394109518479378                  0
# 3068394109518479387 i    3068394109518479387                  0
# ...                                                         ...
# 3068394109518479610 i    3068394109518479610                  0
# 3068394109518479613 i    3068394109518479613                  0
# 3068394109518479614 i    3068394109518479614                  0
# 3068394109518479616 i    3068394109518479616                  0
# 3068394109518479617 i    3068394109518479617                  0
#
#                                              ssObjectReassocTime  \
# diaObjectId         band diaSourceId
# 3068394109518479363 i    3068394109518479363                 NaT
# 3068394109518479365 i    3068394109518479365                 NaT
# 3068394109518479370 i    3068394109518479370                 NaT
# 3068394109518479378 i    3068394109518479378                 NaT
# 3068394109518479387 i    3068394109518479387                 NaT
# ...                                                          ...
# 3068394109518479610 i    3068394109518479610                 NaT
# 3068394109518479613 i    3068394109518479613                 NaT
# 3068394109518479614 i    3068394109518479614                 NaT
# 3068394109518479616 i    3068394109518479616                 NaT
# 3068394109518479617 i    3068394109518479617                 NaT
#
#                                               midpointMjdTai          ra  \
# diaObjectId         band diaSourceId
# 3068394109518479363 i    3068394109518479363     60487.08931  216.017679
# 3068394109518479365 i    3068394109518479365     60487.08931  216.158525
# 3068394109518479370 i    3068394109518479370     60487.08931  216.164852
# 3068394109518479378 i    3068394109518479378     60487.08931  216.026806
# 3068394109518479387 i    3068394109518479387     60487.08931  216.007582
# ...                                                      ...         ...
# 3068394109518479610 i    3068394109518479610     60487.08931  216.152445
# 3068394109518479613 i    3068394109518479613     60487.08931  216.162058
# 3068394109518479614 i    3068394109518479614     60487.08931  216.092032
# 3068394109518479616 i    3068394109518479616     60487.08931  216.149203
# 3068394109518479617 i    3068394109518479617     60487.08931  216.048597
#
#                                                      raErr  ...  \
# diaObjectId         band diaSourceId                        ...
# 3068394109518479363 i    3068394109518479363  9.527630e-06  ...
# 3068394109518479365 i    3068394109518479365  1.007832e-05  ...
# 3068394109518479370 i    3068394109518479370  5.153925e-06  ...
# 3068394109518479378 i    3068394109518479378  1.268341e-05  ...
# 3068394109518479387 i    3068394109518479387  1.341156e-05  ...
# ...                                                    ...  ...
# 3068394109518479610 i    3068394109518479610  1.644181e-05  ...
# 3068394109518479613 i    3068394109518479613  1.669841e-05  ...
# 3068394109518479614 i    3068394109518479614  6.834653e-07  ...
# 3068394109518479616 i    3068394109518479616  1.803159e-05  ...
# 3068394109518479617 i    3068394109518479617  1.958444e-05  ...
#
#                                               pixelFlags_saturated  \
# diaObjectId         band diaSourceId
# 3068394109518479363 i    3068394109518479363                 False
# 3068394109518479365 i    3068394109518479365                 False
# 3068394109518479370 i    3068394109518479370                 False
# 3068394109518479378 i    3068394109518479378                 False
# 3068394109518479387 i    3068394109518479387                 False
# ...                                                            ...
# 3068394109518479610 i    3068394109518479610                 False
# 3068394109518479613 i    3068394109518479613                 False
# 3068394109518479614 i    3068394109518479614                 False
# 3068394109518479616 i    3068394109518479616                 False
# 3068394109518479617 i    3068394109518479617                 False
#
#                                               pixelFlags_saturatedCenter  \
# diaObjectId         band diaSourceId
# 3068394109518479363 i    3068394109518479363                       False
# 3068394109518479365 i    3068394109518479365                       False
# 3068394109518479370 i    3068394109518479370                       False
# 3068394109518479378 i    3068394109518479378                       False
# 3068394109518479387 i    3068394109518479387                       False
# ...                                                                  ...
# 3068394109518479610 i    3068394109518479610                       False
# 3068394109518479613 i    3068394109518479613                       False
# 3068394109518479614 i    3068394109518479614                       False
# 3068394109518479616 i    3068394109518479616                       False
# 3068394109518479617 i    3068394109518479617                       False
#
#                                               pixelFlags_suspect  \
# diaObjectId         band diaSourceId
# 3068394109518479363 i    3068394109518479363               False
# 3068394109518479365 i    3068394109518479365               False
# 3068394109518479370 i    3068394109518479370               False
# 3068394109518479378 i    3068394109518479378               False
# 3068394109518479387 i    3068394109518479387               False
# ...                                                          ...
# 3068394109518479610 i    3068394109518479610               False
# 3068394109518479613 i    3068394109518479613               False
# 3068394109518479614 i    3068394109518479614               False
# 3068394109518479616 i    3068394109518479616               False
# 3068394109518479617 i    3068394109518479617               False
#
#                                               pixelFlags_suspectCenter  \
# diaObjectId         band diaSourceId
# 3068394109518479363 i    3068394109518479363                     False
# 3068394109518479365 i    3068394109518479365                     False
# 3068394109518479370 i    3068394109518479370                     False
# 3068394109518479378 i    3068394109518479378                     False
# 3068394109518479387 i    3068394109518479387                     False
# ...                                                                ...
# 3068394109518479610 i    3068394109518479610                     False
# 3068394109518479613 i    3068394109518479613                     False
# 3068394109518479614 i    3068394109518479614                     False
# 3068394109518479616 i    3068394109518479616                     False
# 3068394109518479617 i    3068394109518479617                     False
#
#                                               pixelFlags_streak  \
# diaObjectId         band diaSourceId
# 3068394109518479363 i    3068394109518479363              False
# 3068394109518479365 i    3068394109518479365              False
# 3068394109518479370 i    3068394109518479370              False
# 3068394109518479378 i    3068394109518479378              False
# 3068394109518479387 i    3068394109518479387              False
# ...                                                         ...
# 3068394109518479610 i    3068394109518479610              False
# 3068394109518479613 i    3068394109518479613              False
# 3068394109518479614 i    3068394109518479614              False
# 3068394109518479616 i    3068394109518479616              False
# 3068394109518479617 i    3068394109518479617              False
#
#                                               pixelFlags_streakCenter  \
# diaObjectId         band diaSourceId
# 3068394109518479363 i    3068394109518479363                    False
# 3068394109518479365 i    3068394109518479365                    False
# 3068394109518479370 i    3068394109518479370                    False
# 3068394109518479378 i    3068394109518479378                    False
# 3068394109518479387 i    3068394109518479387                    False
# ...                                                               ...
# 3068394109518479610 i    3068394109518479610                    False
# 3068394109518479613 i    3068394109518479613                    False
# 3068394109518479614 i    3068394109518479614                    False
# 3068394109518479616 i    3068394109518479616                    False
# 3068394109518479617 i    3068394109518479617                    False
#
#                                               pixelFlags_injected  \
# diaObjectId         band diaSourceId
# 3068394109518479363 i    3068394109518479363                False
# 3068394109518479365 i    3068394109518479365                False
# 3068394109518479370 i    3068394109518479370                False
# 3068394109518479378 i    3068394109518479378                False
# 3068394109518479387 i    3068394109518479387                False
# ...                                                           ...
# 3068394109518479610 i    3068394109518479610                False
# 3068394109518479613 i    3068394109518479613                False
# 3068394109518479614 i    3068394109518479614                False
# 3068394109518479616 i    3068394109518479616                False
# 3068394109518479617 i    3068394109518479617                False
#
#                                               pixelFlags_injectedCenter  \
# diaObjectId         band diaSourceId
# 3068394109518479363 i    3068394109518479363                      False
# 3068394109518479365 i    3068394109518479365                      False
# 3068394109518479370 i    3068394109518479370                      False
# 3068394109518479378 i    3068394109518479378                      False
# 3068394109518479387 i    3068394109518479387                      False
# ...                                                                 ...
# 3068394109518479610 i    3068394109518479610                      False
# 3068394109518479613 i    3068394109518479613                      False
# 3068394109518479614 i    3068394109518479614                      False
# 3068394109518479616 i    3068394109518479616                      False
# 3068394109518479617 i    3068394109518479617                      False
#
#                                               pixelFlags_injected_template  \
# diaObjectId         band diaSourceId
# 3068394109518479363 i    3068394109518479363                         False
# 3068394109518479365 i    3068394109518479365                         False
# 3068394109518479370 i    3068394109518479370                         False
# 3068394109518479378 i    3068394109518479378                         False
# 3068394109518479387 i    3068394109518479387                         False
# ...                                                                    ...
# 3068394109518479610 i    3068394109518479610                         False
# 3068394109518479613 i    3068394109518479613                         False
# 3068394109518479614 i    3068394109518479614                         False
# 3068394109518479616 i    3068394109518479616                         False
# 3068394109518479617 i    3068394109518479617                         False
#
#                                               pixelFlags_injected_templateCenter
# diaObjectId         band diaSourceId
# 3068394109518479363 i    3068394109518479363                               False
# 3068394109518479365 i    3068394109518479365                               False
# 3068394109518479370 i    3068394109518479370                               False
# 3068394109518479378 i    3068394109518479378                               False
# 3068394109518479387 i    3068394109518479387                               False
# ...                                                                          ...
# 3068394109518479610 i    3068394109518479610                               False
# 3068394109518479613 i    3068394109518479613                               False
# 3068394109518479614 i    3068394109518479614                               False
# 3068394109518479616 i    3068394109518479616                               False
# 3068394109518479617 i    3068394109518479617                               False
#
# [93 rows x 143 columns]

# %%
# new cell
columns = single_butler_cand_src.schema.getNames()  # Get all column names
data = {col: single_butler_cand_src[col].tolist() for col in columns}  # Extract each column's data
single_butler_cand_src_df = pd.DataFrame(data)
single_butler_cand_src_df[['id', 'ip_diffim_DipoleFit_flag_classification', 'coord_ra', 'coord_raErr', 'coord_dec', 'coord_decErr', 'base_SdssCentroid_x', 'base_SdssCentroid_xErr', 'base_SdssCentroid_y', 'base_SdssCentroid_yErr', 'base_PsfFlux_instFlux']]
# Out:
#                     id  ip_diffim_DipoleFit_flag_classification  coord_ra  \
# 0  3068394109518479458                                     True  3.772797
#
#     coord_raErr  coord_dec  coord_decErr  base_SdssCentroid_x  \
# 0  1.309876e-07  -0.221926  1.661769e-07           434.075123
#
#    base_SdssCentroid_xErr  base_SdssCentroid_y  base_SdssCentroid_yErr  \
# 0                0.133803          1538.242949                0.174691
#
#    base_PsfFlux_instFlux
# 0            4106.269749

# %%
# x and y are nan, ok - how does ra,dec not be nan
print(single_butler_cand_src['coord_raErr'], single_butler_cand_src['coord_decErr'], 
      single_butler_cand_src.getIxx(), single_butler_cand_src.getIyy(), single_butler_cand_src['ip_diffim_DipoleFit_flag_classification'])
print(single_butler_prefilter_src['coord_raErr'], single_butler_prefilter_src['coord_decErr'], 
      single_butler_prefilter_src.getIxx(), single_butler_prefilter_src.getIyy(), single_butler_prefilter_src['ip_diffim_DipoleFit_flag_classification'])
# Out:
# [1.3098756e-07] [1.661769e-07] [nan] [nan] [ True]
# [1.3098756e-07] [1.661769e-07] [nan] [nan] [ True]

# %%
single_butler_prefilter_src.getX()
# Out:
# array([431.81155109])

# %%
slot = single_butler_prefilter_src.getCentroidSlot()
slot.getErrKey().get(single_butler_prefilter_src[0])
# Out:
# array([[nan,  0.],
#        [ 0., nan]], dtype=float32)

# %%
single_butler_cand_src[0]
# Out:
# <class 'lsst.afw.table.SourceRecord'>
# id: 3068394109518479458
# coord_ra: 3.7728 rad
# coord_dec: -0.221926 rad
# parent: 0
# coord_raErr: 1.30988e-07
# coord_decErr: 1.66177e-07
# coord_ra_dec_Cov: 3.4106e-15
# flags_negative: 0
# deblend_nChild: 0
# deblend_deblendedAsPsf: 0
# deblend_psfCenter_x: nan
# deblend_psfCenter_y: nan
# deblend_psf_instFlux: nan
# deblend_tooManyPeaks: 0
# deblend_parentTooBig: 0
# deblend_masked: 0
# deblend_failed: 0
# deblend_skipped: 0
# deblend_rampedTemplate: 0
# deblend_patchedTemplate: 0
# deblend_hasStrayFlux: 0
# deblend_peak_center_x: 0
# deblend_peak_center_y: 0
# deblend_peakId: 0
# deblend_nPeaks: 0
# deblend_parentNPeaks: 0
# detect_isPrimary: 0
# detect_isDeblendedSource: 0
# detect_fromBlend: 0
# detect_isIsolated: 0
# base_SdssCentroid_x: 434.075
# base_SdssCentroid_y: 1538.24
# base_SdssCentroid_xErr: 0.133803
# base_SdssCentroid_yErr: 0.174691
# base_SdssCentroid_flag: 0
# base_SdssCentroid_flag_edge: 0
# base_SdssCentroid_flag_noSecondDerivative: 0
# base_SdssCentroid_flag_almostNoSecondDerivative: 0
# base_SdssCentroid_flag_notAtMaximum: 0
# base_SdssCentroid_flag_near_edge: 0
# base_SdssCentroid_flag_resetToPeak: 0
# base_SdssCentroid_flag_badError: 0
# ip_diffim_DipoleFit_pos_instFlux: 162504
# ip_diffim_DipoleFit_pos_instFluxErr: 1827.92
# ip_diffim_DipoleFit_neg_instFlux: -162504
# ip_diffim_DipoleFit_neg_instFluxErr: 1827.92
# ip_diffim_DipoleFit_instFlux: 162504
# ip_diffim_DipoleFit_instFluxErr: nan
# ip_diffim_DipoleFit_pos_x: 431.855
# ip_diffim_DipoleFit_pos_y: 1537.76
# ip_diffim_DipoleFit_neg_x: 431.768
# ip_diffim_DipoleFit_neg_y: 1537.74
# ip_diffim_DipoleFit_x: 431.812
# ip_diffim_DipoleFit_y: 1537.75
# ip_diffim_DipoleFit_xErr: nan
# ip_diffim_DipoleFit_yErr: nan
# ip_diffim_DipoleFit_orientation: 0.231887
# ip_diffim_DipoleFit_separation: 0.0888557
# ip_diffim_DipoleFit_chi2dof: 766.815
# ip_diffim_DipoleFit_nData: 1380
# ip_diffim_DipoleFit_signalToNoise: 1827.92
# ip_diffim_DipoleFit_flag_classification: 1
# ip_diffim_DipoleFit_flag_classificationAttempted: 1
# ip_diffim_DipoleFit_flag: 0
# ip_diffim_DipoleFit_flag_edge: 0
# ext_shapeHSM_HsmPsfMoments_flag: 0
# ext_shapeHSM_HsmPsfMoments_flag_no_pixels: 0
# ext_shapeHSM_HsmPsfMoments_flag_not_contained: 0
# ext_shapeHSM_HsmPsfMoments_flag_parent_source: 0
# ext_shapeHSM_HsmPsfMoments_flag_galsim: 0
# ext_shapeHSM_HsmPsfMoments_flag_invalid_param: 0
# ext_shapeHSM_HsmPsfMoments_flag_edge: 0
# ext_shapeHSM_HsmPsfMoments_flag_no_psf: 0
# ext_shapeHSM_HsmPsfMoments_x: -0.000230114
# ext_shapeHSM_HsmPsfMoments_y: -0.0002764
# ext_shapeHSM_HsmPsfMoments_xx: 2.43913
# ext_shapeHSM_HsmPsfMoments_yy: 2.40822
# ext_shapeHSM_HsmPsfMoments_xy: -0.00333211
# ext_shapeHSM_HsmSourceMoments_flag: 1
# ext_shapeHSM_HsmSourceMoments_flag_no_pixels: 0
# ext_shapeHSM_HsmSourceMoments_flag_not_contained: 0
# ext_shapeHSM_HsmSourceMoments_flag_parent_source: 0
# ext_shapeHSM_HsmSourceMoments_flag_galsim: 0
# ext_shapeHSM_HsmSourceMoments_flag_invalid_param: 0
# ext_shapeHSM_HsmSourceMoments_flag_edge: 0
# ext_shapeHSM_HsmSourceMoments_flag_no_psf: 0
# ext_shapeHSM_HsmSourceMoments_x: nan
# ext_shapeHSM_HsmSourceMoments_y: nan
# ext_shapeHSM_HsmSourceMoments_xx: nan
# ext_shapeHSM_HsmSourceMoments_yy: nan
# ext_shapeHSM_HsmSourceMoments_xy: nan
# base_CircularApertureFlux_12_0_instFlux: -733.829
# base_CircularApertureFlux_12_0_instFluxErr: 788.515
# base_CircularApertureFlux_12_0_flag: 0
# base_CircularApertureFlux_12_0_flag_apertureTruncated: 0
# base_LocalPhotoCalib_flag: 0
# base_LocalPhotoCalib: 1
# base_LocalPhotoCalibErr: 0.000220049
# base_LocalWcs_flag: 0
# base_LocalWcs_CDMatrix_1_1: -9.23367e-07
# base_LocalWcs_CDMatrix_1_2: 3.01111e-07
# base_LocalWcs_CDMatrix_2_1: 3.01454e-07
# base_LocalWcs_CDMatrix_2_2: 9.22814e-07
# base_PixelFlags_flag: 0
# base_PixelFlags_flag_offimage: 0
# base_PixelFlags_flag_edge: 0
# base_PixelFlags_flag_interpolated: 0
# base_PixelFlags_flag_saturated: 0
# base_PixelFlags_flag_cr: 0
# base_PixelFlags_flag_bad: 0
# base_PixelFlags_flag_suspect: 0
# base_PixelFlags_flag_edgeCenter: 0
# base_PixelFlags_flag_interpolatedCenter: 0
# base_PixelFlags_flag_saturatedCenter: 0
# base_PixelFlags_flag_crCenter: 0
# base_PixelFlags_flag_badCenter: 0
# base_PixelFlags_flag_suspectCenter: 0
# base_PixelFlags_flag_edgeCenterAll: 0
# base_PixelFlags_flag_interpolatedCenterAll: 0
# base_PixelFlags_flag_saturatedCenterAll: 0
# base_PixelFlags_flag_crCenterAll: 0
# base_PixelFlags_flag_badCenterAll: 0
# base_PixelFlags_flag_suspectCenterAll: 0
# base_PixelFlags_flag_streakCenter: 0
# base_PixelFlags_flag_injectedCenter: 0
# base_PixelFlags_flag_injected_templateCenter: 0
# base_PixelFlags_flag_streakCenterAll: 0
# base_PixelFlags_flag_injectedCenterAll: 0
# base_PixelFlags_flag_injected_templateCenterAll: 0
# base_PixelFlags_flag_streak: 0
# base_PixelFlags_flag_injected: 0
# base_PixelFlags_flag_injected_template: 0
# base_PsfFlux_instFlux: 4106.27
# base_PsfFlux_instFluxErr: 348.134
# base_PsfFlux_area: 38.1299
# base_PsfFlux_chi2: 1969.9
# base_PsfFlux_npixels: 1681
# base_PsfFlux_flag: 0
# base_PsfFlux_flag_noGoodPixels: 0
# base_PsfFlux_flag_edge: 0
# ext_trailedSources_Naive_ra: nan
# ext_trailedSources_Naive_dec: nan
# ext_trailedSources_Naive_x0: nan
# ext_trailedSources_Naive_y0: nan
# ext_trailedSources_Naive_x1: nan
# ext_trailedSources_Naive_y1: nan
# ext_trailedSources_Naive_flux: nan
# ext_trailedSources_Naive_length: nan
# ext_trailedSources_Naive_angle: nan
# ext_trailedSources_Naive_x0Err: nan
# ext_trailedSources_Naive_y0Err: nan
# ext_trailedSources_Naive_x1Err: nan
# ext_trailedSources_Naive_y1Err: nan
# ext_trailedSources_Naive_fluxErr: nan
# ext_trailedSources_Naive_lengthErr: nan
# ext_trailedSources_Naive_angleErr: nan
# ext_trailedSources_Naive_flag: 1
# ext_trailedSources_Naive_flag_noFlux: 0
# ext_trailedSources_Naive_flag_noConverge: 0
# ext_trailedSources_Naive_flag_noSigma: 0
# ext_trailedSources_Naive_flag_edge: 0
# ext_trailedSources_Naive_flag_off_image: 0
# ext_trailedSources_Naive_flag_nan: 0
# ext_trailedSources_Naive_flag_suspect_long_trail: 0
# ext_trailedSources_Naive_flag_shape: 1
# base_InvalidPsf_flag: 0
# base_PsfFlux_apCorr: 0.995369
# base_PsfFlux_apCorrErr: 0
# base_PsfFlux_flag_apCorr: 0
# ip_diffim_forced_PsfFlux_instFlux: 98635.8
# ip_diffim_forced_PsfFlux_instFluxErr: 339.133
# ip_diffim_forced_PsfFlux_area: 38.4206
# ip_diffim_forced_PsfFlux_flag: 0
# ip_diffim_forced_PsfFlux_flag_noGoodPixels: 0
# ip_diffim_forced_PsfFlux_flag_edge: 0
# refMatchId: 0
# srcMatchId: 0
# sky_source: 0

# %%
src_prefilter_via_butler[2]
# Out:
# <class 'lsst.afw.table.SourceRecord'>
# id: 3068394109518479363
# coord_ra: 3.77022 rad
# coord_dec: -0.2226 rad
# parent: 0
# coord_raErr: 1.73145e-07
# coord_decErr: 1.77258e-07
# coord_ra_dec_Cov: -4.56414e-17
# flags_negative: 0
# deblend_nChild: 0
# deblend_deblendedAsPsf: 0
# deblend_psfCenter_x: nan
# deblend_psfCenter_y: nan
# deblend_psf_instFlux: nan
# deblend_tooManyPeaks: 0
# deblend_parentTooBig: 0
# deblend_masked: 0
# deblend_failed: 0
# deblend_skipped: 0
# deblend_rampedTemplate: 0
# deblend_patchedTemplate: 0
# deblend_hasStrayFlux: 0
# deblend_peak_center_x: 0
# deblend_peak_center_y: 0
# deblend_peakId: 0
# deblend_nPeaks: 0
# deblend_parentNPeaks: 0
# detect_isPrimary: 0
# detect_isDeblendedSource: 0
# detect_fromBlend: 0
# detect_isIsolated: 0
# base_SdssCentroid_x: 2679.53
# base_SdssCentroid_y: 72.8617
# base_SdssCentroid_xErr: 0.182919
# base_SdssCentroid_yErr: 0.182572
# base_SdssCentroid_flag: 0
# base_SdssCentroid_flag_edge: 0
# base_SdssCentroid_flag_noSecondDerivative: 0
# base_SdssCentroid_flag_almostNoSecondDerivative: 0
# base_SdssCentroid_flag_notAtMaximum: 0
# base_SdssCentroid_flag_near_edge: 0
# base_SdssCentroid_flag_resetToPeak: 0
# base_SdssCentroid_flag_badError: 0
# ip_diffim_DipoleFit_pos_instFlux: 539295
# ip_diffim_DipoleFit_pos_instFluxErr: 5485.7
# ip_diffim_DipoleFit_neg_instFlux: -539295
# ip_diffim_DipoleFit_neg_instFluxErr: 5485.7
# ip_diffim_DipoleFit_instFlux: 539295
# ip_diffim_DipoleFit_instFluxErr: nan
# ip_diffim_DipoleFit_pos_x: 2679.23
# ip_diffim_DipoleFit_pos_y: 73.8191
# ip_diffim_DipoleFit_neg_x: 2679.23
# ip_diffim_DipoleFit_neg_y: 73.8384
# ip_diffim_DipoleFit_x: 2679.23
# ip_diffim_DipoleFit_y: 73.8287
# ip_diffim_DipoleFit_xErr: nan
# ip_diffim_DipoleFit_yErr: nan
# ip_diffim_DipoleFit_orientation: -1.14837
# ip_diffim_DipoleFit_separation: 0.0211813
# ip_diffim_DipoleFit_chi2dof: 4847.12
# ip_diffim_DipoleFit_nData: 1080
# ip_diffim_DipoleFit_signalToNoise: 5485.7
# ip_diffim_DipoleFit_flag_classification: 1
# ip_diffim_DipoleFit_flag_classificationAttempted: 1
# ip_diffim_DipoleFit_flag: 0
# ip_diffim_DipoleFit_flag_edge: 0
# ext_shapeHSM_HsmPsfMoments_flag: 0
# ext_shapeHSM_HsmPsfMoments_flag_no_pixels: 0
# ext_shapeHSM_HsmPsfMoments_flag_not_contained: 0
# ext_shapeHSM_HsmPsfMoments_flag_parent_source: 0
# ext_shapeHSM_HsmPsfMoments_flag_galsim: 0
# ext_shapeHSM_HsmPsfMoments_flag_invalid_param: 0
# ext_shapeHSM_HsmPsfMoments_flag_edge: 0
# ext_shapeHSM_HsmPsfMoments_flag_no_psf: 0
# ext_shapeHSM_HsmPsfMoments_x: -0.000230114
# ext_shapeHSM_HsmPsfMoments_y: -0.0002764
# ext_shapeHSM_HsmPsfMoments_xx: 2.43913
# ext_shapeHSM_HsmPsfMoments_yy: 2.40822
# ext_shapeHSM_HsmPsfMoments_xy: -0.00333211
# ext_shapeHSM_HsmSourceMoments_flag: 0
# ext_shapeHSM_HsmSourceMoments_flag_no_pixels: 0
# ext_shapeHSM_HsmSourceMoments_flag_not_contained: 0
# ext_shapeHSM_HsmSourceMoments_flag_parent_source: 0
# ext_shapeHSM_HsmSourceMoments_flag_galsim: 0
# ext_shapeHSM_HsmSourceMoments_flag_invalid_param: 0
# ext_shapeHSM_HsmSourceMoments_flag_edge: 0
# ext_shapeHSM_HsmSourceMoments_flag_no_psf: 0
# ext_shapeHSM_HsmSourceMoments_x: 2679.35
# ext_shapeHSM_HsmSourceMoments_y: 73.1001
# ext_shapeHSM_HsmSourceMoments_xx: 0.89901
# ext_shapeHSM_HsmSourceMoments_yy: 1.61481
# ext_shapeHSM_HsmSourceMoments_xy: 0.63558
# base_CircularApertureFlux_12_0_instFlux: 157.609
# base_CircularApertureFlux_12_0_instFluxErr: 946.383
# base_CircularApertureFlux_12_0_flag: 0
# base_CircularApertureFlux_12_0_flag_apertureTruncated: 0
# base_LocalPhotoCalib_flag: 0
# base_LocalPhotoCalib: 1
# base_LocalPhotoCalibErr: 0.000220049
# base_LocalWcs_flag: 0
# base_LocalWcs_CDMatrix_1_1: -9.22668e-07
# base_LocalWcs_CDMatrix_1_2: 3.01533e-07
# base_LocalWcs_CDMatrix_2_1: 3.01879e-07
# base_LocalWcs_CDMatrix_2_2: 9.2258e-07
# base_PixelFlags_flag: 0
# base_PixelFlags_flag_offimage: 0
# base_PixelFlags_flag_edge: 0
# base_PixelFlags_flag_interpolated: 0
# base_PixelFlags_flag_saturated: 0
# base_PixelFlags_flag_cr: 0
# base_PixelFlags_flag_bad: 0
# base_PixelFlags_flag_suspect: 0
# base_PixelFlags_flag_edgeCenter: 0
# base_PixelFlags_flag_interpolatedCenter: 0
# base_PixelFlags_flag_saturatedCenter: 0
# base_PixelFlags_flag_crCenter: 0
# base_PixelFlags_flag_badCenter: 0
# base_PixelFlags_flag_suspectCenter: 0
# base_PixelFlags_flag_edgeCenterAll: 0
# base_PixelFlags_flag_interpolatedCenterAll: 0
# base_PixelFlags_flag_saturatedCenterAll: 0
# base_PixelFlags_flag_crCenterAll: 0
# base_PixelFlags_flag_badCenterAll: 0
# base_PixelFlags_flag_suspectCenterAll: 0
# base_PixelFlags_flag_streakCenter: 0
# base_PixelFlags_flag_injectedCenter: 0
# base_PixelFlags_flag_injected_templateCenter: 0
# base_PixelFlags_flag_streakCenterAll: 0
# base_PixelFlags_flag_injectedCenterAll: 0
# base_PixelFlags_flag_injected_templateCenterAll: 0
# base_PixelFlags_flag_streak: 0
# base_PixelFlags_flag_injected: 0
# base_PixelFlags_flag_injected_template: 0
# base_PsfFlux_instFlux: 6431.59
# base_PsfFlux_instFluxErr: 718.97
# base_PsfFlux_area: 38.0861
# base_PsfFlux_chi2: 2138.83
# base_PsfFlux_npixels: 1681
# base_PsfFlux_flag: 0
# base_PsfFlux_flag_noGoodPixels: 0
# base_PsfFlux_flag_edge: 0
# ext_trailedSources_Naive_ra: 216.018
# ext_trailedSources_Naive_dec: -12.754
# ext_trailedSources_Naive_x0: 2678.43
# ext_trailedSources_Naive_y0: 71.5289
# ext_trailedSources_Naive_x1: 2680.27
# ext_trailedSources_Naive_y1: 74.6713
# ext_trailedSources_Naive_flux: 5971.14
# ext_trailedSources_Naive_length: 3.63988
# ext_trailedSources_Naive_angle: 1.04182
# ext_trailedSources_Naive_x0Err: 0.42769
# ext_trailedSources_Naive_y0Err: 0.427285
# ext_trailedSources_Naive_x1Err: 0.42769
# ext_trailedSources_Naive_y1Err: 0.427285
# ext_trailedSources_Naive_fluxErr: 157.917
# ext_trailedSources_Naive_lengthErr: 0
# ext_trailedSources_Naive_angleErr: 0
# ext_trailedSources_Naive_flag: 0
# ext_trailedSources_Naive_flag_noFlux: 0
# ext_trailedSources_Naive_flag_noConverge: 0
# ext_trailedSources_Naive_flag_noSigma: 0
# ext_trailedSources_Naive_flag_edge: 0
# ext_trailedSources_Naive_flag_off_image: 0
# ext_trailedSources_Naive_flag_nan: 0
# ext_trailedSources_Naive_flag_suspect_long_trail: 0
# ext_trailedSources_Naive_flag_shape: 0
# base_InvalidPsf_flag: 0
# base_PsfFlux_apCorr: 0.992351
# base_PsfFlux_apCorrErr: 0
# base_PsfFlux_flag_apCorr: 0
# ip_diffim_forced_PsfFlux_instFlux: 496606
# ip_diffim_forced_PsfFlux_instFluxErr: 704.927
# ip_diffim_forced_PsfFlux_area: 38.6628
# ip_diffim_forced_PsfFlux_flag: 0
# ip_diffim_forced_PsfFlux_flag_noGoodPixels: 0
# ip_diffim_forced_PsfFlux_flag_edge: 0
# refMatchId: 0
# srcMatchId: 0
# sky_source: 0

# %%
single_butler_cand_src['ip_diffim_DipoleFit_flag_classification']
# Out:
# array([ True])

# %%
single_butler_cand_src.schema
# Out:
# Schema(
#     (Field['L'](name="id", doc="unique ID"), Key<L>(offset=0, nElements=1)),
#     (Field['Angle'](name="coord_ra", doc="position in ra/dec"), Key<Angle>(offset=8, nElements=1)),
#     (Field['Angle'](name="coord_dec", doc="position in ra/dec"), Key<Angle>(offset=16, nElements=1)),
#     (Field['L'](name="parent", doc="unique ID of parent source"), Key<L>(offset=24, nElements=1)),
#     (Field['F'](name="coord_raErr", doc="1-sigma uncertainty on ra", units="rad"), Key<F>(offset=32, nElements=1)),
#     (Field['F'](name="coord_decErr", doc="1-sigma uncertainty on dec", units="rad"), Key<F>(offset=36, nElements=1)),
#     (Field['F'](name="coord_ra_dec_Cov", doc="uncertainty covariance between ra and dec", units="rad rad"), Key<F>(offset=40, nElements=1)),
#     (Field['Flag'](name="flags_negative", doc="set if source was detected as significantly negative"), Key['Flag'](offset=48, bit=0)),
#     (Field['I'](name="deblend_nChild", doc="Number of children this object has (defaults to 0)"), Key<I>(offset=56, nElements=1)),
#     (Field['Flag'](name="deblend_deblendedAsPsf", doc="Deblender thought this source looked like a PSF"), Key['Flag'](offset=48, bit=1)),
#     (Field['D'](name="deblend_psfCenter_x", doc="If deblended-as-psf, the PSF centroid", units="pixel"), Key<D>(offset=64, nElements=1)),
#     (Field['D'](name="deblend_psfCenter_y", doc="If deblended-as-psf, the PSF centroid", units="pixel"), Key<D>(offset=72, nElements=1)),
#     (Field['D'](name="deblend_psf_instFlux", doc="If deblended-as-psf, the instrumental PSF flux", units="count"), Key<D>(offset=80, nElements=1)),
#     (Field['Flag'](name="deblend_tooManyPeaks", doc="Source had too many peaks; only the brightest were included"), Key['Flag'](offset=48, bit=2)),
#     (Field['Flag'](name="deblend_parentTooBig", doc="Parent footprint covered too many pixels"), Key['Flag'](offset=48, bit=3)),
#     (Field['Flag'](name="deblend_masked", doc="Parent footprint was predominantly masked"), Key['Flag'](offset=48, bit=4)),
#     (Field['Flag'](name="deblend_failed", doc="Deblending failed on source"), Key['Flag'](offset=48, bit=5)),
#     (Field['Flag'](name="deblend_skipped", doc="Deblender skipped this source"), Key['Flag'](offset=48, bit=6)),
#     (Field['Flag'](name="deblend_rampedTemplate", doc="This source was near an image edge and the deblender used "ramp" edge-handling."), Key['Flag'](offset=48, bit=7)),
#     (Field['Flag'](name="deblend_patchedTemplate", doc="This source was near an image edge and the deblender used "patched" edge-handling."), Key['Flag'](offset=48, bit=8)),
#     (Field['Flag'](name="deblend_hasStrayFlux", doc="This source was assigned some stray flux"), Key['Flag'](offset=48, bit=9)),
#     (Field['I'](name="deblend_peak_center_x", doc="Center used to apply constraints in scarlet", units="pixel"), Key<I>(offset=88, nElements=1)),
#     (Field['I'](name="deblend_peak_center_y", doc="Center used to apply constraints in scarlet", units="pixel"), Key<I>(offset=92, nElements=1)),
#     (Field['I'](name="deblend_peakId", doc="ID of the peak in the parent footprint. This is not unique, but the combination of"), Key<I>(offset=96, nElements=1)),
#     (Field['I'](name="deblend_nPeaks", doc="Number of initial peaks in the blend. This includes peaks that may have been culled during deblending or failed to deblend"), Key<I>(offset=100, nElements=1)),
#     (Field['I'](name="deblend_parentNPeaks", doc="Same as deblend_n_peaks, but the number of peaks in the parent footprint"), Key<I>(offset=104, nElements=1)),
#     (Field['Flag'](name="detect_isPrimary", doc="True if source has no children and is not a sky source."), Key['Flag'](offset=48, bit=10)),
#     (Field['Flag'](name="detect_isDeblendedSource", doc="True if source has no children and is not a sky source. and is either an unblended isolated source or a deblended child from a parent with"), Key['Flag'](offset=48, bit=11)),
#     (Field['Flag'](name="detect_fromBlend", doc="This source is deblended from a parent with more than one child."), Key['Flag'](offset=48, bit=12)),
#     (Field['Flag'](name="detect_isIsolated", doc="This source is not a part of a blend."), Key['Flag'](offset=48, bit=13)),
#     (Field['D'](name="base_SdssCentroid_x", doc="centroid from Sdss Centroid algorithm", units="pixel"), Key<D>(offset=112, nElements=1)),
#     (Field['D'](name="base_SdssCentroid_y", doc="centroid from Sdss Centroid algorithm", units="pixel"), Key<D>(offset=120, nElements=1)),
#     (Field['F'](name="base_SdssCentroid_xErr", doc="1-sigma uncertainty on x position", units="pixel"), Key<F>(offset=128, nElements=1)),
#     (Field['F'](name="base_SdssCentroid_yErr", doc="1-sigma uncertainty on y position", units="pixel"), Key<F>(offset=132, nElements=1)),
#     (Field['Flag'](name="base_SdssCentroid_flag", doc="General Failure Flag"), Key['Flag'](offset=48, bit=14)),
#     (Field['Flag'](name="base_SdssCentroid_flag_edge", doc="Object too close to edge; peak used."), Key['Flag'](offset=48, bit=15)),
#     (Field['Flag'](name="base_SdssCentroid_flag_noSecondDerivative", doc="Vanishing second derivative"), Key['Flag'](offset=48, bit=16)),
#     (Field['Flag'](name="base_SdssCentroid_flag_almostNoSecondDerivative", doc="Almost vanishing second derivative"), Key['Flag'](offset=48, bit=17)),
#     (Field['Flag'](name="base_SdssCentroid_flag_notAtMaximum", doc="Object is not at a maximum"), Key['Flag'](offset=48, bit=18)),
#     (Field['Flag'](name="base_SdssCentroid_flag_near_edge", doc="Object close to edge; fallback kernel used."), Key['Flag'](offset=48, bit=19)),
#     (Field['Flag'](name="base_SdssCentroid_flag_resetToPeak", doc="set if CentroidChecker reset the centroid"), Key['Flag'](offset=48, bit=20)),
#     (Field['Flag'](name="base_SdssCentroid_flag_badError", doc="Error on x and/or y position is NaN"), Key['Flag'](offset=48, bit=21)),
#     (Field['D'](name="ip_diffim_DipoleFit_pos_instFlux", doc="Dipole positive lobe instrumental flux.", units="count"), Key<D>(offset=136, nElements=1)),
#     (Field['D'](name="ip_diffim_DipoleFit_pos_instFluxErr", doc="1-sigma instFlux uncertainty", units="count"), Key<D>(offset=144, nElements=1)),
#     (Field['D'](name="ip_diffim_DipoleFit_neg_instFlux", doc="Dipole negative lobe instrumental flux.", units="count"), Key<D>(offset=152, nElements=1)),
#     (Field['D'](name="ip_diffim_DipoleFit_neg_instFluxErr", doc="1-sigma instFlux uncertainty", units="count"), Key<D>(offset=160, nElements=1)),
#     (Field['D'](name="ip_diffim_DipoleFit_instFlux", doc="Dipole overall instrumental flux (mean of absolute value of positive and negative lobes).", units="count"), Key<D>(offset=168, nElements=1)),
#     (Field['D'](name="ip_diffim_DipoleFit_instFluxErr", doc="1-sigma instFlux uncertainty", units="count"), Key<D>(offset=176, nElements=1)),
#     (Field['D'](name="ip_diffim_DipoleFit_pos_x", doc="Dipole positive lobe centroid position.", units="pixel"), Key<D>(offset=184, nElements=1)),
#     (Field['D'](name="ip_diffim_DipoleFit_pos_y", doc="Dipole positive lobe centroid position.", units="pixel"), Key<D>(offset=192, nElements=1)),
#     (Field['D'](name="ip_diffim_DipoleFit_neg_x", doc="Dipole negative lobe centroid position.", units="pixel"), Key<D>(offset=200, nElements=1)),
#     (Field['D'](name="ip_diffim_DipoleFit_neg_y", doc="Dipole negative lobe centroid position.", units="pixel"), Key<D>(offset=208, nElements=1)),
#     (Field['D'](name="ip_diffim_DipoleFit_x", doc="Dipole centroid position.", units="pixel"), Key<D>(offset=216, nElements=1)),
#     (Field['D'](name="ip_diffim_DipoleFit_y", doc="Dipole centroid position.", units="pixel"), Key<D>(offset=224, nElements=1)),
#     (Field['F'](name="ip_diffim_DipoleFit_xErr", doc="1-sigma uncertainty on x position", units="pixel"), Key<F>(offset=232, nElements=1)),
#     (Field['F'](name="ip_diffim_DipoleFit_yErr", doc="1-sigma uncertainty on y position", units="pixel"), Key<F>(offset=236, nElements=1)),
#     (Field['D'](name="ip_diffim_DipoleFit_orientation", doc="Dipole orientation.  Convention is CCW from +x on image.", units="rad"), Key<D>(offset=240, nElements=1)),
#     (Field['D'](name="ip_diffim_DipoleFit_separation", doc="Pixel separation between positive and negative lobes of dipole", units="pixel"), Key<D>(offset=248, nElements=1)),
#     (Field['D'](name="ip_diffim_DipoleFit_chi2dof", doc="Chi2 per degree of freedom (chi2/(nData-nVariables)) of dipole fit"), Key<D>(offset=256, nElements=1)),
#     (Field['L'](name="ip_diffim_DipoleFit_nData", doc="Number of data points in the dipole fit"), Key<L>(offset=264, nElements=1)),
#     (Field['D'](name="ip_diffim_DipoleFit_signalToNoise", doc="Estimated signal-to-noise of dipole fit"), Key<D>(offset=272, nElements=1)),
#     (Field['Flag'](name="ip_diffim_DipoleFit_flag_classification", doc="Flag indicating diaSource is classified as a dipole"), Key['Flag'](offset=48, bit=22)),
#     (Field['Flag'](name="ip_diffim_DipoleFit_flag_classificationAttempted", doc="Flag indicating diaSource was attempted to be classified as a dipole"), Key['Flag'](offset=48, bit=23)),
#     (Field['Flag'](name="ip_diffim_DipoleFit_flag", doc="General failure flag for dipole fit"), Key['Flag'](offset=48, bit=24)),
#     (Field['Flag'](name="ip_diffim_DipoleFit_flag_edge", doc="Flag set when dipole is too close to edge of image"), Key['Flag'](offset=48, bit=25)),
#     (Field['Flag'](name="ext_shapeHSM_HsmPsfMoments_flag", doc="General failure flag, set if anything went wrong"), Key['Flag'](offset=48, bit=26)),
#     (Field['Flag'](name="ext_shapeHSM_HsmPsfMoments_flag_no_pixels", doc="No pixels to measure"), Key['Flag'](offset=48, bit=27)),
#     (Field['Flag'](name="ext_shapeHSM_HsmPsfMoments_flag_not_contained", doc="Center not contained in footprint bounding box"), Key['Flag'](offset=48, bit=28)),
#     (Field['Flag'](name="ext_shapeHSM_HsmPsfMoments_flag_parent_source", doc="Parent source, ignored"), Key['Flag'](offset=48, bit=29)),
#     (Field['Flag'](name="ext_shapeHSM_HsmPsfMoments_flag_galsim", doc="GalSim failure"), Key['Flag'](offset=48, bit=30)),
#     (Field['Flag'](name="ext_shapeHSM_HsmPsfMoments_flag_invalid_param", doc="Invalid combination of moments"), Key['Flag'](offset=48, bit=31)),
#     (Field['Flag'](name="ext_shapeHSM_HsmPsfMoments_flag_edge", doc="Variance undefined outside image edge"), Key['Flag'](offset=48, bit=32)),
#     (Field['Flag'](name="ext_shapeHSM_HsmPsfMoments_flag_no_psf", doc="Exposure lacks PSF"), Key['Flag'](offset=48, bit=33)),
#     (Field['D'](name="ext_shapeHSM_HsmPsfMoments_x", doc="Centroid of the PSF via the HSM shape algorithm", units="pixel"), Key<D>(offset=280, nElements=1)),
#     (Field['D'](name="ext_shapeHSM_HsmPsfMoments_y", doc="Centroid of the PSF via the HSM shape algorithm", units="pixel"), Key<D>(offset=288, nElements=1)),
#     (Field['D'](name="ext_shapeHSM_HsmPsfMoments_xx", doc="Adaptive moments of the PSF via the HSM shape algorithm", units="pixel^2"), Key<D>(offset=296, nElements=1)),
#     (Field['D'](name="ext_shapeHSM_HsmPsfMoments_yy", doc="Adaptive moments of the PSF via the HSM shape algorithm", units="pixel^2"), Key<D>(offset=304, nElements=1)),
#     (Field['D'](name="ext_shapeHSM_HsmPsfMoments_xy", doc="Adaptive moments of the PSF via the HSM shape algorithm", units="pixel^2"), Key<D>(offset=312, nElements=1)),
#     (Field['Flag'](name="ext_shapeHSM_HsmSourceMoments_flag", doc="General failure flag, set if anything went wrong"), Key['Flag'](offset=48, bit=34)),
#     (Field['Flag'](name="ext_shapeHSM_HsmSourceMoments_flag_no_pixels", doc="No pixels to measure"), Key['Flag'](offset=48, bit=35)),
#     (Field['Flag'](name="ext_shapeHSM_HsmSourceMoments_flag_not_contained", doc="Center not contained in footprint bounding box"), Key['Flag'](offset=48, bit=36)),
#     (Field['Flag'](name="ext_shapeHSM_HsmSourceMoments_flag_parent_source", doc="Parent source, ignored"), Key['Flag'](offset=48, bit=37)),
#     (Field['Flag'](name="ext_shapeHSM_HsmSourceMoments_flag_galsim", doc="GalSim failure"), Key['Flag'](offset=48, bit=38)),
#     (Field['Flag'](name="ext_shapeHSM_HsmSourceMoments_flag_invalid_param", doc="Invalid combination of moments"), Key['Flag'](offset=48, bit=39)),
#     (Field['Flag'](name="ext_shapeHSM_HsmSourceMoments_flag_edge", doc="Variance undefined outside image edge"), Key['Flag'](offset=48, bit=40)),
#     (Field['Flag'](name="ext_shapeHSM_HsmSourceMoments_flag_no_psf", doc="Exposure lacks PSF"), Key['Flag'](offset=48, bit=41)),
#     (Field['D'](name="ext_shapeHSM_HsmSourceMoments_x", doc="Centroid of the source via the HSM shape algorithm", units="pixel"), Key<D>(offset=320, nElements=1)),
#     (Field['D'](name="ext_shapeHSM_HsmSourceMoments_y", doc="Centroid of the source via the HSM shape algorithm", units="pixel"), Key<D>(offset=328, nElements=1)),
#     (Field['D'](name="ext_shapeHSM_HsmSourceMoments_xx", doc="Adaptive moments of the source via the HSM shape algorithm", units="pixel^2"), Key<D>(offset=336, nElements=1)),
#     (Field['D'](name="ext_shapeHSM_HsmSourceMoments_yy", doc="Adaptive moments of the source via the HSM shape algorithm", units="pixel^2"), Key<D>(offset=344, nElements=1)),
#     (Field['D'](name="ext_shapeHSM_HsmSourceMoments_xy", doc="Adaptive moments of the source via the HSM shape algorithm", units="pixel^2"), Key<D>(offset=352, nElements=1)),
#     (Field['D'](name="base_CircularApertureFlux_12_0_instFlux", doc="instFlux within 12.000000-pixel aperture", units="count"), Key<D>(offset=360, nElements=1)),
#     (Field['D'](name="base_CircularApertureFlux_12_0_instFluxErr", doc="1-sigma instFlux uncertainty", units="count"), Key<D>(offset=368, nElements=1)),
#     (Field['Flag'](name="base_CircularApertureFlux_12_0_flag", doc="General Failure Flag"), Key['Flag'](offset=48, bit=42)),
#     (Field['Flag'](name="base_CircularApertureFlux_12_0_flag_apertureTruncated", doc="aperture did not fit within measurement image"), Key['Flag'](offset=48, bit=43)),
#     (Field['Flag'](name="base_LocalPhotoCalib_flag", doc="Set for any fatal failure"), Key['Flag'](offset=48, bit=44)),
#     (Field['D'](name="base_LocalPhotoCalib", doc="Local approximation of the PhotoCalib calibration factor at the location of the src."), Key<D>(offset=376, nElements=1)),
#     (Field['D'](name="base_LocalPhotoCalibErr", doc="Error on the local approximation of the PhotoCalib calibration factor at the location of the src."), Key<D>(offset=384, nElements=1)),
#     (Field['Flag'](name="base_LocalWcs_flag", doc="Set for any fatal failure"), Key['Flag'](offset=48, bit=45)),
#     (Field['D'](name="base_LocalWcs_CDMatrix_1_1", doc="(1, 1) element of the CDMatrix for the linear approximation of the WCS at the src location. Gives units in radians."), Key<D>(offset=392, nElements=1)),
#     (Field['D'](name="base_LocalWcs_CDMatrix_1_2", doc="(1, 2) element of the CDMatrix for the linear approximation of the WCS at the src location. Gives units in radians."), Key<D>(offset=400, nElements=1)),
#     (Field['D'](name="base_LocalWcs_CDMatrix_2_1", doc="(2, 1) element of the CDMatrix for the linear approximation of the WCS at the src location. Gives units in radians."), Key<D>(offset=408, nElements=1)),
#     (Field['D'](name="base_LocalWcs_CDMatrix_2_2", doc="(2, 2) element of the CDMatrix for the linear approximation of the WCS at the src location. Gives units in radians."), Key<D>(offset=416, nElements=1)),
#     (Field['Flag'](name="base_PixelFlags_flag", doc="General failure flag, set if anything went wrong"), Key['Flag'](offset=48, bit=46)),
#     (Field['Flag'](name="base_PixelFlags_flag_offimage", doc="Source center is off image"), Key['Flag'](offset=48, bit=47)),
#     (Field['Flag'](name="base_PixelFlags_flag_edge", doc="Source is outside usable exposure region (masked EDGE or NO_DATA, or centroid off image)."), Key['Flag'](offset=48, bit=48)),
#     (Field['Flag'](name="base_PixelFlags_flag_interpolated", doc="Interpolated pixel in the Source footprint"), Key['Flag'](offset=48, bit=49)),
#     (Field['Flag'](name="base_PixelFlags_flag_saturated", doc="Saturated pixel in the Source footprint"), Key['Flag'](offset=48, bit=50)),
#     (Field['Flag'](name="base_PixelFlags_flag_cr", doc="Cosmic ray in the Source footprint"), Key['Flag'](offset=48, bit=51)),
#     (Field['Flag'](name="base_PixelFlags_flag_bad", doc="Bad pixel in the Source footprint"), Key['Flag'](offset=48, bit=52)),
#     (Field['Flag'](name="base_PixelFlags_flag_suspect", doc="Source''''s footprint includes suspect pixels"), Key['Flag'](offset=48, bit=53)),
#     (Field['Flag'](name="base_PixelFlags_flag_edgeCenter", doc="EDGE or NO_DATA Pixel in the 3x3 region around the centroid."), Key['Flag'](offset=48, bit=54)),
#     (Field['Flag'](name="base_PixelFlags_flag_interpolatedCenter", doc="Interpolated pixel in the 3x3 region around the centroid."), Key['Flag'](offset=48, bit=55)),
#     (Field['Flag'](name="base_PixelFlags_flag_saturatedCenter", doc="Saturated pixel in the 3x3 region around the centroid."), Key['Flag'](offset=48, bit=56)),
#     (Field['Flag'](name="base_PixelFlags_flag_crCenter", doc="Cosmic ray in the 3x3 region around the centroid."), Key['Flag'](offset=48, bit=57)),
#     (Field['Flag'](name="base_PixelFlags_flag_badCenter", doc="Bad pixel in the 3x3 region around the centroid"), Key['Flag'](offset=48, bit=58)),
#     (Field['Flag'](name="base_PixelFlags_flag_suspectCenter", doc="Suspect pixel in the 3x3 region around the centroid."), Key['Flag'](offset=48, bit=59)),
#     (Field['Flag'](name="base_PixelFlags_flag_edgeCenterAll", doc="All pixels in the 3x3 region around the centroid are marked EDGE or NO_DATA."), Key['Flag'](offset=48, bit=60)),
#     (Field['Flag'](name="base_PixelFlags_flag_interpolatedCenterAll", doc="All pixels in the 3x3 region around the centroid are interpolated."), Key['Flag'](offset=48, bit=61)),
#     (Field['Flag'](name="base_PixelFlags_flag_saturatedCenterAll", doc="All pixels in the 3x3 region around the centroid are saturated."), Key['Flag'](offset=48, bit=62)),
#     (Field['Flag'](name="base_PixelFlags_flag_crCenterAll", doc="All pixels in the 3x3 region around the centroid have the cosmic ray mask bit."), Key['Flag'](offset=48, bit=63)),
#     (Field['Flag'](name="base_PixelFlags_flag_badCenterAll", doc="All pixels in the 3x3 region around the centroid are bad."), Key['Flag'](offset=424, bit=0)),
#     (Field['Flag'](name="base_PixelFlags_flag_suspectCenterAll", doc="All pixels in the 3x3 region around the centroid are suspect."), Key['Flag'](offset=424, bit=1)),
#     (Field['Flag'](name="base_PixelFlags_flag_streakCenter", doc="3x3 region around the centroid has STREAK pixels"), Key['Flag'](offset=424, bit=2)),
#     (Field['Flag'](name="base_PixelFlags_flag_injectedCenter", doc="3x3 region around the centroid has INJECTED pixels"), Key['Flag'](offset=424, bit=3)),
#     (Field['Flag'](name="base_PixelFlags_flag_injected_templateCenter", doc="3x3 region around the centroid has INJECTED_TEMPLATE pixels"), Key['Flag'](offset=424, bit=4)),
#     (Field['Flag'](name="base_PixelFlags_flag_streakCenterAll", doc="All pixels in the 3x3 region around the source centroid are STREAK pixels"), Key['Flag'](offset=424, bit=5)),
#     (Field['Flag'](name="base_PixelFlags_flag_injectedCenterAll", doc="All pixels in the 3x3 region around the source centroid are INJECTED pixels"), Key['Flag'](offset=424, bit=6)),
#     (Field['Flag'](name="base_PixelFlags_flag_injected_templateCenterAll", doc="All pixels in the 3x3 region around the source centroid are INJECTED_TEMPLATE pixels"), Key['Flag'](offset=424, bit=7)),
#     (Field['Flag'](name="base_PixelFlags_flag_streak", doc="Source footprint includes STREAK pixels"), Key['Flag'](offset=424, bit=8)),
#     (Field['Flag'](name="base_PixelFlags_flag_injected", doc="Source footprint includes INJECTED pixels"), Key['Flag'](offset=424, bit=9)),
#     (Field['Flag'](name="base_PixelFlags_flag_injected_template", doc="Source footprint includes INJECTED_TEMPLATE pixels"), Key['Flag'](offset=424, bit=10)),
#     (Field['D'](name="base_PsfFlux_instFlux", doc="instFlux derived from linear least-squares fit of PSF model", units="count"), Key<D>(offset=432, nElements=1)),
#     (Field['D'](name="base_PsfFlux_instFluxErr", doc="1-sigma instFlux uncertainty", units="count"), Key<D>(offset=440, nElements=1)),
#     (Field['F'](name="base_PsfFlux_area", doc="effective area of PSF", units="pixel"), Key<F>(offset=448, nElements=1)),
#     (Field['F'](name="base_PsfFlux_chi2", doc="chi2 of the fitted PSF"), Key<F>(offset=452, nElements=1)),
#     (Field['I'](name="base_PsfFlux_npixels", doc="number of pixels that were included in the PSF fit", units="pixel"), Key<I>(offset=456, nElements=1)),
#     (Field['Flag'](name="base_PsfFlux_flag", doc="General Failure Flag"), Key['Flag'](offset=424, bit=11)),
#     (Field['Flag'](name="base_PsfFlux_flag_noGoodPixels", doc="not enough non-rejected pixels in data to attempt the fit"), Key['Flag'](offset=424, bit=12)),
#     (Field['Flag'](name="base_PsfFlux_flag_edge", doc="object was too close to the edge of the image to use the full PSF model"), Key['Flag'](offset=424, bit=13)),
#     (Field['D'](name="ext_trailedSources_Naive_ra", doc="Trail centroid right ascension."), Key<D>(offset=464, nElements=1)),
#     (Field['D'](name="ext_trailedSources_Naive_dec", doc="Trail centroid declination."), Key<D>(offset=472, nElements=1)),
#     (Field['D'](name="ext_trailedSources_Naive_x0", doc="Trail head X coordinate.", units="pixel"), Key<D>(offset=480, nElements=1)),
#     (Field['D'](name="ext_trailedSources_Naive_y0", doc="Trail head Y coordinate.", units="pixel"), Key<D>(offset=488, nElements=1)),
#     (Field['D'](name="ext_trailedSources_Naive_x1", doc="Trail tail X coordinate.", units="pixel"), Key<D>(offset=496, nElements=1)),
#     (Field['D'](name="ext_trailedSources_Naive_y1", doc="Trail tail Y coordinate.", units="pixel"), Key<D>(offset=504, nElements=1)),
#     (Field['D'](name="ext_trailedSources_Naive_flux", doc="Trailed source flux.", units="count"), Key<D>(offset=512, nElements=1)),
#     (Field['D'](name="ext_trailedSources_Naive_length", doc="Trail length.", units="pixel"), Key<D>(offset=520, nElements=1)),
#     (Field['D'](name="ext_trailedSources_Naive_angle", doc="Angle measured from +x-axis."), Key<D>(offset=528, nElements=1)),
#     (Field['D'](name="ext_trailedSources_Naive_x0Err", doc="Trail head X coordinate error.", units="pixel"), Key<D>(offset=536, nElements=1)),
#     (Field['D'](name="ext_trailedSources_Naive_y0Err", doc="Trail head Y coordinate error.", units="pixel"), Key<D>(offset=544, nElements=1)),
#     (Field['D'](name="ext_trailedSources_Naive_x1Err", doc="Trail tail X coordinate error.", units="pixel"), Key<D>(offset=552, nElements=1)),
#     (Field['D'](name="ext_trailedSources_Naive_y1Err", doc="Trail tail Y coordinate error.", units="pixel"), Key<D>(offset=560, nElements=1)),
#     (Field['D'](name="ext_trailedSources_Naive_fluxErr", doc="Trail flux error.", units="count"), Key<D>(offset=568, nElements=1)),
#     (Field['D'](name="ext_trailedSources_Naive_lengthErr", doc="Trail length error.", units="pixel"), Key<D>(offset=576, nElements=1)),
#     (Field['D'](name="ext_trailedSources_Naive_angleErr", doc="Trail angle error."), Key<D>(offset=584, nElements=1)),
#     (Field['Flag'](name="ext_trailedSources_Naive_flag", doc="No trailed-source measured"), Key['Flag'](offset=424, bit=14)),
#     (Field['Flag'](name="ext_trailedSources_Naive_flag_noFlux", doc="No suitable prior flux measurement"), Key['Flag'](offset=424, bit=15)),
#     (Field['Flag'](name="ext_trailedSources_Naive_flag_noConverge", doc="The root finder did not converge"), Key['Flag'](offset=424, bit=16)),
#     (Field['Flag'](name="ext_trailedSources_Naive_flag_noSigma", doc="No PSF width (sigma)"), Key['Flag'](offset=424, bit=17)),
#     (Field['Flag'](name="ext_trailedSources_Naive_flag_edge", doc="Trail contains edge pixels"), Key['Flag'](offset=424, bit=18)),
#     (Field['Flag'](name="ext_trailedSources_Naive_flag_off_image", doc="Trail extends off image"), Key['Flag'](offset=424, bit=19)),
#     (Field['Flag'](name="ext_trailedSources_Naive_flag_nan", doc="One or more trail coordinates are missing"), Key['Flag'](offset=424, bit=20)),
#     (Field['Flag'](name="ext_trailedSources_Naive_flag_suspect_long_trail", doc="Trail length is greater than three times the psf radius"), Key['Flag'](offset=424, bit=21)),
#     (Field['Flag'](name="ext_trailedSources_Naive_flag_shape", doc="Shape flag is set, trail length not calculated"), Key['Flag'](offset=424, bit=22)),
#     (Field['Flag'](name="base_InvalidPsf_flag", doc="Invalid PSF at this location."), Key['Flag'](offset=424, bit=23)),
#     (Field['D'](name="base_PsfFlux_apCorr", doc="aperture correction applied to base_PsfFlux"), Key<D>(offset=592, nElements=1)),
#     (Field['D'](name="base_PsfFlux_apCorrErr", doc="standard deviation of aperture correction applied to base_PsfFlux"), Key<D>(offset=600, nElements=1)),
#     (Field['Flag'](name="base_PsfFlux_flag_apCorr", doc="set if unable to aperture correct base_PsfFlux"), Key['Flag'](offset=424, bit=24)),
#     (Field['D'](name="ip_diffim_forced_PsfFlux_instFlux", doc="Forced PSF flux measured on the direct image.", units="count"), Key<D>(offset=608, nElements=1)),
#     (Field['D'](name="ip_diffim_forced_PsfFlux_instFluxErr", doc="Forced PSF flux error measured on the direct image.", units="count"), Key<D>(offset=616, nElements=1)),
#     (Field['F'](name="ip_diffim_forced_PsfFlux_area", doc="Forced PSF flux effective area of PSF.", units="pixel"), Key<F>(offset=624, nElements=1)),
#     (Field['Flag'](name="ip_diffim_forced_PsfFlux_flag", doc="Forced PSF flux general failure flag."), Key['Flag'](offset=424, bit=25)),
#     (Field['Flag'](name="ip_diffim_forced_PsfFlux_flag_noGoodPixels", doc="Forced PSF flux not enough non-rejected pixels in data to attempt the fit."), Key['Flag'](offset=424, bit=26)),
#     (Field['Flag'](name="ip_diffim_forced_PsfFlux_flag_edge", doc="Forced PSF flux object was too close to the edge of the image to use the full PSF model."), Key['Flag'](offset=424, bit=27)),
#     (Field['L'](name="refMatchId", doc="unique id of reference catalog match"), Key<L>(offset=632, nElements=1)),
#     (Field['L'](name="srcMatchId", doc="unique id of source match"), Key<L>(offset=640, nElements=1)),
#     (Field['Flag'](name="sky_source", doc="Region on image with no detections."), Key['Flag'](offset=424, bit=28)),
#     'base_CircularApertureFlux_flag_badCentroid'->'base_SdssCentroid_flag'
#     'base_PsfFlux_flag_badCentroid'->'base_SdssCentroid_flag'
#     'ext_shapeHSM_HsmPsfMoments_flag_badCentroid'->'base_SdssCentroid_flag'
#     'ext_shapeHSM_HsmSourceMoments_flag_badCentroid'->'base_SdssCentroid_flag'
#     'slot_ApFlux'->'base_CircularApertureFlux_12_0'
#     'slot_Centroid'->'ip_diffim_DipoleFit'
#     'slot_PsfFlux'->'base_PsfFlux'
#     'slot_PsfShape'->'ext_shapeHSM_HsmPsfMoments'
#     'slot_Shape'->'ext_shapeHSM_HsmSourceMoments'
# )

# %%
# Example with a source that nan for everything 


3068394170709180481
# Out:
# [nan] [nan]
# [ 2.42979021         nan  0.89901007  1.86880781  1.02040274         nan
#          nan         nan         nan  0.78302035  0.94995876  4.05733869
#   2.21459579  2.4673213   2.30740869  2.49645517  2.66406942  4.75147192
#   2.33746559  0.71333826  0.59524305  2.27588901  2.71315311         nan
#          nan  2.30043421         nan  0.98863064         nan  2.03046761
#   1.18807498         nan  0.56203557  2.59067533  1.8641115   0.73210196
#   3.71170538  2.53449335         nan  1.12511696  2.59112209  2.59307781
#   0.79964572  2.62560838  1.1386002          nan         nan         nan
#   1.04921573  2.47060147         nan  2.36196454  2.45020053  2.32353091
#   2.24398519  0.85237127  1.01615596  2.81086552  0.97231718  2.08279597
#          nan  1.69048491  2.69418361  2.35985149         nan  0.98291545
#   2.29875376  0.90599679  2.16133844         nan  2.39297222  1.11503434
#          nan  0.96345799         nan  1.34836219 10.98610107  2.73597696
#          nan  2.33676941         nan         nan         nan         nan
#          nan  2.67989304         nan  0.79969908  1.53851199  0.71375658
#   0.41926181         nan  0.89982551         nan  0.86543464  2.43268314
#   0.80863474         nan  2.0332461          nan  2.40920585         nan
#   2.12221086         nan  2.57461083  0.97960364         nan  2.09334781
#   0.88731188         nan  0.73819314         nan  1.75248593  1.10040662
#   3.10554557  0.84030902  2.36688079  2.66451111         nan  2.2981961
#   0.63460288         nan  2.35276168  1.6455184          nan         nan
#   2.51345362  2.48650794  2.53701917  1.19131978  0.83592601  0.77485172
#   2.44298527         nan         nan         nan  2.63589088         nan
#          nan         nan  2.74239035         nan  2.49212583         nan
#   0.76742503         nan         nan  0.90535302  1.40746563  2.50565729
#   1.0276142   0.57954955  1.04433333         nan  2.94200879  2.50958842
#          nan         nan  2.19016511  0.57948878  0.61623625  0.99978273
#   2.45398373         nan         nan  0.46161807         nan         nan
#   1.24127922         nan  1.96215219  0.56620247         nan         nan
#   0.81922811  0.63841079  2.37896051  3.35976489         nan         nan
#   4.0969721   0.93545929  1.17182849  2.66908198  2.34356221  1.69712793
#   3.92247599  0.50322878  3.01464549  1.95214027         nan  2.79818029
#          nan         nan  1.26648711  0.71017436         nan  0.71405963
#          nan         nan  2.39605454  0.66020645         nan         nan
#   1.24675096  1.68810133         nan  1.73201675  0.53040641         nan
#   2.52709836  1.3568563   2.78167565         nan         nan  2.92431941
#   3.04013767         nan  1.99523366  2.47534999  2.02727166         nan
#          nan  2.46770299         nan         nan         nan  3.23493839
#   0.88637966         nan         nan  1.6994058          nan         nan
#          nan         nan         nan 31.15213694         nan         nan
#          nan         nan         nan         nan         nan  1.09664221
#          nan         nan         nan         nan         nan         nan
#          nan         nan         nan         nan         nan         nan
#          nan         nan         nan         nan         nan         nan
#          nan         nan         nan         nan         nan         nan
#          nan         nan         nan         nan         nan         nan
#          nan         nan         nan         nan         nan  3.53231168
#          nan         nan 39.64600519         nan         nan         nan
#          nan         nan         nan         nan         nan         nan
#          nan         nan         nan         nan         nan         nan
#  18.43206606         nan         nan         nan         nan         nan
#          nan         nan         nan         nan 19.82326331 31.03762128
#          nan         nan         nan         nan         nan         nan
#          nan         nan         nan         nan  2.82088833         nan
#   9.17125405         nan         nan         nan         nan         nan
#          nan         nan]

# %%
src_test_via_butler.schema
# Out:
# Schema(
#     (Field['L'](name="id", doc="unique ID"), Key<L>(offset=0, nElements=1)),
#     (Field['Angle'](name="coord_ra", doc="position in ra/dec"), Key<Angle>(offset=8, nElements=1)),
#     (Field['Angle'](name="coord_dec", doc="position in ra/dec"), Key<Angle>(offset=16, nElements=1)),
#     (Field['L'](name="parent", doc="unique ID of parent source"), Key<L>(offset=24, nElements=1)),
#     (Field['F'](name="coord_raErr", doc="1-sigma uncertainty on ra", units="rad"), Key<F>(offset=32, nElements=1)),
#     (Field['F'](name="coord_decErr", doc="1-sigma uncertainty on dec", units="rad"), Key<F>(offset=36, nElements=1)),
#     (Field['F'](name="coord_ra_dec_Cov", doc="uncertainty covariance between ra and dec", units="rad rad"), Key<F>(offset=40, nElements=1)),
#     (Field['Flag'](name="flags_negative", doc="set if source was detected as significantly negative"), Key['Flag'](offset=48, bit=0)),
#     (Field['I'](name="deblend_nChild", doc="Number of children this object has (defaults to 0)"), Key<I>(offset=56, nElements=1)),
#     (Field['Flag'](name="deblend_deblendedAsPsf", doc="Deblender thought this source looked like a PSF"), Key['Flag'](offset=48, bit=1)),
#     (Field['D'](name="deblend_psfCenter_x", doc="If deblended-as-psf, the PSF centroid", units="pixel"), Key<D>(offset=64, nElements=1)),
#     (Field['D'](name="deblend_psfCenter_y", doc="If deblended-as-psf, the PSF centroid", units="pixel"), Key<D>(offset=72, nElements=1)),
#     (Field['D'](name="deblend_psf_instFlux", doc="If deblended-as-psf, the instrumental PSF flux", units="count"), Key<D>(offset=80, nElements=1)),
#     (Field['Flag'](name="deblend_tooManyPeaks", doc="Source had too many peaks; only the brightest were included"), Key['Flag'](offset=48, bit=2)),
#     (Field['Flag'](name="deblend_parentTooBig", doc="Parent footprint covered too many pixels"), Key['Flag'](offset=48, bit=3)),
#     (Field['Flag'](name="deblend_masked", doc="Parent footprint was predominantly masked"), Key['Flag'](offset=48, bit=4)),
#     (Field['Flag'](name="deblend_failed", doc="Deblending failed on source"), Key['Flag'](offset=48, bit=5)),
#     (Field['Flag'](name="deblend_skipped", doc="Deblender skipped this source"), Key['Flag'](offset=48, bit=6)),
#     (Field['Flag'](name="deblend_rampedTemplate", doc="This source was near an image edge and the deblender used "ramp" edge-handling."), Key['Flag'](offset=48, bit=7)),
#     (Field['Flag'](name="deblend_patchedTemplate", doc="This source was near an image edge and the deblender used "patched" edge-handling."), Key['Flag'](offset=48, bit=8)),
#     (Field['Flag'](name="deblend_hasStrayFlux", doc="This source was assigned some stray flux"), Key['Flag'](offset=48, bit=9)),
#     (Field['I'](name="deblend_peak_center_x", doc="Center used to apply constraints in scarlet", units="pixel"), Key<I>(offset=88, nElements=1)),
#     (Field['I'](name="deblend_peak_center_y", doc="Center used to apply constraints in scarlet", units="pixel"), Key<I>(offset=92, nElements=1)),
#     (Field['I'](name="deblend_peakId", doc="ID of the peak in the parent footprint. This is not unique, but the combination of"), Key<I>(offset=96, nElements=1)),
#     (Field['I'](name="deblend_nPeaks", doc="Number of initial peaks in the blend. This includes peaks that may have been culled during deblending or failed to deblend"), Key<I>(offset=100, nElements=1)),
#     (Field['I'](name="deblend_parentNPeaks", doc="Same as deblend_n_peaks, but the number of peaks in the parent footprint"), Key<I>(offset=104, nElements=1)),
#     (Field['Flag'](name="detect_isPrimary", doc="True if source has no children and is not a sky source."), Key['Flag'](offset=48, bit=10)),
#     (Field['Flag'](name="detect_isDeblendedSource", doc="True if source has no children and is not a sky source. and is either an unblended isolated source or a deblended child from a parent with"), Key['Flag'](offset=48, bit=11)),
#     (Field['Flag'](name="detect_fromBlend", doc="This source is deblended from a parent with more than one child."), Key['Flag'](offset=48, bit=12)),
#     (Field['Flag'](name="detect_isIsolated", doc="This source is not a part of a blend."), Key['Flag'](offset=48, bit=13)),
#     (Field['D'](name="base_SdssCentroid_x", doc="centroid from Sdss Centroid algorithm", units="pixel"), Key<D>(offset=112, nElements=1)),
#     (Field['D'](name="base_SdssCentroid_y", doc="centroid from Sdss Centroid algorithm", units="pixel"), Key<D>(offset=120, nElements=1)),
#     (Field['F'](name="base_SdssCentroid_xErr", doc="1-sigma uncertainty on x position", units="pixel"), Key<F>(offset=128, nElements=1)),
#     (Field['F'](name="base_SdssCentroid_yErr", doc="1-sigma uncertainty on y position", units="pixel"), Key<F>(offset=132, nElements=1)),
#     (Field['Flag'](name="base_SdssCentroid_flag", doc="General Failure Flag"), Key['Flag'](offset=48, bit=14)),
#     (Field['Flag'](name="base_SdssCentroid_flag_edge", doc="Object too close to edge; peak used."), Key['Flag'](offset=48, bit=15)),
#     (Field['Flag'](name="base_SdssCentroid_flag_noSecondDerivative", doc="Vanishing second derivative"), Key['Flag'](offset=48, bit=16)),
#     (Field['Flag'](name="base_SdssCentroid_flag_almostNoSecondDerivative", doc="Almost vanishing second derivative"), Key['Flag'](offset=48, bit=17)),
#     (Field['Flag'](name="base_SdssCentroid_flag_notAtMaximum", doc="Object is not at a maximum"), Key['Flag'](offset=48, bit=18)),
#     (Field['Flag'](name="base_SdssCentroid_flag_near_edge", doc="Object close to edge; fallback kernel used."), Key['Flag'](offset=48, bit=19)),
#     (Field['Flag'](name="base_SdssCentroid_flag_resetToPeak", doc="set if CentroidChecker reset the centroid"), Key['Flag'](offset=48, bit=20)),
#     (Field['Flag'](name="base_SdssCentroid_flag_badError", doc="Error on x and/or y position is NaN"), Key['Flag'](offset=48, bit=21)),
#     (Field['D'](name="ip_diffim_DipoleFit_pos_instFlux", doc="Dipole positive lobe instrumental flux.", units="count"), Key<D>(offset=136, nElements=1)),
#     (Field['D'](name="ip_diffim_DipoleFit_pos_instFluxErr", doc="1-sigma instFlux uncertainty", units="count"), Key<D>(offset=144, nElements=1)),
#     (Field['D'](name="ip_diffim_DipoleFit_neg_instFlux", doc="Dipole negative lobe instrumental flux.", units="count"), Key<D>(offset=152, nElements=1)),
#     (Field['D'](name="ip_diffim_DipoleFit_neg_instFluxErr", doc="1-sigma instFlux uncertainty", units="count"), Key<D>(offset=160, nElements=1)),
#     (Field['D'](name="ip_diffim_DipoleFit_instFlux", doc="Dipole overall instrumental flux (mean of absolute value of positive and negative lobes).", units="count"), Key<D>(offset=168, nElements=1)),
#     (Field['D'](name="ip_diffim_DipoleFit_instFluxErr", doc="1-sigma instFlux uncertainty", units="count"), Key<D>(offset=176, nElements=1)),
#     (Field['D'](name="ip_diffim_DipoleFit_pos_x", doc="Dipole positive lobe centroid position.", units="pixel"), Key<D>(offset=184, nElements=1)),
#     (Field['D'](name="ip_diffim_DipoleFit_pos_y", doc="Dipole positive lobe centroid position.", units="pixel"), Key<D>(offset=192, nElements=1)),
#     (Field['D'](name="ip_diffim_DipoleFit_neg_x", doc="Dipole negative lobe centroid position.", units="pixel"), Key<D>(offset=200, nElements=1)),
#     (Field['D'](name="ip_diffim_DipoleFit_neg_y", doc="Dipole negative lobe centroid position.", units="pixel"), Key<D>(offset=208, nElements=1)),
#     (Field['D'](name="ip_diffim_DipoleFit_x", doc="Dipole centroid position.", units="pixel"), Key<D>(offset=216, nElements=1)),
#     (Field['D'](name="ip_diffim_DipoleFit_y", doc="Dipole centroid position.", units="pixel"), Key<D>(offset=224, nElements=1)),
#     (Field['F'](name="ip_diffim_DipoleFit_xErr", doc="1-sigma uncertainty on x position", units="pixel"), Key<F>(offset=232, nElements=1)),
#     (Field['F'](name="ip_diffim_DipoleFit_yErr", doc="1-sigma uncertainty on y position", units="pixel"), Key<F>(offset=236, nElements=1)),
#     (Field['D'](name="ip_diffim_DipoleFit_orientation", doc="Dipole orientation.  Convention is CCW from +x on image.", units="rad"), Key<D>(offset=240, nElements=1)),
#     (Field['D'](name="ip_diffim_DipoleFit_separation", doc="Pixel separation between positive and negative lobes of dipole", units="pixel"), Key<D>(offset=248, nElements=1)),
#     (Field['D'](name="ip_diffim_DipoleFit_chi2dof", doc="Chi2 per degree of freedom (chi2/(nData-nVariables)) of dipole fit"), Key<D>(offset=256, nElements=1)),
#     (Field['L'](name="ip_diffim_DipoleFit_nData", doc="Number of data points in the dipole fit"), Key<L>(offset=264, nElements=1)),
#     (Field['D'](name="ip_diffim_DipoleFit_signalToNoise", doc="Estimated signal-to-noise of dipole fit"), Key<D>(offset=272, nElements=1)),
#     (Field['Flag'](name="ip_diffim_DipoleFit_flag_classification", doc="Flag indicating diaSource is classified as a dipole"), Key['Flag'](offset=48, bit=22)),
#     (Field['Flag'](name="ip_diffim_DipoleFit_flag_classificationAttempted", doc="Flag indicating diaSource was attempted to be classified as a dipole"), Key['Flag'](offset=48, bit=23)),
#     (Field['Flag'](name="ip_diffim_DipoleFit_flag", doc="General failure flag for dipole fit"), Key['Flag'](offset=48, bit=24)),
#     (Field['Flag'](name="ip_diffim_DipoleFit_flag_edge", doc="Flag set when dipole is too close to edge of image"), Key['Flag'](offset=48, bit=25)),
#     (Field['Flag'](name="ext_shapeHSM_HsmPsfMoments_flag", doc="General failure flag, set if anything went wrong"), Key['Flag'](offset=48, bit=26)),
#     (Field['Flag'](name="ext_shapeHSM_HsmPsfMoments_flag_no_pixels", doc="No pixels to measure"), Key['Flag'](offset=48, bit=27)),
#     (Field['Flag'](name="ext_shapeHSM_HsmPsfMoments_flag_not_contained", doc="Center not contained in footprint bounding box"), Key['Flag'](offset=48, bit=28)),
#     (Field['Flag'](name="ext_shapeHSM_HsmPsfMoments_flag_parent_source", doc="Parent source, ignored"), Key['Flag'](offset=48, bit=29)),
#     (Field['Flag'](name="ext_shapeHSM_HsmPsfMoments_flag_galsim", doc="GalSim failure"), Key['Flag'](offset=48, bit=30)),
#     (Field['Flag'](name="ext_shapeHSM_HsmPsfMoments_flag_invalid_param", doc="Invalid combination of moments"), Key['Flag'](offset=48, bit=31)),
#     (Field['Flag'](name="ext_shapeHSM_HsmPsfMoments_flag_edge", doc="Variance undefined outside image edge"), Key['Flag'](offset=48, bit=32)),
#     (Field['Flag'](name="ext_shapeHSM_HsmPsfMoments_flag_no_psf", doc="Exposure lacks PSF"), Key['Flag'](offset=48, bit=33)),
#     (Field['D'](name="ext_shapeHSM_HsmPsfMoments_x", doc="Centroid of the PSF via the HSM shape algorithm", units="pixel"), Key<D>(offset=280, nElements=1)),
#     (Field['D'](name="ext_shapeHSM_HsmPsfMoments_y", doc="Centroid of the PSF via the HSM shape algorithm", units="pixel"), Key<D>(offset=288, nElements=1)),
#     (Field['D'](name="ext_shapeHSM_HsmPsfMoments_xx", doc="Adaptive moments of the PSF via the HSM shape algorithm", units="pixel^2"), Key<D>(offset=296, nElements=1)),
#     (Field['D'](name="ext_shapeHSM_HsmPsfMoments_yy", doc="Adaptive moments of the PSF via the HSM shape algorithm", units="pixel^2"), Key<D>(offset=304, nElements=1)),
#     (Field['D'](name="ext_shapeHSM_HsmPsfMoments_xy", doc="Adaptive moments of the PSF via the HSM shape algorithm", units="pixel^2"), Key<D>(offset=312, nElements=1)),
#     (Field['Flag'](name="ext_shapeHSM_HsmSourceMoments_flag", doc="General failure flag, set if anything went wrong"), Key['Flag'](offset=48, bit=34)),
#     (Field['Flag'](name="ext_shapeHSM_HsmSourceMoments_flag_no_pixels", doc="No pixels to measure"), Key['Flag'](offset=48, bit=35)),
#     (Field['Flag'](name="ext_shapeHSM_HsmSourceMoments_flag_not_contained", doc="Center not contained in footprint bounding box"), Key['Flag'](offset=48, bit=36)),
#     (Field['Flag'](name="ext_shapeHSM_HsmSourceMoments_flag_parent_source", doc="Parent source, ignored"), Key['Flag'](offset=48, bit=37)),
#     (Field['Flag'](name="ext_shapeHSM_HsmSourceMoments_flag_galsim", doc="GalSim failure"), Key['Flag'](offset=48, bit=38)),
#     (Field['Flag'](name="ext_shapeHSM_HsmSourceMoments_flag_invalid_param", doc="Invalid combination of moments"), Key['Flag'](offset=48, bit=39)),
#     (Field['Flag'](name="ext_shapeHSM_HsmSourceMoments_flag_edge", doc="Variance undefined outside image edge"), Key['Flag'](offset=48, bit=40)),
#     (Field['Flag'](name="ext_shapeHSM_HsmSourceMoments_flag_no_psf", doc="Exposure lacks PSF"), Key['Flag'](offset=48, bit=41)),
#     (Field['D'](name="ext_shapeHSM_HsmSourceMoments_x", doc="Centroid of the source via the HSM shape algorithm", units="pixel"), Key<D>(offset=320, nElements=1)),
#     (Field['D'](name="ext_shapeHSM_HsmSourceMoments_y", doc="Centroid of the source via the HSM shape algorithm", units="pixel"), Key<D>(offset=328, nElements=1)),
#     (Field['D'](name="ext_shapeHSM_HsmSourceMoments_xx", doc="Adaptive moments of the source via the HSM shape algorithm", units="pixel^2"), Key<D>(offset=336, nElements=1)),
#     (Field['D'](name="ext_shapeHSM_HsmSourceMoments_yy", doc="Adaptive moments of the source via the HSM shape algorithm", units="pixel^2"), Key<D>(offset=344, nElements=1)),
#     (Field['D'](name="ext_shapeHSM_HsmSourceMoments_xy", doc="Adaptive moments of the source via the HSM shape algorithm", units="pixel^2"), Key<D>(offset=352, nElements=1)),
#     (Field['D'](name="base_CircularApertureFlux_12_0_instFlux", doc="instFlux within 12.000000-pixel aperture", units="count"), Key<D>(offset=360, nElements=1)),
#     (Field['D'](name="base_CircularApertureFlux_12_0_instFluxErr", doc="1-sigma instFlux uncertainty", units="count"), Key<D>(offset=368, nElements=1)),
#     (Field['Flag'](name="base_CircularApertureFlux_12_0_flag", doc="General Failure Flag"), Key['Flag'](offset=48, bit=42)),
#     (Field['Flag'](name="base_CircularApertureFlux_12_0_flag_apertureTruncated", doc="aperture did not fit within measurement image"), Key['Flag'](offset=48, bit=43)),
#     (Field['Flag'](name="base_LocalPhotoCalib_flag", doc="Set for any fatal failure"), Key['Flag'](offset=48, bit=44)),
#     (Field['D'](name="base_LocalPhotoCalib", doc="Local approximation of the PhotoCalib calibration factor at the location of the src."), Key<D>(offset=376, nElements=1)),
#     (Field['D'](name="base_LocalPhotoCalibErr", doc="Error on the local approximation of the PhotoCalib calibration factor at the location of the src."), Key<D>(offset=384, nElements=1)),
#     (Field['Flag'](name="base_LocalWcs_flag", doc="Set for any fatal failure"), Key['Flag'](offset=48, bit=45)),
#     (Field['D'](name="base_LocalWcs_CDMatrix_1_1", doc="(1, 1) element of the CDMatrix for the linear approximation of the WCS at the src location. Gives units in radians."), Key<D>(offset=392, nElements=1)),
#     (Field['D'](name="base_LocalWcs_CDMatrix_1_2", doc="(1, 2) element of the CDMatrix for the linear approximation of the WCS at the src location. Gives units in radians."), Key<D>(offset=400, nElements=1)),
#     (Field['D'](name="base_LocalWcs_CDMatrix_2_1", doc="(2, 1) element of the CDMatrix for the linear approximation of the WCS at the src location. Gives units in radians."), Key<D>(offset=408, nElements=1)),
#     (Field['D'](name="base_LocalWcs_CDMatrix_2_2", doc="(2, 2) element of the CDMatrix for the linear approximation of the WCS at the src location. Gives units in radians."), Key<D>(offset=416, nElements=1)),
#     (Field['Flag'](name="base_PixelFlags_flag", doc="General failure flag, set if anything went wrong"), Key['Flag'](offset=48, bit=46)),
#     (Field['Flag'](name="base_PixelFlags_flag_offimage", doc="Source center is off image"), Key['Flag'](offset=48, bit=47)),
#     (Field['Flag'](name="base_PixelFlags_flag_edge", doc="Source is outside usable exposure region (masked EDGE or NO_DATA, or centroid off image)."), Key['Flag'](offset=48, bit=48)),
#     (Field['Flag'](name="base_PixelFlags_flag_interpolated", doc="Interpolated pixel in the Source footprint"), Key['Flag'](offset=48, bit=49)),
#     (Field['Flag'](name="base_PixelFlags_flag_saturated", doc="Saturated pixel in the Source footprint"), Key['Flag'](offset=48, bit=50)),
#     (Field['Flag'](name="base_PixelFlags_flag_cr", doc="Cosmic ray in the Source footprint"), Key['Flag'](offset=48, bit=51)),
#     (Field['Flag'](name="base_PixelFlags_flag_bad", doc="Bad pixel in the Source footprint"), Key['Flag'](offset=48, bit=52)),
#     (Field['Flag'](name="base_PixelFlags_flag_suspect", doc="Source''s footprint includes suspect pixels"), Key['Flag'](offset=48, bit=53)),
#     (Field['Flag'](name="base_PixelFlags_flag_edgeCenter", doc="EDGE or NO_DATA Pixel in the 3x3 region around the centroid."), Key['Flag'](offset=48, bit=54)),
#     (Field['Flag'](name="base_PixelFlags_flag_interpolatedCenter", doc="Interpolated pixel in the 3x3 region around the centroid."), Key['Flag'](offset=48, bit=55)),
#     (Field['Flag'](name="base_PixelFlags_flag_saturatedCenter", doc="Saturated pixel in the 3x3 region around the centroid."), Key['Flag'](offset=48, bit=56)),
#     (Field['Flag'](name="base_PixelFlags_flag_crCenter", doc="Cosmic ray in the 3x3 region around the centroid."), Key['Flag'](offset=48, bit=57)),
#     (Field['Flag'](name="base_PixelFlags_flag_badCenter", doc="Bad pixel in the 3x3 region around the centroid"), Key['Flag'](offset=48, bit=58)),
#     (Field['Flag'](name="base_PixelFlags_flag_suspectCenter", doc="Suspect pixel in the 3x3 region around the centroid."), Key['Flag'](offset=48, bit=59)),
#     (Field['Flag'](name="base_PixelFlags_flag_edgeCenterAll", doc="All pixels in the 3x3 region around the centroid are marked EDGE or NO_DATA."), Key['Flag'](offset=48, bit=60)),
#     (Field['Flag'](name="base_PixelFlags_flag_interpolatedCenterAll", doc="All pixels in the 3x3 region around the centroid are interpolated."), Key['Flag'](offset=48, bit=61)),
#     (Field['Flag'](name="base_PixelFlags_flag_saturatedCenterAll", doc="All pixels in the 3x3 region around the centroid are saturated."), Key['Flag'](offset=48, bit=62)),
#     (Field['Flag'](name="base_PixelFlags_flag_crCenterAll", doc="All pixels in the 3x3 region around the centroid have the cosmic ray mask bit."), Key['Flag'](offset=48, bit=63)),
#     (Field['Flag'](name="base_PixelFlags_flag_badCenterAll", doc="All pixels in the 3x3 region around the centroid are bad."), Key['Flag'](offset=424, bit=0)),
#     (Field['Flag'](name="base_PixelFlags_flag_suspectCenterAll", doc="All pixels in the 3x3 region around the centroid are suspect."), Key['Flag'](offset=424, bit=1)),
#     (Field['Flag'](name="base_PixelFlags_flag_streakCenter", doc="3x3 region around the centroid has STREAK pixels"), Key['Flag'](offset=424, bit=2)),
#     (Field['Flag'](name="base_PixelFlags_flag_injectedCenter", doc="3x3 region around the centroid has INJECTED pixels"), Key['Flag'](offset=424, bit=3)),
#     (Field['Flag'](name="base_PixelFlags_flag_injected_templateCenter", doc="3x3 region around the centroid has INJECTED_TEMPLATE pixels"), Key['Flag'](offset=424, bit=4)),
#     (Field['Flag'](name="base_PixelFlags_flag_streakCenterAll", doc="All pixels in the 3x3 region around the source centroid are STREAK pixels"), Key['Flag'](offset=424, bit=5)),
#     (Field['Flag'](name="base_PixelFlags_flag_injectedCenterAll", doc="All pixels in the 3x3 region around the source centroid are INJECTED pixels"), Key['Flag'](offset=424, bit=6)),
#     (Field['Flag'](name="base_PixelFlags_flag_injected_templateCenterAll", doc="All pixels in the 3x3 region around the source centroid are INJECTED_TEMPLATE pixels"), Key['Flag'](offset=424, bit=7)),
#     (Field['Flag'](name="base_PixelFlags_flag_streak", doc="Source footprint includes STREAK pixels"), Key['Flag'](offset=424, bit=8)),
#     (Field['Flag'](name="base_PixelFlags_flag_injected", doc="Source footprint includes INJECTED pixels"), Key['Flag'](offset=424, bit=9)),
#     (Field['Flag'](name="base_PixelFlags_flag_injected_template", doc="Source footprint includes INJECTED_TEMPLATE pixels"), Key['Flag'](offset=424, bit=10)),
#     (Field['D'](name="base_PsfFlux_instFlux", doc="instFlux derived from linear least-squares fit of PSF model", units="count"), Key<D>(offset=432, nElements=1)),
#     (Field['D'](name="base_PsfFlux_instFluxErr", doc="1-sigma instFlux uncertainty", units="count"), Key<D>(offset=440, nElements=1)),
#     (Field['F'](name="base_PsfFlux_area", doc="effective area of PSF", units="pixel"), Key<F>(offset=448, nElements=1)),
#     (Field['F'](name="base_PsfFlux_chi2", doc="chi2 of the fitted PSF"), Key<F>(offset=452, nElements=1)),
#     (Field['I'](name="base_PsfFlux_npixels", doc="number of pixels that were included in the PSF fit", units="pixel"), Key<I>(offset=456, nElements=1)),
#     (Field['Flag'](name="base_PsfFlux_flag", doc="General Failure Flag"), Key['Flag'](offset=424, bit=11)),
#     (Field['Flag'](name="base_PsfFlux_flag_noGoodPixels", doc="not enough non-rejected pixels in data to attempt the fit"), Key['Flag'](offset=424, bit=12)),
#     (Field['Flag'](name="base_PsfFlux_flag_edge", doc="object was too close to the edge of the image to use the full PSF model"), Key['Flag'](offset=424, bit=13)),
#     (Field['D'](name="ext_trailedSources_Naive_ra", doc="Trail centroid right ascension."), Key<D>(offset=464, nElements=1)),
#     (Field['D'](name="ext_trailedSources_Naive_dec", doc="Trail centroid declination."), Key<D>(offset=472, nElements=1)),
#     (Field['D'](name="ext_trailedSources_Naive_x0", doc="Trail head X coordinate.", units="pixel"), Key<D>(offset=480, nElements=1)),
#     (Field['D'](name="ext_trailedSources_Naive_y0", doc="Trail head Y coordinate.", units="pixel"), Key<D>(offset=488, nElements=1)),
#     (Field['D'](name="ext_trailedSources_Naive_x1", doc="Trail tail X coordinate.", units="pixel"), Key<D>(offset=496, nElements=1)),
#     (Field['D'](name="ext_trailedSources_Naive_y1", doc="Trail tail Y coordinate.", units="pixel"), Key<D>(offset=504, nElements=1)),
#     (Field['D'](name="ext_trailedSources_Naive_flux", doc="Trailed source flux.", units="count"), Key<D>(offset=512, nElements=1)),
#     (Field['D'](name="ext_trailedSources_Naive_length", doc="Trail length.", units="pixel"), Key<D>(offset=520, nElements=1)),
#     (Field['D'](name="ext_trailedSources_Naive_angle", doc="Angle measured from +x-axis."), Key<D>(offset=528, nElements=1)),
#     (Field['D'](name="ext_trailedSources_Naive_x0Err", doc="Trail head X coordinate error.", units="pixel"), Key<D>(offset=536, nElements=1)),
#     (Field['D'](name="ext_trailedSources_Naive_y0Err", doc="Trail head Y coordinate error.", units="pixel"), Key<D>(offset=544, nElements=1)),
#     (Field['D'](name="ext_trailedSources_Naive_x1Err", doc="Trail tail X coordinate error.", units="pixel"), Key<D>(offset=552, nElements=1)),
#     (Field['D'](name="ext_trailedSources_Naive_y1Err", doc="Trail tail Y coordinate error.", units="pixel"), Key<D>(offset=560, nElements=1)),
#     (Field['D'](name="ext_trailedSources_Naive_fluxErr", doc="Trail flux error.", units="count"), Key<D>(offset=568, nElements=1)),
#     (Field['D'](name="ext_trailedSources_Naive_lengthErr", doc="Trail length error.", units="pixel"), Key<D>(offset=576, nElements=1)),
#     (Field['D'](name="ext_trailedSources_Naive_angleErr", doc="Trail angle error."), Key<D>(offset=584, nElements=1)),
#     (Field['Flag'](name="ext_trailedSources_Naive_flag", doc="No trailed-source measured"), Key['Flag'](offset=424, bit=14)),
#     (Field['Flag'](name="ext_trailedSources_Naive_flag_noFlux", doc="No suitable prior flux measurement"), Key['Flag'](offset=424, bit=15)),
#     (Field['Flag'](name="ext_trailedSources_Naive_flag_noConverge", doc="The root finder did not converge"), Key['Flag'](offset=424, bit=16)),
#     (Field['Flag'](name="ext_trailedSources_Naive_flag_noSigma", doc="No PSF width (sigma)"), Key['Flag'](offset=424, bit=17)),
#     (Field['Flag'](name="ext_trailedSources_Naive_flag_edge", doc="Trail contains edge pixels"), Key['Flag'](offset=424, bit=18)),
#     (Field['Flag'](name="ext_trailedSources_Naive_flag_off_image", doc="Trail extends off image"), Key['Flag'](offset=424, bit=19)),
#     (Field['Flag'](name="ext_trailedSources_Naive_flag_nan", doc="One or more trail coordinates are missing"), Key['Flag'](offset=424, bit=20)),
#     (Field['Flag'](name="ext_trailedSources_Naive_flag_suspect_long_trail", doc="Trail length is greater than three times the psf radius"), Key['Flag'](offset=424, bit=21)),
#     (Field['Flag'](name="ext_trailedSources_Naive_flag_shape", doc="Shape flag is set, trail length not calculated"), Key['Flag'](offset=424, bit=22)),
#     (Field['Flag'](name="base_InvalidPsf_flag", doc="Invalid PSF at this location."), Key['Flag'](offset=424, bit=23)),
#     (Field['D'](name="base_PsfFlux_apCorr", doc="aperture correction applied to base_PsfFlux"), Key<D>(offset=592, nElements=1)),
#     (Field['D'](name="base_PsfFlux_apCorrErr", doc="standard deviation of aperture correction applied to base_PsfFlux"), Key<D>(offset=600, nElements=1)),
#     (Field['Flag'](name="base_PsfFlux_flag_apCorr", doc="set if unable to aperture correct base_PsfFlux"), Key['Flag'](offset=424, bit=24)),
#     (Field['D'](name="ip_diffim_forced_PsfFlux_instFlux", doc="Forced PSF flux measured on the direct image.", units="count"), Key<D>(offset=608, nElements=1)),
#     (Field['D'](name="ip_diffim_forced_PsfFlux_instFluxErr", doc="Forced PSF flux error measured on the direct image.", units="count"), Key<D>(offset=616, nElements=1)),
#     (Field['F'](name="ip_diffim_forced_PsfFlux_area", doc="Forced PSF flux effective area of PSF.", units="pixel"), Key<F>(offset=624, nElements=1)),
#     (Field['Flag'](name="ip_diffim_forced_PsfFlux_flag", doc="Forced PSF flux general failure flag."), Key['Flag'](offset=424, bit=25)),
#     (Field['Flag'](name="ip_diffim_forced_PsfFlux_flag_noGoodPixels", doc="Forced PSF flux not enough non-rejected pixels in data to attempt the fit."), Key['Flag'](offset=424, bit=26)),
#     (Field['Flag'](name="ip_diffim_forced_PsfFlux_flag_edge", doc="Forced PSF flux object was too close to the edge of the image to use the full PSF model."), Key['Flag'](offset=424, bit=27)),
#     (Field['L'](name="refMatchId", doc="unique id of reference catalog match"), Key<L>(offset=632, nElements=1)),
#     (Field['L'](name="srcMatchId", doc="unique id of source match"), Key<L>(offset=640, nElements=1)),
#     (Field['Flag'](name="sky_source", doc="Region on image with no detections."), Key['Flag'](offset=424, bit=28)),
#     'base_CircularApertureFlux_flag_badCentroid'->'base_SdssCentroid_flag'
#     'base_PsfFlux_flag_badCentroid'->'base_SdssCentroid_flag'
#     'ext_shapeHSM_HsmPsfMoments_flag_badCentroid'->'base_SdssCentroid_flag'
#     'ext_shapeHSM_HsmSourceMoments_flag_badCentroid'->'base_SdssCentroid_flag'
#     'slot_ApFlux'->'base_CircularApertureFlux_12_0'
#     'slot_Centroid'->'ip_diffim_DipoleFit'
#     'slot_PsfFlux'->'base_PsfFlux'
#     'slot_PsfShape'->'ext_shapeHSM_HsmPsfMoments'
#     'slot_Shape'->'ext_shapeHSM_HsmSourceMoments'
# )

# %%
# creating a minimal example
# this is an example where xErr and yErr are NaN, but raErr and decErr are not NaN
import lsst.daf.butler as dafButler

repo = 'embargo_or4'
instrument = 'LSSTComCamSim'
pp_collections = ['LSSTComCamSim/prompt/output-2024-06-25', 'LSSTComCamSim/prompt/output-2024-06-26', 'LSSTComCamSim/prompt/output-2024-06-27']
pp_butler = dafButler.Butler(repo, collections=pp_collections, instrument=instrument)

data1= {'detector': 3, 'visit': 7024062500190}
src_via_butler = pp_butler.get('goodSeeingDiff_assocDiaSrc', dataId=data1)
src_cand_via_butler = pp_butler.get('goodSeeingDiff_candidateDiaSrc', dataId=data1)
src_prefilter_via_butler = pp_butler.get('goodSeeingDiff_diaSrc', dataId=data1)

single_butler_src = src_via_butler[src_via_butler['diaSourceId'] == 3068394109518479458]
single_butler_cand_src = src_cand_via_butler[src_cand_via_butler['id'] == 3068394109518479458]
single_butler_prefilter_src = src_prefilter_via_butler[src_prefilter_via_butler['id'] == 3068394109518479458]

single_butler_src[['diaSourceId', 'ra', 'raErr', 'dec', 'decErr', 'x', 'xErr', 'y', 'yErr', 'psfFlux', 'band', 'isDipole', 'centroid_flag', 'apFlux_flag', 'psfFlux_flag', 'forced_PsfFlux_flag', 'shape_flag']]

# %% [markdown]
# ## Statistical analysis

# %%
list(obj4_field_nan.columns)
# Out:
# ['diaObjectId',
#  'validityStart',
#  'validityEnd',
#  'ra',
#  'raErr',
#  'dec',
#  'decErr',
#  'ra_dec_Cov',
#  'radecMjdTai',
#  'pmRa',
#  'pmRaErr',
#  'pmDec',
#  'pmDecErr',
#  'parallax',
#  'parallaxErr',
#  'pmRa_pmDec_Cov',
#  'pmRa_parallax_Cov',
#  'pmDec_parallax_Cov',
#  'pmParallaxLnL',
#  'pmParallaxChi2',
#  'pmParallaxNdata',
#  'u_psfFluxMean',
#  'u_psfFluxMeanErr',
#  'u_psfFluxSigma',
#  'u_psfFluxChi2',
#  'u_psfFluxNdata',
#  'u_fpFluxMean',
#  'u_fpFluxMeanErr',
#  'u_fpFluxSigma',
#  'g_psfFluxMean',
#  'g_psfFluxMeanErr',
#  'g_psfFluxSigma',
#  'g_psfFluxChi2',
#  'g_psfFluxNdata',
#  'g_fpFluxMean',
#  'g_fpFluxMeanErr',
#  'g_fpFluxSigma',
#  'r_psfFluxMean',
#  'r_psfFluxMeanErr',
#  'r_psfFluxSigma',
#  'r_psfFluxChi2',
#  'r_psfFluxNdata',
#  'r_fpFluxMean',
#  'r_fpFluxMeanErr',
#  'r_fpFluxSigma',
#  'i_psfFluxMean',
#  'i_psfFluxMeanErr',
#  'i_psfFluxSigma',
#  'i_psfFluxChi2',
#  'i_psfFluxNdata',
#  'i_fpFluxMean',
#  'i_fpFluxMeanErr',
#  'i_fpFluxSigma',
#  'z_psfFluxMean',
#  'z_psfFluxMeanErr',
#  'z_psfFluxSigma',
#  'z_psfFluxChi2',
#  'z_psfFluxNdata',
#  'z_fpFluxMean',
#  'z_fpFluxMeanErr',
#  'z_fpFluxSigma',
#  'y_psfFluxMean',
#  'y_psfFluxMeanErr',
#  'y_psfFluxSigma',
#  'y_psfFluxChi2',
#  'y_psfFluxNdata',
#  'y_fpFluxMean',
#  'y_fpFluxMeanErr',
#  'y_fpFluxSigma',
#  'nearbyObj1',
#  'nearbyObj1Dist',
#  'nearbyObj1LnP',
#  'nearbyObj2',
#  'nearbyObj2Dist',
#  'nearbyObj2LnP',
#  'nearbyObj3',
#  'nearbyObj3Dist',
#  'nearbyObj3LnP',
#  'nearbyExtObj1',
#  'nearbyExtObj1Sep',
#  'nearbyExtObj2',
#  'nearbyExtObj2Sep',
#  'nearbyExtObj3',
#  'nearbyExtObj3Sep',
#  'nearbyLowzGal',
#  'nearbyLowzGalSep',
#  'u_scienceFluxMean',
#  'u_scienceFluxMeanErr',
#  'u_scienceFluxSigma',
#  'g_scienceFluxMean',
#  'g_scienceFluxMeanErr',
#  'g_scienceFluxSigma',
#  'r_scienceFluxMean',
#  'r_scienceFluxMeanErr',
#  'r_scienceFluxSigma',
#  'i_scienceFluxMean',
#  'i_scienceFluxMeanErr',
#  'i_scienceFluxSigma',
#  'z_scienceFluxMean',
#  'z_scienceFluxMeanErr',
#  'z_scienceFluxSigma',
#  'y_scienceFluxMean',
#  'y_scienceFluxMeanErr',
#  'y_scienceFluxSigma',
#  'u_psfFluxMAD',
#  'u_psfFluxSkew',
#  'u_psfFluxPercentile05',
#  'u_psfFluxPercentile25',
#  'u_psfFluxPercentile50',
#  'u_psfFluxPercentile75',
#  'u_psfFluxPercentile95',
#  'u_psfFluxMin',
#  'u_psfFluxMax',
#  'u_psfFluxStetsonJ',
#  'u_psfFluxLinearSlope',
#  'u_psfFluxLinearIntercept',
#  'u_psfFluxMaxSlope',
#  'u_psfFluxErrMean',
#  'g_psfFluxMAD',
#  'g_psfFluxSkew',
#  'g_psfFluxPercentile05',
#  'g_psfFluxPercentile25',
#  'g_psfFluxPercentile50',
#  'g_psfFluxPercentile75',
#  'g_psfFluxPercentile95',
#  'g_psfFluxMin',
#  'g_psfFluxMax',
#  'g_psfFluxStetsonJ',
#  'g_psfFluxLinearSlope',
#  'g_psfFluxLinearIntercept',
#  'g_psfFluxMaxSlope',
#  'g_psfFluxErrMean',
#  'r_psfFluxMAD',
#  'r_psfFluxSkew',
#  'r_psfFluxPercentile05',
#  'r_psfFluxPercentile25',
#  'r_psfFluxPercentile50',
#  'r_psfFluxPercentile75',
#  'r_psfFluxPercentile95',
#  'r_psfFluxMin',
#  'r_psfFluxMax',
#  'r_psfFluxStetsonJ',
#  'r_psfFluxLinearSlope',
#  'r_psfFluxLinearIntercept',
#  'r_psfFluxMaxSlope',
#  'r_psfFluxErrMean',
#  'i_psfFluxMAD',
#  'i_psfFluxSkew',
#  'i_psfFluxPercentile05',
#  'i_psfFluxPercentile25',
#  'i_psfFluxPercentile50',
#  'i_psfFluxPercentile75',
#  'i_psfFluxPercentile95',
#  'i_psfFluxMin',
#  'i_psfFluxMax',
#  'i_psfFluxStetsonJ',
#  'i_psfFluxLinearSlope',
#  'i_psfFluxLinearIntercept',
#  'i_psfFluxMaxSlope',
#  'i_psfFluxErrMean',
#  'z_psfFluxMAD',
#  'z_psfFluxSkew',
#  'z_psfFluxPercentile05',
#  'z_psfFluxPercentile25',
#  'z_psfFluxPercentile50',
#  'z_psfFluxPercentile75',
#  'z_psfFluxPercentile95',
#  'z_psfFluxMin',
#  'z_psfFluxMax',
#  'z_psfFluxStetsonJ',
#  'z_psfFluxLinearSlope',
#  'z_psfFluxLinearIntercept',
#  'z_psfFluxMaxSlope',
#  'z_psfFluxErrMean',
#  'y_psfFluxMAD',
#  'y_psfFluxSkew',
#  'y_psfFluxPercentile05',
#  'y_psfFluxPercentile25',
#  'y_psfFluxPercentile50',
#  'y_psfFluxPercentile75',
#  'y_psfFluxPercentile95',
#  'y_psfFluxMin',
#  'y_psfFluxMax',
#  'y_psfFluxStetsonJ',
#  'y_psfFluxLinearSlope',
#  'y_psfFluxLinearIntercept',
#  'y_psfFluxMaxSlope',
#  'y_psfFluxErrMean',
#  'lastNonForcedSource',
#  'nDiaSources']

# %%
obj4_field_nan_min_max = obj4_field_nan[['diaObjectId','g_psfFluxMean', 'g_psfFluxMin', 'g_psfFluxMax', 'r_psfFluxMean', 'r_psfFluxMin', 'r_psfFluxMax', 'i_psfFluxMean', 'i_psfFluxMin', 'i_psfFluxMax']]

plt.scatter(np.arange(len(obj4_field_nan_min_max)), obj4_field_nan_min_max['r_psfFluxMean'].values, color='red')
plt.scatter(np.arange(len(obj4_field_nan_min_max)), obj4_field_nan_min_max['g_psfFluxMean'].values, s=10, color='g')
plt.scatter(np.arange(len(obj4_field_nan_min_max)), obj4_field_nan_min_max['i_psfFluxMean'].values, s=10, color='brown')
plt.ylim(-10000, 10000)
# Out:
# (-10000.0, 10000.0)

# %%
obj4_field_nan_min_max[obj4_field_nan_min_max['r_psfFluxMean']>1000]
# Out:
#                 diaObjectId  g_psfFluxMean  g_psfFluxMin  g_psfFluxMax  \
# 153210  3068394109505896606            NaN           NaN           NaN
# 153293  3068394109505896700            NaN           NaN           NaN
# 153298  3068394109505896705            NaN           NaN           NaN
# 153313  3068394109505896723            NaN           NaN           NaN
# 153315  3068394109505896725            NaN           NaN           NaN
# ...                     ...            ...           ...           ...
# 171406  3068394172869247095            NaN           NaN           NaN
# 171432  3068394172881829904            NaN           NaN           NaN
# 171439  3068394172881829934            NaN           NaN           NaN
# 171444  3068394172881829955            NaN           NaN           NaN
# 171470  3068394172886024343            NaN           NaN           NaN
#
#         r_psfFluxMean  r_psfFluxMin  r_psfFluxMax  i_psfFluxMean  \
# 153210    1518.954346   1518.954346   1518.954346            NaN
# 153293    1437.075562   1437.075562   1437.075562            NaN
# 153298    4969.968262   3656.614990   9012.880859            NaN
# 153313    1355.668823   1355.668823   1355.668823            NaN
# 153315    1581.683838   1581.683838   1581.683838            NaN
# ...               ...           ...           ...            ...
# 171406    1629.364624   1629.364624   1629.364624            NaN
# 171432    1935.905151   1935.905029   1935.905029            NaN
# 171439    3431.348633   3431.348877   3431.348877            NaN
# 171444    1486.537964   1486.538086   1486.538086            NaN
# 171470    1919.322876   1919.322754   1919.322754            NaN
#
#         i_psfFluxMin  i_psfFluxMax
# 153210           NaN           NaN
# 153293           NaN           NaN
# 153298           NaN           NaN
# 153313           NaN           NaN
# 153315           NaN           NaN
# ...              ...           ...
# 171406           NaN           NaN
# 171432           NaN           NaN
# 171439           NaN           NaN
# 171444           NaN           NaN
# 171470           NaN           NaN
#
# [441 rows x 10 columns]

# %%
src4_field[['diaSourceId', 'raErr', 'decErr', 'psfFlux', 'band', 'centroid_flag', 'apFlux_flag', 'psfFlux_flag', 'forced_PsfFlux_flag', 'shape_flag']]
# Out:
#                diaSourceId     raErr    decErr       psfFlux band  \
# 0      3068394109514285084       NaN       NaN  -1946.655640    i
# 1      3068394109514285091  0.000006  0.000005   9831.191406    i
# 2      3068394109514285097  0.000005  0.000004  11874.484375    i
# 3      3068394109514285112  0.000027  0.000021   1254.862061    i
# 4      3068394109514285133  0.000016  0.000022   1797.926636    i
# ...                    ...       ...       ...           ...  ...
# 58246  3068394109510091044  0.000003  0.000003  26648.339844    i
# 58247  3068394109510091045  0.000005  0.000004  10978.866211    i
# 58248  3068394109510091046  0.000007  0.000008   3998.014160    i
# 58249  3068394109510091047  0.000012  0.000013   2391.240234    i
# 58250  3068394109510091048       NaN       NaN   2049.343994    i
#
#        centroid_flag  apFlux_flag  psfFlux_flag  forced_PsfFlux_flag  \
# 0               True         True          True                 True
# 1              False        False         False                False
# 2              False        False         False                False
# 3              False        False         False                False
# 4              False        False         False                False
# ...              ...          ...           ...                  ...
# 58246          False        False         False                False
# 58247          False        False         False                False
# 58248          False        False         False                False
# 58249          False        False         False                False
# 58250           True         True          True                 True
#
#        shape_flag
# 0            True
# 1            True
# 2            True
# 3           False
# 4           False
# ...           ...
# 58246       False
# 58247       False
# 58248        True
# 58249        True
# 58250        True
#
# [58251 rows x 10 columns]

# %%
print(len(src4_field))

print(len(src4_field[ (src4_field['psfFlux']<0)]['raErr']))
print(len(src4_field[(src4_field['shape_flag']==True)]))
src_shape_negative = src4_field[(src4_field['shape_flag']==True) & (src4_field['psfFlux']<0)]['raErr']
print(len(src_shape_negative))
src_shape_negative[~np.isnan(src_shape_negative)].index
print(np.sum(np.isnan(src4_field['raErr'])))
# Out:
# 58251
# 15782
# 29300
# 15778
# 16401

# %%
np.sum(np.isnan(src4_field['raErr']))
# Out:
# 16401

# %%
src4_field[['diaSourceId', 'raErr', 'decErr', 'psfFlux', 'psfFluxErr', 'band', 'centroid_flag', 'apFlux_flag', 'psfFlux_flag', 'forced_PsfFlux_flag', 'shape_flag']].loc[src_shape_negative[~np.isnan(src_shape_negative)].index]
# Out:
#                diaSourceId     raErr    decErr      psfFlux  psfFluxErr band  \
# 1311   3068394109539451098  0.000366  0.000131 -1482.257935  233.992737    i
# 2152   3068394111670157475  0.000027  0.000037   -92.264366  216.773254    i
# 2311   3068394111674351700  0.000035  0.000073  -580.065918  232.914749    i
# 3885   3068394112743899273  0.000238  0.000072  -640.667603  224.214325    i
# 3903   3068394112743899298  0.000322  0.000090 -2063.958252  581.654968    i
# ...                    ...       ...       ...          ...         ...  ...
# 53355  3068394129906991262  0.000851  0.001028  -291.092712  814.717468    i
# 54371  3068394123485511681  0.000076  0.000012 -1725.450439  374.449738    i
# 55145  3068394124542476388  0.000091  0.000020   -37.486374  237.978043    i
# 55606  3068394124571836466  0.000013  0.000029  -513.365417  264.827393    i
# 57004  3068394125641384097  0.000008  0.000013 -1531.627319  235.394424    i
#
#        centroid_flag  apFlux_flag  psfFlux_flag  forced_PsfFlux_flag  \
# 1311            True         True          True                 True
# 2152           False        False         False                False
# 2311           False        False         False                False
# 3885            True         True          True                 True
# 3903           False         True          True                 True
# ...              ...          ...           ...                  ...
# 53355          False        False         False                False
# 54371           True         True          True                 True
# 55145          False        False         False                False
# 55606          False        False         False                False
# 57004           True         True          True                 True
#
#        shape_flag
# 1311         True
# 2152         True
# 2311         True
# 3885         True
# 3903         True
# ...           ...
# 53355        True
# 54371        True
# 55145        True
# 55606        True
# 57004        True
#
# [64 rows x 11 columns]

# %%
src_shape_negative = src4_field[(src4_field['shape_flag']==True) & (src4_field['psfFlux']>0)]['raErr']
src_shape_negative[~np.isnan(src_shape_negative)]
# Out:
# 1        0.000006
# 2        0.000005
# 6        0.000022
# 21       0.000013
# 22       0.000004
#            ...
# 58237    0.000011
# 58241    0.000010
# 58243    0.000004
# 58248    0.000007
# 58249    0.000012
# Name: raErr, Length: 12835, dtype: float64
